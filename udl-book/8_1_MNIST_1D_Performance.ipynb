# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /private/var/folders/n5/sr7wwb8n1wggd7jsk_k37l_w0000gn/T/pip-req-build-r4yl9qvy
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /private/var/folders/n5/sr7wwb8n1wggd7jsk_k37l_w0000gn/T/pip-req-build-r4yl9qvy
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from mnist1d==0.0.2.post16) (2.31.0)
# Requirement already satisfied: numpy in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from mnist1d==0.0.2.post16) (1.26.4)
# Requirement already satisfied: matplotlib in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from mnist1d==0.0.2.post16) (3.8.3)
# Requirement already satisfied: scipy in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from mnist1d==0.0.2.post16) (1.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (6.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from requests->mnist1d==0.0.2.post16) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from requests->mnist1d==0.0.2.post16) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from requests->mnist1d==0.0.2.post16) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from requests->mnist1d==0.0.2.post16) (2023.7.22)
# Requirement already satisfied: zipp>=3.1.0 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->mnist1d==0.0.2.post16) (3.11.0)
# Requirement already satisfied: six>=1.5 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.16.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k50 = 50   # Hidden dimensions
D_k100 = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TO DO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = nn.Sequential(
       nn.Linear(D_i, D_k100),
       nn.ReLU(),
       nn.Linear(D_k100, D_k100), 
       nn.ReLU(),         
       nn.Linear(D_k100, D_k100), 
       nn.ReLU(),         
       nn.Linear(D_k100, D_o))

def weights_init(layer_in):
  # TO DO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  print("Initializing layer")
  if isinstance(layer_in, nn.Linear):
          nn.init.kaiming_normal_(layer_in.weight)
          layer_in.bias.data.fill_(0.0)

# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=100, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.589388, train error 62.33,  test loss 1.666241, test error 67.20
# Epoch     1, train loss 1.324869, train error 51.08,  test loss 1.450302, test error 57.10
# Epoch     2, train loss 1.156860, train error 43.97,  test loss 1.362903, test error 54.90
# Epoch     3, train loss 1.028570, train error 39.03,  test loss 1.256450, test error 49.60
# Epoch     4, train loss 0.934075, train error 35.55,  test loss 1.293286, test error 48.40
# Epoch     5, train loss 0.812544, train error 31.18,  test loss 1.215825, test error 46.00
# Epoch     6, train loss 0.683438, train error 25.90,  test loss 1.165070, test error 43.40
# Epoch     7, train loss 0.563272, train error 20.75,  test loss 1.122532, test error 41.30
# Epoch     8, train loss 0.517839, train error 20.50,  test loss 1.120350, test error 41.00
# Epoch     9, train loss 0.451176, train error 16.65,  test loss 1.144669, test error 38.90
# Epoch    10, train loss 0.345679, train error 11.28,  test loss 1.081374, test error 36.30
# Epoch    11, train loss 0.374454, train error 13.38,  test loss 1.222357, test error 36.50
# Epoch    12, train loss 0.308799, train error 10.80,  test loss 1.287572, test error 37.90
# Epoch    13, train loss 0.285899, train error 10.57,  test loss 1.196399, test error 35.90
# Epoch    14, train loss 0.225030, train error 8.18,  test loss 1.270684, test error 35.80
# Epoch    15, train loss 0.205972, train error 6.93,  test loss 1.379255, test error 36.60
# Epoch    16, train loss 0.158230, train error 4.97,  test loss 1.235078, test error 34.40
# Epoch    17, train loss 0.113780, train error 3.43,  test loss 1.286865, test error 32.90
# Epoch    18, train loss 0.112057, train error 3.28,  test loss 1.361868, test error 35.40
# Epoch    19, train loss 0.168379, train error 5.45,  test loss 1.517731, test error 34.90
# Epoch    20, train loss 0.194062, train error 6.72,  test loss 1.558582, test error 36.60
# Epoch    21, train loss 0.189197, train error 6.78,  test loss 1.513862, test error 34.50
# Epoch    22, train loss 0.142887, train error 4.90,  test loss 1.646142, test error 36.40
# Epoch    23, train loss 0.150281, train error 5.10,  test loss 1.596322, test error 35.30
# Epoch    24, train loss 0.120739, train error 3.53,  test loss 1.583451, test error 35.00
# Epoch    25, train loss 0.070308, train error 1.95,  test loss 1.522773, test error 32.00
# Epoch    26, train loss 0.051267, train error 1.50,  test loss 1.566918, test error 32.30
# Epoch    27, train loss 0.097376, train error 3.35,  test loss 1.774028, test error 35.80
# Epoch    28, train loss 0.073372, train error 2.30,  test loss 1.643098, test error 33.40
# Epoch    29, train loss 0.091427, train error 3.15,  test loss 1.871409, test error 33.30
# Epoch    30, train loss 0.181125, train error 6.20,  test loss 1.925911, test error 34.50
# Epoch    31, train loss 0.192243, train error 6.88,  test loss 1.917016, test error 37.50
# Epoch    32, train loss 0.072830, train error 2.57,  test loss 1.721855, test error 34.10
# Epoch    33, train loss 0.075216, train error 2.15,  test loss 1.740216, test error 32.00
# Epoch    34, train loss 0.030311, train error 0.80,  test loss 1.656140, test error 31.70
# Epoch    35, train loss 0.021723, train error 0.47,  test loss 1.746311, test error 31.90
# Epoch    36, train loss 0.008259, train error 0.12,  test loss 1.773126, test error 31.10
# Epoch    37, train loss 0.002630, train error 0.00,  test loss 1.682008, test error 29.40
# Epoch    38, train loss 0.001536, train error 0.00,  test loss 1.709402, test error 29.50
# Epoch    39, train loss 0.001247, train error 0.00,  test loss 1.718306, test error 29.70
# Epoch    40, train loss 0.001092, train error 0.00,  test loss 1.732491, test error 29.80
# Epoch    41, train loss 0.000983, train error 0.00,  test loss 1.741039, test error 29.70
# Epoch    42, train loss 0.000898, train error 0.00,  test loss 1.752027, test error 29.70
# Epoch    43, train loss 0.000830, train error 0.00,  test loss 1.761144, test error 30.00
# Epoch    44, train loss 0.000773, train error 0.00,  test loss 1.771511, test error 30.00
# Epoch    45, train loss 0.000724, train error 0.00,  test loss 1.779936, test error 29.90
# Epoch    46, train loss 0.000684, train error 0.00,  test loss 1.787525, test error 30.00
# Epoch    47, train loss 0.000646, train error 0.00,  test loss 1.796635, test error 29.90
# Epoch    48, train loss 0.000614, train error 0.00,  test loss 1.803234, test error 29.80
# Epoch    49, train loss 0.000585, train error 0.00,  test loss 1.809163, test error 29.70
# Epoch    50, train loss 0.000559, train error 0.00,  test loss 1.817132, test error 29.70
# Epoch    51, train loss 0.000536, train error 0.00,  test loss 1.822045, test error 29.50
# Epoch    52, train loss 0.000514, train error 0.00,  test loss 1.828452, test error 29.50
# Epoch    53, train loss 0.000495, train error 0.00,  test loss 1.834447, test error 29.60
# Epoch    54, train loss 0.000477, train error 0.00,  test loss 1.839299, test error 29.60
# Epoch    55, train loss 0.000461, train error 0.00,  test loss 1.843772, test error 29.60
# Epoch    56, train loss 0.000446, train error 0.00,  test loss 1.848647, test error 29.70
# Epoch    57, train loss 0.000432, train error 0.00,  test loss 1.853286, test error 29.80
# Epoch    58, train loss 0.000418, train error 0.00,  test loss 1.857588, test error 29.70
# Epoch    59, train loss 0.000406, train error 0.00,  test loss 1.861659, test error 29.80
# Epoch    60, train loss 0.000394, train error 0.00,  test loss 1.866593, test error 29.80
# Epoch    61, train loss 0.000383, train error 0.00,  test loss 1.870926, test error 29.80
# Epoch    62, train loss 0.000373, train error 0.00,  test loss 1.874348, test error 29.80
# Epoch    63, train loss 0.000363, train error 0.00,  test loss 1.878429, test error 29.70
# Epoch    64, train loss 0.000354, train error 0.00,  test loss 1.882934, test error 29.80
# Epoch    65, train loss 0.000345, train error 0.00,  test loss 1.886320, test error 29.70
# Epoch    66, train loss 0.000337, train error 0.00,  test loss 1.889600, test error 29.80
# Epoch    67, train loss 0.000329, train error 0.00,  test loss 1.893879, test error 29.60
# Epoch    68, train loss 0.000321, train error 0.00,  test loss 1.896672, test error 29.60
# Epoch    69, train loss 0.000314, train error 0.00,  test loss 1.900425, test error 29.70
# Epoch    70, train loss 0.000307, train error 0.00,  test loss 1.903078, test error 29.60
# Epoch    71, train loss 0.000301, train error 0.00,  test loss 1.906586, test error 29.70
# Epoch    72, train loss 0.000295, train error 0.00,  test loss 1.909322, test error 29.80
# Epoch    73, train loss 0.000289, train error 0.00,  test loss 1.912700, test error 29.80
# Epoch    74, train loss 0.000283, train error 0.00,  test loss 1.915682, test error 29.70
# Epoch    75, train loss 0.000277, train error 0.00,  test loss 1.918722, test error 29.70
# Epoch    76, train loss 0.000272, train error 0.00,  test loss 1.921607, test error 29.70
# Epoch    77, train loss 0.000267, train error 0.00,  test loss 1.924079, test error 29.70
# Epoch    78, train loss 0.000262, train error 0.00,  test loss 1.927214, test error 29.70
# Epoch    79, train loss 0.000258, train error 0.00,  test loss 1.929483, test error 29.80
# Epoch    80, train loss 0.000253, train error 0.00,  test loss 1.932632, test error 29.80
# Epoch    81, train loss 0.000249, train error 0.00,  test loss 1.935292, test error 29.70
# Epoch    82, train loss 0.000245, train error 0.00,  test loss 1.937914, test error 29.90
# Epoch    83, train loss 0.000241, train error 0.00,  test loss 1.940375, test error 29.90
# Epoch    84, train loss 0.000237, train error 0.00,  test loss 1.942832, test error 29.90
# Epoch    85, train loss 0.000233, train error 0.00,  test loss 1.945291, test error 30.00
# Epoch    86, train loss 0.000229, train error 0.00,  test loss 1.948001, test error 29.90
# Epoch    87, train loss 0.000226, train error 0.00,  test loss 1.950642, test error 30.00
# Epoch    88, train loss 0.000222, train error 0.00,  test loss 1.953043, test error 30.00
# Epoch    89, train loss 0.000219, train error 0.00,  test loss 1.955429, test error 30.00
# Epoch    90, train loss 0.000216, train error 0.00,  test loss 1.958089, test error 29.90
# Epoch    91, train loss 0.000213, train error 0.00,  test loss 1.960032, test error 29.90
# Epoch    92, train loss 0.000210, train error 0.00,  test loss 1.962360, test error 30.00
# Epoch    93, train loss 0.000207, train error 0.00,  test loss 1.964645, test error 30.00
# Epoch    94, train loss 0.000204, train error 0.00,  test loss 1.967465, test error 30.00
# Epoch    95, train loss 0.000201, train error 0.00,  test loss 1.969759, test error 30.00
# Epoch    96, train loss 0.000198, train error 0.00,  test loss 1.971588, test error 30.00
# Epoch    97, train loss 0.000196, train error 0.00,  test loss 1.973332, test error 30.00
# Epoch    98, train loss 0.000193, train error 0.00,  test loss 1.975749, test error 30.00
# Epoch    99, train loss 0.000191, train error 0.00,  test loss 1.978194, test error 30.00

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TO DO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
