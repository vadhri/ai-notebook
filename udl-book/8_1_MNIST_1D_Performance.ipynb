# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /private/var/folders/n5/sr7wwb8n1wggd7jsk_k37l_w0000gn/T/pip-req-build-r4yl9qvy
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /private/var/folders/n5/sr7wwb8n1wggd7jsk_k37l_w0000gn/T/pip-req-build-r4yl9qvy
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from mnist1d==0.0.2.post16) (2.31.0)
# Requirement already satisfied: numpy in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from mnist1d==0.0.2.post16) (1.26.4)
# Requirement already satisfied: matplotlib in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from mnist1d==0.0.2.post16) (3.8.3)
# Requirement already satisfied: scipy in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from mnist1d==0.0.2.post16) (1.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from matplotlib->mnist1d==0.0.2.post16) (6.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from requests->mnist1d==0.0.2.post16) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from requests->mnist1d==0.0.2.post16) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from requests->mnist1d==0.0.2.post16) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from requests->mnist1d==0.0.2.post16) (2023.7.22)
# Requirement already satisfied: zipp>=3.1.0 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->mnist1d==0.0.2.post16) (3.11.0)
# Requirement already satisfied: six>=1.5 in /Users/venkat/opt/anaconda3/envs/QCML/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.16.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k50 = 50   # Hidden dimensions
D_k100 = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TO DO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = nn.Sequential(
       nn.Linear(D_i, D_k50),
       nn.ReLU(),
       nn.Linear(D_k50, D_k100), 
       nn.ReLU(),  
       nn.Linear(D_k100, D_k100), 
       nn.ReLU(),         
       nn.Linear(D_k100, D_k50), 
       nn.ReLU(),         
       nn.Dropout(0.2),
       nn.Linear(D_k50, D_o))

def weights_init(layer_in):
  # TO DO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  print("Initializing layer")
  if isinstance(layer_in, nn.Linear):
          nn.init.kaiming_normal_(layer_in.weight)
          layer_in.bias.data.fill_(0.0)

# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=50, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=50, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=50, bias=True)
#   (7): ReLU()
#   (8): Dropout(p=0.2, inplace=False)
#   (9): Linear(in_features=50, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.1, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=100, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 200
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.733311, train error 68.85,  test loss 1.765005, test error 70.10
# Epoch     1, train loss 1.476596, train error 59.58,  test loss 1.564979, test error 63.10
# Epoch     2, train loss 1.369781, train error 54.67,  test loss 1.493754, test error 59.20
# Epoch     3, train loss 1.366346, train error 57.03,  test loss 1.493482, test error 64.10
# Epoch     4, train loss 1.171474, train error 46.47,  test loss 1.301119, test error 54.50
# Epoch     5, train loss 1.170520, train error 46.50,  test loss 1.361379, test error 54.00
# Epoch     6, train loss 1.050935, train error 41.22,  test loss 1.322825, test error 51.20
# Epoch     7, train loss 0.973639, train error 38.58,  test loss 1.255017, test error 48.80
# Epoch     8, train loss 1.039409, train error 39.90,  test loss 1.316623, test error 48.50
# Epoch     9, train loss 0.886530, train error 35.38,  test loss 1.234156, test error 44.80
# Epoch    10, train loss 0.932253, train error 35.53,  test loss 1.346984, test error 49.00
# Epoch    11, train loss 0.971413, train error 35.78,  test loss 1.343182, test error 48.00
# Epoch    12, train loss 0.864638, train error 32.93,  test loss 1.247377, test error 42.80
# Epoch    13, train loss 0.786168, train error 30.95,  test loss 1.317930, test error 45.90
# Epoch    14, train loss 0.838977, train error 30.90,  test loss 1.225753, test error 44.20
# Epoch    15, train loss 0.731503, train error 28.07,  test loss 1.232256, test error 43.80
# Epoch    16, train loss 0.722798, train error 27.85,  test loss 1.320048, test error 43.20
# Epoch    17, train loss 0.687637, train error 26.32,  test loss 1.260893, test error 40.80
# Epoch    18, train loss 0.647627, train error 24.25,  test loss 1.226474, test error 38.40
# Epoch    19, train loss 0.606664, train error 22.72,  test loss 1.271583, test error 41.10
# Epoch    20, train loss 0.628714, train error 22.82,  test loss 1.257815, test error 39.80
# Epoch    21, train loss 0.676255, train error 24.65,  test loss 1.360093, test error 41.30
# Epoch    22, train loss 0.585910, train error 22.25,  test loss 1.286898, test error 39.80
# Epoch    23, train loss 0.598982, train error 21.53,  test loss 1.393995, test error 43.70
# Epoch    24, train loss 0.576659, train error 21.45,  test loss 1.313666, test error 37.60
# Epoch    25, train loss 0.563319, train error 20.72,  test loss 1.342425, test error 40.50
# Epoch    26, train loss 0.527969, train error 19.88,  test loss 1.180262, test error 38.00
# Epoch    27, train loss 0.573455, train error 20.97,  test loss 1.369995, test error 38.60
# Epoch    28, train loss 0.484697, train error 18.03,  test loss 1.308845, test error 37.60
# Epoch    29, train loss 0.477344, train error 17.30,  test loss 1.422522, test error 38.10
# Epoch    30, train loss 0.446360, train error 16.10,  test loss 1.284643, test error 37.00
# Epoch    31, train loss 0.503340, train error 17.40,  test loss 1.353773, test error 36.00
# Epoch    32, train loss 0.447156, train error 15.78,  test loss 1.262740, test error 37.80
# Epoch    33, train loss 0.402435, train error 14.72,  test loss 1.337553, test error 35.30
# Epoch    34, train loss 0.536379, train error 19.28,  test loss 1.321228, test error 37.90
# Epoch    35, train loss 0.600050, train error 21.30,  test loss 1.415035, test error 40.50
# Epoch    36, train loss 0.532085, train error 17.80,  test loss 1.342685, test error 39.30
# Epoch    37, train loss 0.553893, train error 18.10,  test loss 1.402958, test error 40.00
# Epoch    38, train loss 0.457988, train error 15.78,  test loss 1.436468, test error 37.40
# Epoch    39, train loss 0.485672, train error 17.43,  test loss 1.422675, test error 37.70
# Epoch    40, train loss 0.434404, train error 15.28,  test loss 1.358060, test error 35.60
# Epoch    41, train loss 0.382064, train error 13.40,  test loss 1.501649, test error 34.50
# Epoch    42, train loss 0.460973, train error 16.40,  test loss 1.387593, test error 36.50
# Epoch    43, train loss 0.431977, train error 14.70,  test loss 1.514472, test error 36.20
# Epoch    44, train loss 0.362674, train error 12.68,  test loss 1.568397, test error 37.90
# Epoch    45, train loss 0.444213, train error 13.95,  test loss 1.751994, test error 40.10
# Epoch    46, train loss 0.469797, train error 15.65,  test loss 1.599587, test error 38.90
# Epoch    47, train loss 0.399546, train error 12.55,  test loss 1.776811, test error 39.30
# Epoch    48, train loss 0.448995, train error 15.07,  test loss 1.637089, test error 38.90
# Epoch    49, train loss 0.479146, train error 16.95,  test loss 1.410438, test error 37.90
# Epoch    50, train loss 0.524795, train error 17.53,  test loss 1.483114, test error 38.50
# Epoch    51, train loss 0.481566, train error 15.65,  test loss 1.477150, test error 35.50
# Epoch    52, train loss 0.588037, train error 16.50,  test loss 1.932391, test error 39.50
# Epoch    53, train loss 0.399755, train error 14.05,  test loss 1.296237, test error 36.40
# Epoch    54, train loss 0.341995, train error 11.43,  test loss 1.576710, test error 36.00
# Epoch    55, train loss 0.372398, train error 12.50,  test loss 1.557138, test error 35.70
# Epoch    56, train loss 0.428527, train error 14.40,  test loss 1.602688, test error 38.10
# Epoch    57, train loss 0.319897, train error 11.12,  test loss 1.502224, test error 35.40
# Epoch    58, train loss 0.447463, train error 13.60,  test loss 1.717075, test error 36.90
# Epoch    59, train loss 0.309359, train error 10.60,  test loss 1.462340, test error 36.50
# Epoch    60, train loss 0.415140, train error 13.78,  test loss 1.632799, test error 35.40
# Epoch    61, train loss 0.527091, train error 16.62,  test loss 1.685890, test error 38.60
# Epoch    62, train loss 0.541332, train error 16.78,  test loss 2.006175, test error 40.60
# Epoch    63, train loss 0.545520, train error 16.57,  test loss 1.500182, test error 36.60
# Epoch    64, train loss 0.640908, train error 20.93,  test loss 1.559366, test error 40.30
# Epoch    65, train loss 0.514993, train error 16.78,  test loss 1.555399, test error 36.50
# Epoch    66, train loss 0.396951, train error 12.20,  test loss 1.717555, test error 37.00
# Epoch    67, train loss 0.423416, train error 13.28,  test loss 1.695424, test error 37.70
# Epoch    68, train loss 0.388290, train error 13.07,  test loss 1.723773, test error 38.60
# Epoch    69, train loss 0.414674, train error 13.28,  test loss 1.708009, test error 37.90
# Epoch    70, train loss 0.463766, train error 13.47,  test loss 1.832350, test error 38.90
# Epoch    71, train loss 0.542079, train error 15.50,  test loss 2.009563, test error 40.60
# Epoch    72, train loss 0.396080, train error 13.15,  test loss 1.706321, test error 40.70
# Epoch    73, train loss 0.437654, train error 12.15,  test loss 1.818268, test error 36.00
# Epoch    74, train loss 0.371734, train error 12.38,  test loss 1.680489, test error 36.70
# Epoch    75, train loss 0.362654, train error 11.97,  test loss 2.007435, test error 36.80
# Epoch    76, train loss 0.427229, train error 12.75,  test loss 1.910395, test error 40.20
# Epoch    77, train loss 0.648422, train error 15.35,  test loss 2.082395, test error 42.40
# Epoch    78, train loss 0.486513, train error 15.80,  test loss 1.644684, test error 39.40
# Epoch    79, train loss 0.460647, train error 14.75,  test loss 1.987570, test error 37.70
# Epoch    80, train loss 0.364928, train error 11.97,  test loss 1.658685, test error 36.60
# Epoch    81, train loss 0.515573, train error 15.93,  test loss 1.983856, test error 38.40
# Epoch    82, train loss 0.473515, train error 14.60,  test loss 2.137848, test error 39.50
# Epoch    83, train loss 0.465056, train error 14.32,  test loss 1.713777, test error 36.80
# Epoch    84, train loss 0.653887, train error 18.43,  test loss 1.984079, test error 39.80
# Epoch    85, train loss 0.909001, train error 24.93,  test loss 2.398806, test error 45.30
# Epoch    86, train loss 1.053039, train error 30.85,  test loss 2.165860, test error 50.30
# Epoch    87, train loss 1.188065, train error 33.32,  test loss 2.199110, test error 50.40
# Epoch    88, train loss 0.998326, train error 33.95,  test loss 1.721263, test error 50.30
# Epoch    89, train loss 1.058653, train error 33.57,  test loss 2.075405, test error 49.30
# Epoch    90, train loss 0.965064, train error 29.72,  test loss 1.695153, test error 43.90
# Epoch    91, train loss 0.662929, train error 22.35,  test loss 1.588864, test error 42.10
# Epoch    92, train loss 1.053518, train error 33.07,  test loss 1.848656, test error 50.40
# Epoch    93, train loss 0.883347, train error 25.93,  test loss 1.873720, test error 46.00
# Epoch    94, train loss 1.015356, train error 28.18,  test loss 1.797616, test error 43.60
# Epoch    95, train loss 0.745217, train error 25.43,  test loss 1.646952, test error 43.10
# Epoch    96, train loss 0.944500, train error 32.25,  test loss 1.774288, test error 50.60
# Epoch    97, train loss 0.792044, train error 25.47,  test loss 1.858194, test error 45.20
# Epoch    98, train loss 1.033018, train error 35.20,  test loss 1.812417, test error 52.50
# Epoch    99, train loss 0.758790, train error 24.65,  test loss 1.680506, test error 41.50
# Epoch   100, train loss 0.537675, train error 18.90,  test loss 1.526264, test error 39.40
# Epoch   101, train loss 0.373805, train error 13.55,  test loss 1.846667, test error 36.50
# Epoch   102, train loss 0.306640, train error 10.50,  test loss 1.929549, test error 36.90
# Epoch   103, train loss 0.266792, train error 9.38,  test loss 2.122543, test error 36.30
# Epoch   104, train loss 0.210999, train error 7.62,  test loss 1.980617, test error 34.90
# Epoch   105, train loss 0.196289, train error 6.97,  test loss 2.143184, test error 34.40
# Epoch   106, train loss 0.192971, train error 6.70,  test loss 2.178511, test error 35.10
# Epoch   107, train loss 0.182103, train error 6.18,  test loss 2.530475, test error 35.30
# Epoch   108, train loss 0.159643, train error 5.10,  test loss 2.628824, test error 35.70
# Epoch   109, train loss 0.139008, train error 5.38,  test loss 2.652404, test error 34.20
# Epoch   110, train loss 0.123097, train error 4.53,  test loss 2.581049, test error 34.60
# Epoch   111, train loss 0.160216, train error 5.40,  test loss 2.673319, test error 34.90
# Epoch   112, train loss 0.133700, train error 4.47,  test loss 2.543468, test error 34.70
# Epoch   113, train loss 0.117366, train error 3.80,  test loss 2.561995, test error 33.60
# Epoch   114, train loss 0.098191, train error 3.35,  test loss 2.764992, test error 35.20
# Epoch   115, train loss 0.102025, train error 3.55,  test loss 2.760603, test error 33.00
# Epoch   116, train loss 0.093046, train error 3.50,  test loss 2.933409, test error 34.30
# Epoch   117, train loss 0.084973, train error 2.95,  test loss 2.780115, test error 33.60
# Epoch   118, train loss 0.118774, train error 3.70,  test loss 2.833031, test error 33.60
# Epoch   119, train loss 0.107914, train error 3.47,  test loss 3.089028, test error 34.30
# Epoch   120, train loss 0.123384, train error 3.75,  test loss 2.978929, test error 34.90
# Epoch   121, train loss 0.124402, train error 4.25,  test loss 2.847038, test error 34.60
# Epoch   122, train loss 0.084909, train error 2.90,  test loss 2.704862, test error 35.20
# Epoch   123, train loss 0.114119, train error 3.53,  test loss 3.259931, test error 36.00
# Epoch   124, train loss 0.124304, train error 3.72,  test loss 3.112366, test error 34.60
# Epoch   125, train loss 0.118031, train error 3.70,  test loss 2.873440, test error 34.50
# Epoch   126, train loss 0.123407, train error 3.70,  test loss 3.103188, test error 35.30
# Epoch   127, train loss 0.161176, train error 4.65,  test loss 2.951725, test error 34.80
# Epoch   128, train loss 0.095112, train error 3.47,  test loss 3.170326, test error 34.90
# Epoch   129, train loss 0.084196, train error 2.70,  test loss 3.273186, test error 36.00
# Epoch   130, train loss 0.084160, train error 2.68,  test loss 3.102796, test error 33.40
# Epoch   131, train loss 0.059260, train error 1.82,  test loss 3.133217, test error 33.20
# Epoch   132, train loss 0.072485, train error 2.43,  test loss 3.237790, test error 33.60
# Epoch   133, train loss 0.062996, train error 2.03,  test loss 3.313900, test error 33.90
# Epoch   134, train loss 0.061274, train error 1.65,  test loss 3.332166, test error 33.40
# Epoch   135, train loss 0.055350, train error 1.93,  test loss 3.387909, test error 33.30
# Epoch   136, train loss 0.058073, train error 1.93,  test loss 3.485495, test error 33.50
# Epoch   137, train loss 0.079899, train error 2.57,  test loss 3.306614, test error 33.50
# Epoch   138, train loss 0.105796, train error 2.97,  test loss 3.607807, test error 33.50
# Epoch   139, train loss 0.142052, train error 4.15,  test loss 3.333544, test error 34.40
# Epoch   140, train loss 0.079853, train error 2.53,  test loss 3.160534, test error 34.90
# Epoch   141, train loss 0.055764, train error 1.88,  test loss 3.141344, test error 33.80
# Epoch   142, train loss 0.075050, train error 2.72,  test loss 3.498575, test error 33.70
# Epoch   143, train loss 0.061965, train error 2.15,  test loss 3.316141, test error 34.20
# Epoch   144, train loss 0.040372, train error 1.45,  test loss 3.406438, test error 32.70
# Epoch   145, train loss 0.038292, train error 1.28,  test loss 3.407210, test error 33.50
# Epoch   146, train loss 0.027296, train error 0.80,  test loss 3.693970, test error 33.10
# Epoch   147, train loss 0.051990, train error 1.75,  test loss 3.829780, test error 32.50
# Epoch   148, train loss 0.115128, train error 2.68,  test loss 3.680011, test error 34.90
# Epoch   149, train loss 0.101648, train error 2.88,  test loss 3.481967, test error 33.10
# Epoch   150, train loss 0.114266, train error 3.53,  test loss 3.375334, test error 36.40
# Epoch   151, train loss 0.090841, train error 2.60,  test loss 3.160830, test error 34.00
# Epoch   152, train loss 0.078601, train error 2.15,  test loss 3.187198, test error 34.80
# Epoch   153, train loss 0.060718, train error 2.18,  test loss 3.345648, test error 34.60
# Epoch   154, train loss 0.314589, train error 4.72,  test loss 3.574678, test error 35.10
# Epoch   155, train loss 0.095288, train error 2.72,  test loss 3.531048, test error 34.40
# Epoch   156, train loss 0.068181, train error 1.82,  test loss 3.580293, test error 33.30
# Epoch   157, train loss 0.162052, train error 3.40,  test loss 3.480335, test error 34.20
# Epoch   158, train loss 0.101634, train error 2.95,  test loss 3.514999, test error 33.50
# Epoch   159, train loss 0.091832, train error 2.72,  test loss 3.445376, test error 33.70
# Epoch   160, train loss 0.082479, train error 2.50,  test loss 3.304694, test error 36.20
# Epoch   161, train loss 0.055659, train error 1.43,  test loss 3.137628, test error 34.10
# Epoch   162, train loss 0.043772, train error 1.20,  test loss 3.426101, test error 33.20
# Epoch   163, train loss 0.026187, train error 0.78,  test loss 3.554217, test error 33.10
# Epoch   164, train loss 0.033667, train error 0.85,  test loss 3.676030, test error 33.20
# Epoch   165, train loss 0.031679, train error 0.95,  test loss 3.610664, test error 32.40
# Epoch   166, train loss 0.031779, train error 1.15,  test loss 3.519581, test error 33.30
# Epoch   167, train loss 0.022953, train error 0.70,  test loss 3.564818, test error 32.00
# Epoch   168, train loss 0.021944, train error 0.70,  test loss 3.610830, test error 31.90
# Epoch   169, train loss 0.018943, train error 0.57,  test loss 3.796032, test error 32.00
# Epoch   170, train loss 0.022527, train error 0.70,  test loss 3.846374, test error 32.70
# Epoch   171, train loss 0.022448, train error 0.95,  test loss 3.816570, test error 31.90
# Epoch   172, train loss 0.020972, train error 0.70,  test loss 3.877517, test error 32.90
# Epoch   173, train loss 0.019931, train error 0.68,  test loss 3.798401, test error 33.10
# Epoch   174, train loss 0.025141, train error 0.85,  test loss 3.895656, test error 32.60
# Epoch   175, train loss 0.020500, train error 0.65,  test loss 4.280656, test error 32.30
# Epoch   176, train loss 0.014081, train error 0.53,  test loss 4.167483, test error 31.70
# Epoch   177, train loss 0.026943, train error 1.00,  test loss 4.202705, test error 32.10
# Epoch   178, train loss 0.015472, train error 0.60,  test loss 4.380748, test error 32.70
# Epoch   179, train loss 0.027254, train error 0.82,  test loss 4.264583, test error 31.90
# Epoch   180, train loss 0.022737, train error 0.57,  test loss 4.147512, test error 32.10
# Epoch   181, train loss 0.051160, train error 1.30,  test loss 4.317064, test error 33.00
# Epoch   182, train loss 0.208007, train error 3.85,  test loss 3.975817, test error 33.80
# Epoch   183, train loss 0.177208, train error 5.25,  test loss 3.855906, test error 36.00
# Epoch   184, train loss 0.103305, train error 3.55,  test loss 3.090527, test error 32.80
# Epoch   185, train loss 0.091445, train error 2.43,  test loss 2.996989, test error 33.00
# Epoch   186, train loss 0.057936, train error 1.75,  test loss 3.228384, test error 35.00
# Epoch   187, train loss 0.047059, train error 1.50,  test loss 3.324078, test error 32.80
# Epoch   188, train loss 0.058128, train error 1.50,  test loss 3.520188, test error 33.30
# Epoch   189, train loss 0.053545, train error 1.57,  test loss 3.484113, test error 34.00
# Epoch   190, train loss 0.030509, train error 0.75,  test loss 3.777134, test error 32.90
# Epoch   191, train loss 0.033802, train error 0.85,  test loss 3.710823, test error 33.20
# Epoch   192, train loss 0.019676, train error 0.62,  test loss 3.692177, test error 32.20
# Epoch   193, train loss 0.024397, train error 0.65,  test loss 3.812295, test error 31.70
# Epoch   194, train loss 0.026505, train error 0.60,  test loss 3.889124, test error 32.90
# Epoch   195, train loss 0.026707, train error 0.72,  test loss 3.999740, test error 31.30
# Epoch   196, train loss 0.021204, train error 0.60,  test loss 4.071089, test error 32.10
# Epoch   197, train loss 0.023587, train error 0.68,  test loss 4.275157, test error 33.10
# Epoch   198, train loss 0.015709, train error 0.50,  test loss 4.251202, test error 32.00
# Epoch   199, train loss 0.014549, train error 0.38,  test loss 4.361123, test error 32.30

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TO DO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
