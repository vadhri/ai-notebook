# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap16/16_3_Contraction_Mappings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 16.3: Contraction mappings**
#
# This notebook investigates a 1D normalizing flows example similar to that illustrated in figure 16.9 in the book.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define a function that is a contraction mapping
def f(z):
    return 0.3 + 0.5 *z + 0.02 * np.sin(z*15)

# %%
def draw_function(f, fixed_point=None):
  z = np.arange(0,1,0.01)
  z_prime = f(z)

  # Draw this function
  fig, ax = plt.subplots()
  fig.set_figwidth(4)
  fig.set_figheight(3.5)
  ax.plot(z, z_prime,'c-')
  ax.plot([0,1],[0,1],'k--')
  if fixed_point!=None:
    ax.plot(fixed_point, fixed_point, 'ro')
  ax.set_xlim(0,1)
  ax.set_ylim(0,1)
  ax.set_xlabel('Input, $z$')
  ax.set_ylabel('Output, f$[z]$')
  plt.show()

# %% [markdown]
# Now let's find where $\text{f}[z]=z$ using fixed point iteration

# %%
# Takes a function f and a starting point z
def fixed_point_iteration(f, z0):
  # TODO -- write this function
  # Print out the iterations as you go, so you can see the progress
  # Set the maximum number of iterations to 20
  # Replace this line
  z_out = z0;
  iterations = 20;

  for i in range(iterations):
    print (i, "Check if Z and F(z) are closeness tolerance of 1e-10 = ", np.round(z_out, 3), np.round(f(z_out), 3), np.isclose(z_out, f(z_out), atol=1e-10))
    z_out = f(z_out)

  return z_out

# %% [markdown]
# Now let's test that and plot the solution

# %%
# Now let's test that
z = fixed_point_iteration(f, 0.2)
draw_function(f, z)
# Out:
# 0 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.2 0.403 False
# 1 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.403 0.497 False
# 2 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.497 0.567 False
# 3 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.567 0.599 False
# 4 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.599 0.608 False
# 5 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.608 0.61 False
# 6 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.61 0.61 False
# 7 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.61 0.611 False
# 8 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.611 0.611 False
# 9 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.611 0.611 True
# 10 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.611 0.611 True
# 11 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.611 0.611 True
# 12 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.611 0.611 True
# 13 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.611 0.611 True
# 14 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.611 0.611 True
# 15 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.611 0.611 True
# 16 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.611 0.611 True
# 17 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.611 0.611 True
# 18 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.611 0.611 True
# 19 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.611 0.611 True

# %%
# Let's define another function
def f2(z):
    return 0.7 + -0.6 *z + 0.03 * np.sin(z*15)
draw_function(f2)

# %%
# Now let's test that
# TODO Before running this code, predict what you think will happen
z = fixed_point_iteration(f2, 0.9)
draw_function(f2, z)
# Out:
# 0 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.9 0.184 False
# 1 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.184 0.601 False
# 2 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.601 0.352 False
# 3 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.352 0.464 False
# 4 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.464 0.44 False
# 5 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.44 0.445 False
# 6 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.445 0.444 False
# 7 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.444 0.445 False
# 8 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.445 0.445 False
# 9 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.445 0.445 False
# 10 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.445 0.445 True
# 11 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.445 0.445 True
# 12 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.445 0.445 True
# 13 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.445 0.445 True
# 14 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.445 0.445 True
# 15 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.445 0.445 True
# 16 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.445 0.445 True
# 17 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.445 0.445 True
# 18 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.445 0.445 True
# 19 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.445 0.445 True

# %%
# Let's define another function
# Define a function that is a contraction mapping
def f3(z):
    return -0.2 + 1.5 *z + 0.1 * np.sin(z*15)
draw_function(f3)

# %%
# Now let's test that
# TODO Before running this code, predict what you think will happen
z = fixed_point_iteration(f3, 0.7)
draw_function(f3, z)
# Out:
# 0 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.7 0.762 False
# 1 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.762 0.852 False
# 2 Check if Z and F(z) are closeness tolerance of 1e-10 =  0.852 1.1 False
# 3 Check if Z and F(z) are closeness tolerance of 1e-10 =  1.1 1.379 False
# 4 Check if Z and F(z) are closeness tolerance of 1e-10 =  1.379 1.965 False
# 5 Check if Z and F(z) are closeness tolerance of 1e-10 =  1.965 2.654 False
# 6 Check if Z and F(z) are closeness tolerance of 1e-10 =  2.654 3.867 False
# 7 Check if Z and F(z) are closeness tolerance of 1e-10 =  3.867 5.7 False
# 8 Check if Z and F(z) are closeness tolerance of 1e-10 =  5.7 8.287 False
# 9 Check if Z and F(z) are closeness tolerance of 1e-10 =  8.287 12.133 False
# 10 Check if Z and F(z) are closeness tolerance of 1e-10 =  12.133 17.979 False
# 11 Check if Z and F(z) are closeness tolerance of 1e-10 =  17.979 26.72 False
# 12 Check if Z and F(z) are closeness tolerance of 1e-10 =  26.72 39.783 False
# 13 Check if Z and F(z) are closeness tolerance of 1e-10 =  39.783 59.459 False
# 14 Check if Z and F(z) are closeness tolerance of 1e-10 =  59.459 88.957 False
# 15 Check if Z and F(z) are closeness tolerance of 1e-10 =  88.957 133.309 False
# 16 Check if Z and F(z) are closeness tolerance of 1e-10 =  133.309 199.863 False
# 17 Check if Z and F(z) are closeness tolerance of 1e-10 =  199.863 299.672 False
# 18 Check if Z and F(z) are closeness tolerance of 1e-10 =  299.672 449.359 False
# 19 Check if Z and F(z) are closeness tolerance of 1e-10 =  449.359 673.739 False

# %% [markdown]
# Finally, let's invert a problem of the form $y = z+ f[z]$  for a given value of $y$. What is the $z$ that maps to it?

# %%
def f4(z):
   return -0.3 + 0.5 *z + 0.02 * np.sin(z*15)

# %%
def fixed_point_iteration_z_plus_f(f, y, z0):
  # TODO -- write this function
  # Replace this line
  z_out = z0
  iterations = 20
  for i in range(iterations):
    print (i, z_out +  f(z_out))
    z_out = y - f(z_out)

  return z_out

# %%
def draw_function2(f, y, fixed_point=None):
  z = np.arange(0,1,0.01)
  z_prime = z+f(z)

  # Draw this function
  fig, ax = plt.subplots()
  ax.plot(z, z_prime,'c-')
  ax.plot(z, y-f(z),'r-')
  ax.plot([0,1],[0,1],'k--')
  if fixed_point!=None:
    ax.plot(fixed_point, y, 'ro')
  ax.set_xlim(0,1)
  ax.set_ylim(0,1)
  ax.set_xlabel('Input, $z$')
  ax.set_ylabel('Output, z+f$[z]$')
  plt.show()

# %%
# Test this out and draw
y = 0.8
z = fixed_point_iteration_z_plus_f(f4,y,0.2)
draw_function2(f4,y,z)
# If you have done this correctly, the red dot should be
# where the cyan curve has a y value of 0.8
# Out:
# 0 0.0028224001611973637
# 1 1.2094035538040362
# 2 0.5930883551627767
# 3 0.879987230140957
# 4 0.7527997160815854
# 5 0.8246931146398835
# 6 0.7858475074963301
# 7 0.8077875807189341
# 8 0.7956048829361357
# 9 0.8024477566533559
# 10 0.7986262480907717
# 11 0.8007677401477664
# 12 0.7995699113015113
# 13 0.8002406159802345
# 14 0.7998652852453828
# 15 0.8000753919043044
# 16 0.7999577977346122
# 17 0.8000236205516434
# 18 0.7999867786409528
# 19 0.800007400215579
