# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-qp_dyy6u
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-qp_dyy6u
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post16) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post16) (3.8.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mnist1d==0.0.2.post16) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post16) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->mnist1d==0.0.2.post16) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.16.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14624 sha256=46ee53ff645878730de1e57b380b1c3e53ea89aabb1e236720fbe6f95d299968
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fom04qb3/wheels/41/95/55/45fcf7d38cfa97e35682da6c5017d4513729131326ce935371
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.282601, train error 85.00,  test loss 2.285433, test error 85.60
# Epoch   100, train loss 1.852347, train error 70.35,  test loss 1.699741, test error 68.40
# Epoch   200, train loss 1.847983, train error 70.15,  test loss 1.697170, test error 67.30
# Epoch   300, train loss 1.846059, train error 69.95,  test loss 1.697798, test error 67.32
# Epoch   400, train loss 1.846806, train error 70.43,  test loss 1.688726, test error 68.18
# Epoch   500, train loss 1.843972, train error 70.50,  test loss 1.689626, test error 67.53
# Epoch   600, train loss 1.846929, train error 70.65,  test loss 1.687083, test error 67.32
# Epoch   700, train loss 1.845923, train error 71.00,  test loss 1.684506, test error 67.78
# Epoch   800, train loss 1.842065, train error 70.43,  test loss 1.686932, test error 67.03
# Epoch   900, train loss 1.843584, train error 70.47,  test loss 1.695867, test error 67.45
# Training model with   4 hidden variables
# Epoch     0, train loss 2.301329, train error 88.68,  test loss 2.299675, test error 88.22
# Epoch   100, train loss 1.785771, train error 66.75,  test loss 1.630596, test error 64.03
# Epoch   200, train loss 1.769614, train error 66.05,  test loss 1.628152, test error 63.50
# Epoch   300, train loss 1.756738, train error 65.25,  test loss 1.626079, test error 62.92
# Epoch   400, train loss 1.753126, train error 64.97,  test loss 1.621653, test error 62.50
# Epoch   500, train loss 1.757383, train error 66.35,  test loss 1.613348, test error 62.83
# Epoch   600, train loss 1.750719, train error 65.85,  test loss 1.614178, test error 62.60
# Epoch   700, train loss 1.750556, train error 66.22,  test loss 1.611212, test error 62.72
# Epoch   800, train loss 1.749703, train error 65.50,  test loss 1.621723, test error 62.72
# Epoch   900, train loss 1.751675, train error 64.95,  test loss 1.628185, test error 62.62
# Training model with   6 hidden variables
# Epoch     0, train loss 2.185392, train error 82.30,  test loss 2.153341, test error 81.28
# Epoch   100, train loss 1.750968, train error 63.95,  test loss 1.600505, test error 63.22
# Epoch   200, train loss 1.691782, train error 60.60,  test loss 1.551642, test error 60.15
# Epoch   300, train loss 1.671997, train error 60.22,  test loss 1.534313, test error 60.08
# Epoch   400, train loss 1.663278, train error 59.97,  test loss 1.545681, test error 60.67
# Epoch   500, train loss 1.646232, train error 57.88,  test loss 1.511654, test error 58.17
# Epoch   600, train loss 1.629941, train error 57.30,  test loss 1.492991, test error 57.30
# Epoch   700, train loss 1.632471, train error 57.47,  test loss 1.492471, test error 57.85
# Epoch   800, train loss 1.628334, train error 57.17,  test loss 1.484761, test error 57.30
# Epoch   900, train loss 1.623571, train error 57.70,  test loss 1.488637, test error 57.45
# Training model with   8 hidden variables
# Epoch     0, train loss 2.214133, train error 83.15,  test loss 2.197609, test error 82.10
# Epoch   100, train loss 1.564184, train error 53.35,  test loss 1.397704, test error 52.78
# Epoch   200, train loss 1.516926, train error 52.10,  test loss 1.369918, test error 51.47
# Epoch   300, train loss 1.485265, train error 51.90,  test loss 1.339448, test error 50.67
# Epoch   400, train loss 1.474344, train error 50.70,  test loss 1.336319, test error 49.42
# Epoch   500, train loss 1.459451, train error 49.85,  test loss 1.312119, test error 48.60
# Epoch   600, train loss 1.452133, train error 49.25,  test loss 1.318918, test error 48.78
# Epoch   700, train loss 1.443256, train error 48.75,  test loss 1.305136, test error 48.12
# Epoch   800, train loss 1.439742, train error 49.17,  test loss 1.316138, test error 48.33
# Epoch   900, train loss 1.436934, train error 49.05,  test loss 1.313519, test error 48.25
# Training model with  10 hidden variables
# Epoch     0, train loss 2.246877, train error 83.70,  test loss 2.233821, test error 83.00
# Epoch   100, train loss 1.653647, train error 57.55,  test loss 1.508326, test error 56.75
# Epoch   200, train loss 1.593263, train error 55.03,  test loss 1.487650, test error 56.10
# Epoch   300, train loss 1.558422, train error 53.95,  test loss 1.455814, test error 55.53
# Epoch   400, train loss 1.540715, train error 53.10,  test loss 1.451341, test error 54.55
# Epoch   500, train loss 1.530890, train error 52.10,  test loss 1.448446, test error 54.35
# Epoch   600, train loss 1.527469, train error 52.28,  test loss 1.462692, test error 54.45
# Epoch   700, train loss 1.522396, train error 52.15,  test loss 1.454116, test error 54.70
# Epoch   800, train loss 1.512500, train error 52.03,  test loss 1.451792, test error 54.45
# Epoch   900, train loss 1.509296, train error 52.03,  test loss 1.457351, test error 54.35
# Training model with  14 hidden variables
# Epoch     0, train loss 2.233931, train error 82.50,  test loss 2.231716, test error 82.85
# Epoch   100, train loss 1.459021, train error 49.62,  test loss 1.359273, test error 51.15
# Epoch   200, train loss 1.363292, train error 46.78,  test loss 1.333825, test error 48.90
# Epoch   300, train loss 1.300995, train error 44.60,  test loss 1.314639, test error 48.05
# Epoch   400, train loss 1.275165, train error 43.62,  test loss 1.343215, test error 47.88
# Epoch   500, train loss 1.252870, train error 42.12,  test loss 1.351060, test error 48.20
# Epoch   600, train loss 1.244253, train error 42.10,  test loss 1.363401, test error 48.25
# Epoch   700, train loss 1.234713, train error 40.97,  test loss 1.379410, test error 48.33
# Epoch   800, train loss 1.235370, train error 41.70,  test loss 1.390580, test error 48.33
# Epoch   900, train loss 1.230546, train error 41.38,  test loss 1.385939, test error 48.70
# Training model with  18 hidden variables
# Epoch     0, train loss 2.195236, train error 80.10,  test loss 2.158795, test error 80.20
# Epoch   100, train loss 1.317188, train error 43.80,  test loss 1.259346, test error 46.88
# Epoch   200, train loss 1.227927, train error 40.92,  test loss 1.270800, test error 47.60
# Epoch   300, train loss 1.178983, train error 38.53,  test loss 1.324205, test error 48.28
# Epoch   400, train loss 1.161426, train error 38.38,  test loss 1.370193, test error 48.33
# Epoch   500, train loss 1.142078, train error 38.50,  test loss 1.388267, test error 49.17
# Epoch   600, train loss 1.128090, train error 37.60,  test loss 1.406996, test error 49.08
# Epoch   700, train loss 1.121549, train error 37.30,  test loss 1.427107, test error 48.95
# Epoch   800, train loss 1.114028, train error 36.92,  test loss 1.450304, test error 49.25
# Epoch   900, train loss 1.110070, train error 37.12,  test loss 1.459146, test error 48.75
# Training model with  22 hidden variables
# Epoch     0, train loss 2.227065, train error 82.47,  test loss 2.221830, test error 81.90
# Epoch   100, train loss 1.326217, train error 44.67,  test loss 1.389948, test error 51.85
# Epoch   200, train loss 1.210667, train error 40.97,  test loss 1.435623, test error 51.88
# Epoch   300, train loss 1.147901, train error 39.50,  test loss 1.504761, test error 52.72
# Epoch   400, train loss 1.110608, train error 38.03,  test loss 1.565197, test error 52.75
# Epoch   500, train loss 1.092599, train error 37.58,  test loss 1.596421, test error 52.53
# Epoch   600, train loss 1.077710, train error 37.50,  test loss 1.650437, test error 53.00
# Epoch   700, train loss 1.074994, train error 37.22,  test loss 1.720692, test error 53.80
# Epoch   800, train loss 1.038763, train error 36.05,  test loss 1.725269, test error 53.65
# Epoch   900, train loss 1.043909, train error 36.55,  test loss 1.800293, test error 54.65
# Training model with  26 hidden variables
# Epoch     0, train loss 2.169846, train error 80.07,  test loss 2.157511, test error 80.03
# Epoch   100, train loss 1.203279, train error 39.60,  test loss 1.307063, test error 47.45
# Epoch   200, train loss 1.060659, train error 35.15,  test loss 1.427023, test error 50.38
# Epoch   300, train loss 0.991199, train error 33.75,  test loss 1.537234, test error 50.95
# Epoch   400, train loss 0.946328, train error 31.57,  test loss 1.619439, test error 51.30
# Epoch   500, train loss 0.909052, train error 30.32,  test loss 1.695879, test error 51.45
# Epoch   600, train loss 0.884069, train error 29.60,  test loss 1.789965, test error 52.30
# Epoch   700, train loss 0.882880, train error 29.97,  test loss 1.934068, test error 53.53
# Epoch   800, train loss 0.850339, train error 28.78,  test loss 1.971317, test error 53.85
# Epoch   900, train loss 0.854934, train error 30.03,  test loss 2.079334, test error 54.28
# Training model with  30 hidden variables
# Epoch     0, train loss 2.096042, train error 77.85,  test loss 2.036989, test error 77.20
# Epoch   100, train loss 1.115240, train error 36.62,  test loss 1.342527, test error 47.50
# Epoch   200, train loss 0.923477, train error 30.93,  test loss 1.532778, test error 50.72
# Epoch   300, train loss 0.816631, train error 26.53,  test loss 1.723755, test error 51.42
# Epoch   400, train loss 0.768105, train error 25.75,  test loss 1.966709, test error 53.40
# Epoch   500, train loss 0.741510, train error 25.05,  test loss 2.110196, test error 53.50
# Epoch   600, train loss 0.748713, train error 25.03,  test loss 2.242543, test error 54.83
# Epoch   700, train loss 0.686825, train error 22.85,  test loss 2.304860, test error 53.75
# Epoch   800, train loss 0.683879, train error 23.00,  test loss 2.515839, test error 55.95
# Epoch   900, train loss 0.676226, train error 22.70,  test loss 2.546569, test error 54.88
# Training model with  35 hidden variables
# Epoch     0, train loss 2.082020, train error 77.43,  test loss 2.043156, test error 78.32
# Epoch   100, train loss 1.035122, train error 34.45,  test loss 1.355319, test error 48.30
# Epoch   200, train loss 0.812190, train error 25.93,  test loss 1.660337, test error 51.60
# Epoch   300, train loss 0.676342, train error 22.22,  test loss 1.973897, test error 53.47
# Epoch   400, train loss 0.627165, train error 20.30,  test loss 2.301282, test error 54.12
# Epoch   500, train loss 0.561482, train error 19.47,  test loss 2.620604, test error 55.08
# Epoch   600, train loss 0.509880, train error 17.50,  test loss 2.924514, test error 55.47
# Epoch   700, train loss 0.482840, train error 16.68,  test loss 3.242153, test error 56.88
# Epoch   800, train loss 0.458479, train error 15.50,  test loss 3.537651, test error 56.62
# Epoch   900, train loss 0.487105, train error 17.28,  test loss 3.781131, test error 56.40
# Training model with  40 hidden variables
# Epoch     0, train loss 2.120639, train error 78.40,  test loss 2.099832, test error 78.22
# Epoch   100, train loss 0.914800, train error 29.25,  test loss 1.480930, test error 51.47
# Epoch   200, train loss 0.649359, train error 20.62,  test loss 2.056603, test error 55.58
# Epoch   300, train loss 0.525044, train error 16.88,  test loss 2.694979, test error 56.25
# Epoch   400, train loss 0.454316, train error 14.80,  test loss 3.262650, test error 56.05
# Epoch   500, train loss 0.374573, train error 11.85,  test loss 3.880230, test error 56.88
# Epoch   600, train loss 0.374863, train error 12.82,  test loss 4.598288, test error 58.22
# Epoch   700, train loss 0.378625, train error 13.00,  test loss 5.304478, test error 58.45
# Epoch   800, train loss 0.314727, train error 11.45,  test loss 5.794883, test error 57.35
# Epoch   900, train loss 0.271207, train error 9.57,  test loss 6.444524, test error 58.10
# Training model with  45 hidden variables
# Epoch     0, train loss 2.100634, train error 77.80,  test loss 2.037404, test error 76.18
# Epoch   100, train loss 0.783736, train error 25.20,  test loss 1.511967, test error 50.47
# Epoch   200, train loss 0.480587, train error 15.85,  test loss 2.375330, test error 54.17
# Epoch   300, train loss 0.296172, train error 9.95,  test loss 3.505821, test error 55.62
# Epoch   400, train loss 0.216775, train error 7.22,  test loss 4.947120, test error 56.60
# Epoch   500, train loss 0.181931, train error 6.47,  test loss 6.240797, test error 57.42
# Epoch   600, train loss 0.021006, train error 0.00,  test loss 7.595928, test error 56.90
# Epoch   700, train loss 0.012297, train error 0.00,  test loss 8.539171, test error 57.40
# Epoch   800, train loss 0.008167, train error 0.00,  test loss 9.172896, test error 57.12
# Epoch   900, train loss 0.006244, train error 0.00,  test loss 9.693411, test error 57.28
# Training model with  50 hidden variables
# Epoch     0, train loss 2.087769, train error 77.32,  test loss 2.034604, test error 76.00
# Epoch   100, train loss 0.731216, train error 22.80,  test loss 1.545682, test error 49.58
# Epoch   200, train loss 0.369551, train error 10.50,  test loss 2.468946, test error 53.00
# Epoch   300, train loss 0.183921, train error 4.80,  test loss 3.950860, test error 53.97
# Epoch   400, train loss 0.045729, train error 0.10,  test loss 5.512031, test error 55.25
# Epoch   500, train loss 0.017908, train error 0.00,  test loss 6.652945, test error 55.22
# Epoch   600, train loss 0.010903, train error 0.00,  test loss 7.400395, test error 55.28
# Epoch   700, train loss 0.007444, train error 0.00,  test loss 7.952843, test error 55.33
# Epoch   800, train loss 0.005674, train error 0.00,  test loss 8.386543, test error 55.50
# Epoch   900, train loss 0.004504, train error 0.00,  test loss 8.739191, test error 55.53
# Training model with  55 hidden variables
# Epoch     0, train loss 2.048356, train error 77.15,  test loss 1.983814, test error 75.95
# Epoch   100, train loss 0.623118, train error 19.75,  test loss 1.653430, test error 50.90
# Epoch   200, train loss 0.220805, train error 5.28,  test loss 2.946350, test error 53.72
# Epoch   300, train loss 0.041648, train error 0.03,  test loss 4.617520, test error 54.12
# Epoch   400, train loss 0.015090, train error 0.00,  test loss 5.667252, test error 54.28
# Epoch   500, train loss 0.008555, train error 0.00,  test loss 6.268677, test error 54.42
# Epoch   600, train loss 0.005734, train error 0.00,  test loss 6.706011, test error 54.30
# Epoch   700, train loss 0.004285, train error 0.00,  test loss 7.042332, test error 54.28
# Epoch   800, train loss 0.003379, train error 0.00,  test loss 7.318392, test error 54.20
# Epoch   900, train loss 0.002765, train error 0.00,  test loss 7.546769, test error 54.10
# Training model with  60 hidden variables
# Epoch     0, train loss 2.093946, train error 76.57,  test loss 2.054713, test error 78.18
# Epoch   100, train loss 0.537847, train error 15.45,  test loss 1.783769, test error 51.58
# Epoch   200, train loss 0.109388, train error 1.38,  test loss 3.602043, test error 55.08
# Epoch   300, train loss 0.019184, train error 0.00,  test loss 5.036983, test error 55.25
# Epoch   400, train loss 0.009317, train error 0.00,  test loss 5.771431, test error 55.22
# Epoch   500, train loss 0.005915, train error 0.00,  test loss 6.247163, test error 55.28
# Epoch   600, train loss 0.004219, train error 0.00,  test loss 6.604152, test error 55.58
# Epoch   700, train loss 0.003265, train error 0.00,  test loss 6.878610, test error 55.65
# Epoch   800, train loss 0.002614, train error 0.00,  test loss 7.113533, test error 55.58
# Epoch   900, train loss 0.002175, train error 0.00,  test loss 7.310244, test error 55.75
# Training model with  70 hidden variables
# Epoch     0, train loss 2.051219, train error 77.03,  test loss 2.005663, test error 74.93
# Epoch   100, train loss 0.371882, train error 9.35,  test loss 1.943775, test error 52.80
# Epoch   200, train loss 0.032896, train error 0.00,  test loss 3.578959, test error 54.22
# Epoch   300, train loss 0.011273, train error 0.00,  test loss 4.386680, test error 54.45
# Epoch   400, train loss 0.006276, train error 0.00,  test loss 4.822273, test error 54.28
# Epoch   500, train loss 0.004203, train error 0.00,  test loss 5.138663, test error 54.65
# Epoch   600, train loss 0.003114, train error 0.00,  test loss 5.375349, test error 54.62
# Epoch   700, train loss 0.002444, train error 0.00,  test loss 5.567459, test error 54.58
# Epoch   800, train loss 0.001998, train error 0.00,  test loss 5.725000, test error 54.53
# Epoch   900, train loss 0.001679, train error 0.00,  test loss 5.865924, test error 54.67
# Training model with  80 hidden variables
# Epoch     0, train loss 2.026174, train error 75.53,  test loss 1.954266, test error 74.90
# Epoch   100, train loss 0.223503, train error 3.82,  test loss 2.124298, test error 52.88
# Epoch   200, train loss 0.019532, train error 0.00,  test loss 3.431206, test error 53.15
# Epoch   300, train loss 0.007864, train error 0.00,  test loss 3.967041, test error 53.12
# Epoch   400, train loss 0.004696, train error 0.00,  test loss 4.288863, test error 53.25
# Epoch   500, train loss 0.003256, train error 0.00,  test loss 4.519227, test error 53.28
# Epoch   600, train loss 0.002455, train error 0.00,  test loss 4.695679, test error 53.17
# Epoch   700, train loss 0.001954, train error 0.00,  test loss 4.842206, test error 53.58
# Epoch   800, train loss 0.001612, train error 0.00,  test loss 4.961163, test error 53.53
# Epoch   900, train loss 0.001364, train error 0.00,  test loss 5.068521, test error 53.60
# Training model with  90 hidden variables
# Epoch     0, train loss 2.021841, train error 74.93,  test loss 1.977003, test error 75.12
# Epoch   100, train loss 0.127955, train error 1.00,  test loss 2.187803, test error 52.67
# Epoch   200, train loss 0.013756, train error 0.00,  test loss 3.181112, test error 52.67
# Epoch   300, train loss 0.006177, train error 0.00,  test loss 3.590492, test error 52.88
# Epoch   400, train loss 0.003789, train error 0.00,  test loss 3.842091, test error 52.65
# Epoch   500, train loss 0.002675, train error 0.00,  test loss 4.026898, test error 52.75
# Epoch   600, train loss 0.002041, train error 0.00,  test loss 4.168450, test error 52.88
# Epoch   700, train loss 0.001633, train error 0.00,  test loss 4.286852, test error 52.75
# Epoch   800, train loss 0.001354, train error 0.00,  test loss 4.386851, test error 52.58
# Epoch   900, train loss 0.001151, train error 0.00,  test loss 4.474770, test error 52.60
# Training model with 100 hidden variables
# Epoch     0, train loss 1.971369, train error 74.10,  test loss 1.893362, test error 73.18
# Epoch   100, train loss 0.089862, train error 0.25,  test loss 2.260010, test error 52.00
# Epoch   200, train loss 0.011928, train error 0.00,  test loss 3.111812, test error 52.20
# Epoch   300, train loss 0.005621, train error 0.00,  test loss 3.480215, test error 52.20
# Epoch   400, train loss 0.003512, train error 0.00,  test loss 3.712390, test error 52.12
# Epoch   500, train loss 0.002501, train error 0.00,  test loss 3.879072, test error 52.12
# Epoch   600, train loss 0.001919, train error 0.00,  test loss 4.010484, test error 52.00
# Epoch   700, train loss 0.001544, train error 0.00,  test loss 4.118826, test error 52.08
# Epoch   800, train loss 0.001283, train error 0.00,  test loss 4.209314, test error 52.05
# Epoch   900, train loss 0.001094, train error 0.00,  test loss 4.290234, test error 52.00
# Training model with 120 hidden variables
# Epoch     0, train loss 1.982759, train error 72.97,  test loss 1.924548, test error 75.28
# Epoch   100, train loss 0.052443, train error 0.03,  test loss 2.228585, test error 49.83
# Epoch   200, train loss 0.009753, train error 0.00,  test loss 2.863113, test error 49.65
# Epoch   300, train loss 0.004824, train error 0.00,  test loss 3.145217, test error 49.70
# Epoch   400, train loss 0.003077, train error 0.00,  test loss 3.328223, test error 49.95
# Epoch   500, train loss 0.002216, train error 0.00,  test loss 3.462546, test error 50.03
# Epoch   600, train loss 0.001711, train error 0.00,  test loss 3.569791, test error 50.05
# Epoch   700, train loss 0.001383, train error 0.00,  test loss 3.658959, test error 50.12
# Epoch   800, train loss 0.001153, train error 0.00,  test loss 3.734158, test error 50.05
# Epoch   900, train loss 0.000985, train error 0.00,  test loss 3.799350, test error 50.12
# Training model with 140 hidden variables
# Epoch     0, train loss 1.934693, train error 71.72,  test loss 1.880784, test error 72.18
# Epoch   100, train loss 0.038394, train error 0.00,  test loss 2.133238, test error 48.75
# Epoch   200, train loss 0.008191, train error 0.00,  test loss 2.625394, test error 48.72
# Epoch   300, train loss 0.004183, train error 0.00,  test loss 2.855675, test error 48.88
# Epoch   400, train loss 0.002715, train error 0.00,  test loss 3.007447, test error 49.05
# Epoch   500, train loss 0.001976, train error 0.00,  test loss 3.119639, test error 49.03
# Epoch   600, train loss 0.001535, train error 0.00,  test loss 3.209524, test error 49.05
# Epoch   700, train loss 0.001246, train error 0.00,  test loss 3.282126, test error 48.97
# Epoch   800, train loss 0.001043, train error 0.00,  test loss 3.345269, test error 48.95
# Epoch   900, train loss 0.000893, train error 0.00,  test loss 3.399990, test error 48.88
# Training model with 160 hidden variables
# Epoch     0, train loss 1.923344, train error 70.53,  test loss 1.878802, test error 72.45
# Epoch   100, train loss 0.028845, train error 0.00,  test loss 2.229072, test error 49.75
# Epoch   200, train loss 0.007203, train error 0.00,  test loss 2.669150, test error 49.70
# Epoch   300, train loss 0.003799, train error 0.00,  test loss 2.887274, test error 49.60
# Epoch   400, train loss 0.002498, train error 0.00,  test loss 3.030110, test error 49.53
# Epoch   500, train loss 0.001827, train error 0.00,  test loss 3.136358, test error 49.50
# Epoch   600, train loss 0.001427, train error 0.00,  test loss 3.221894, test error 49.47
# Epoch   700, train loss 0.001163, train error 0.00,  test loss 3.294140, test error 49.55
# Epoch   800, train loss 0.000976, train error 0.00,  test loss 3.355067, test error 49.53
# Epoch   900, train loss 0.000837, train error 0.00,  test loss 3.408617, test error 49.50
# Training model with 180 hidden variables
# Epoch     0, train loss 1.916359, train error 70.22,  test loss 1.836542, test error 72.90
# Epoch   100, train loss 0.024652, train error 0.00,  test loss 1.968461, test error 48.00
# Epoch   200, train loss 0.006641, train error 0.00,  test loss 2.308425, test error 47.65
# Epoch   300, train loss 0.003554, train error 0.00,  test loss 2.477761, test error 47.45
# Epoch   400, train loss 0.002357, train error 0.00,  test loss 2.590445, test error 47.35
# Epoch   500, train loss 0.001733, train error 0.00,  test loss 2.676176, test error 47.33
# Epoch   600, train loss 0.001358, train error 0.00,  test loss 2.743843, test error 47.40
# Epoch   700, train loss 0.001109, train error 0.00,  test loss 2.800735, test error 47.42
# Epoch   800, train loss 0.000932, train error 0.00,  test loss 2.849666, test error 47.50
# Epoch   900, train loss 0.000802, train error 0.00,  test loss 2.892274, test error 47.53
# Training model with 200 hidden variables
# Epoch     0, train loss 1.922711, train error 71.22,  test loss 1.835591, test error 71.18
# Epoch   100, train loss 0.021703, train error 0.00,  test loss 2.002317, test error 46.97
# Epoch   200, train loss 0.006190, train error 0.00,  test loss 2.318021, test error 47.33
# Epoch   300, train loss 0.003341, train error 0.00,  test loss 2.481077, test error 47.30
# Epoch   400, train loss 0.002228, train error 0.00,  test loss 2.590827, test error 47.35
# Epoch   500, train loss 0.001644, train error 0.00,  test loss 2.672259, test error 47.28
# Epoch   600, train loss 0.001291, train error 0.00,  test loss 2.739317, test error 47.38
# Epoch   700, train loss 0.001056, train error 0.00,  test loss 2.794483, test error 47.35
# Epoch   800, train loss 0.000889, train error 0.00,  test loss 2.841448, test error 47.40
# Epoch   900, train loss 0.000765, train error 0.00,  test loss 2.883037, test error 47.35
# Training model with 250 hidden variables
# Epoch     0, train loss 1.870751, train error 66.70,  test loss 1.818384, test error 69.03
# Epoch   100, train loss 0.016737, train error 0.00,  test loss 1.918124, test error 47.15
# Epoch   200, train loss 0.005279, train error 0.00,  test loss 2.171750, test error 47.10
# Epoch   300, train loss 0.002948, train error 0.00,  test loss 2.305732, test error 47.05
# Epoch   400, train loss 0.001993, train error 0.00,  test loss 2.397677, test error 46.97
# Epoch   500, train loss 0.001483, train error 0.00,  test loss 2.468105, test error 46.92
# Epoch   600, train loss 0.001171, train error 0.00,  test loss 2.523951, test error 46.92
# Epoch   700, train loss 0.000962, train error 0.00,  test loss 2.572013, test error 46.90
# Epoch   800, train loss 0.000812, train error 0.00,  test loss 2.612417, test error 46.83
# Epoch   900, train loss 0.000701, train error 0.00,  test loss 2.648432, test error 46.88
# Training model with 300 hidden variables
# Epoch     0, train loss 1.894413, train error 68.72,  test loss 1.837843, test error 70.22
# Epoch   100, train loss 0.014534, train error 0.00,  test loss 1.811236, test error 45.97
# Epoch   200, train loss 0.004853, train error 0.00,  test loss 2.023715, test error 46.08
# Epoch   300, train loss 0.002748, train error 0.00,  test loss 2.136459, test error 46.03
# Epoch   400, train loss 0.001870, train error 0.00,  test loss 2.214113, test error 46.03
# Epoch   500, train loss 0.001400, train error 0.00,  test loss 2.274849, test error 45.95
# Epoch   600, train loss 0.001108, train error 0.00,  test loss 2.322688, test error 45.80
# Epoch   700, train loss 0.000912, train error 0.00,  test loss 2.363948, test error 45.80
# Epoch   800, train loss 0.000772, train error 0.00,  test loss 2.398649, test error 45.88
# Epoch   900, train loss 0.000667, train error 0.00,  test loss 2.429070, test error 45.95
# Training model with 400 hidden variables
# Epoch     0, train loss 1.886847, train error 67.55,  test loss 1.815462, test error 67.95
# Epoch   100, train loss 0.011735, train error 0.00,  test loss 1.793059, test error 46.92
# Epoch   200, train loss 0.004189, train error 0.00,  test loss 1.975384, test error 46.88
# Epoch   300, train loss 0.002428, train error 0.00,  test loss 2.077024, test error 46.62
# Epoch   400, train loss 0.001673, train error 0.00,  test loss 2.147586, test error 46.35
# Epoch   500, train loss 0.001261, train error 0.00,  test loss 2.201970, test error 46.25
# Epoch   600, train loss 0.001004, train error 0.00,  test loss 2.245978, test error 46.33
# Epoch   700, train loss 0.000829, train error 0.00,  test loss 2.282815, test error 46.28
# Epoch   800, train loss 0.000704, train error 0.00,  test loss 2.314460, test error 46.30
# Epoch   900, train loss 0.000610, train error 0.00,  test loss 2.342342, test error 46.40

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
