# %% [markdown]
# ### 🎮 Environments:
#
# - [SpacesInvadersNoFrameskip-v4](https://gymnasium.farama.org/environments/atari/space_invaders/)
#
# You can see the difference between Space Invaders versions here 👉 https://gymnasium.farama.org/environments/atari/space_invaders/#variants
#
# ### 📚 RL-Library:
#
# - [RL-Baselines3-Zoo](https://github.com/DLR-RM/rl-baselines3-zoo)

# %%
# For now we install this update of RL-Baselines3 Zoo
# !pip install git+https://github.com/DLR-RM/rl-baselines3-zoo@update/hf
# Out:
# Collecting git+https://github.com/DLR-RM/rl-baselines3-zoo@update/hf
#   Cloning https://github.com/DLR-RM/rl-baselines3-zoo (to revision update/hf) to /tmp/pip-req-build-ivxaobz6
#   Running command git clone --filter=blob:none --quiet https://github.com/DLR-RM/rl-baselines3-zoo /tmp/pip-req-build-ivxaobz6
#   Running command git checkout -b update/hf --track origin/update/hf
#   Switched to a new branch 'update/hf'
#   Branch 'update/hf' set up to track remote branch 'update/hf' from 'origin'.
#   Resolved https://github.com/DLR-RM/rl-baselines3-zoo to commit 7dcbff7e74e7a12c052452181ff353a4dbed313a
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting sb3-contrib>=2.0.0a9 (from rl_zoo3==2.0.0a9)
#   Downloading sb3_contrib-2.3.0a1-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 3.1 MB/s eta 0:00:00
# Collecting gym==0.26.2 (from rl_zoo3==2.0.0a9)
#   Downloading gym-0.26.2.tar.gz (721 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.7/721.7 kB 14.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting huggingface-sb3>=2.2.1 (from rl_zoo3==2.0.0a9)
#   Downloading huggingface_sb3-3.0-py3-none-any.whl (9.7 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from rl_zoo3==2.0.0a9) (4.66.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from rl_zoo3==2.0.0a9) (13.7.0)
# Collecting optuna (from rl_zoo3==2.0.0a9)
#   Downloading optuna-3.5.0-py3-none-any.whl (413 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.4/413.4 kB 17.3 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from rl_zoo3==2.0.0a9) (6.0.1)
# Collecting pytablewriter~=0.64 (from rl_zoo3==2.0.0a9)
#   Downloading pytablewriter-0.64.2-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.6/106.6 kB 15.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym==0.26.2->rl_zoo3==2.0.0a9) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym==0.26.2->rl_zoo3==2.0.0a9) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym==0.26.2->rl_zoo3==2.0.0a9) (0.0.8)
# Requirement already satisfied: huggingface-hub~=0.8 in /usr/local/lib/python3.10/dist-packages (from huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (0.20.3)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.10/dist-packages (from huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (1.1.2)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.10/dist-packages (from pytablewriter~=0.64->rl_zoo3==2.0.0a9) (67.7.2)
# Collecting DataProperty<2,>=0.55.0 (from pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Downloading DataProperty-1.0.1-py3-none-any.whl (27 kB)
# Collecting mbstrdecoder<2,>=1.0.0 (from pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Downloading mbstrdecoder-1.1.3-py3-none-any.whl (7.8 kB)
# Collecting pathvalidate<3,>=2.3.0 (from pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Downloading pathvalidate-2.5.2-py3-none-any.whl (20 kB)
# Collecting tabledata<2,>=1.3.0 (from pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Downloading tabledata-1.3.3-py3-none-any.whl (11 kB)
# Collecting tcolorpy<1,>=0.0.5 (from pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Downloading tcolorpy-0.1.4-py3-none-any.whl (7.9 kB)
# Collecting typepy[datetime]<2,>=1.2.0 (from pytablewriter~=0.64->rl_zoo3==2.0.0a9)
#   Downloading typepy-1.3.2-py3-none-any.whl (31 kB)
# Collecting stable-baselines3<3.0,>=2.3.0a0 (from sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9)
#   Downloading stable_baselines3-2.3.0a1-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.7/181.7 kB 12.9 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna->rl_zoo3==2.0.0a9)
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 15.8 MB/s eta 0:00:00
# Collecting colorlog (from optuna->rl_zoo3==2.0.0a9)
#   Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna->rl_zoo3==2.0.0a9) (23.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna->rl_zoo3==2.0.0a9) (2.0.24)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->rl_zoo3==2.0.0a9) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->rl_zoo3==2.0.0a9) (2.16.1)
# Collecting Mako (from alembic>=1.5.0->optuna->rl_zoo3==2.0.0a9)
#   Downloading Mako-1.3.0-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna->rl_zoo3==2.0.0a9) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (2.31.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->rl_zoo3==2.0.0a9) (0.1.2)
# Requirement already satisfied: chardet<6,>=3.0.4 in /usr/local/lib/python3.10/dist-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter~=0.64->rl_zoo3==2.0.0a9) (5.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna->rl_zoo3==2.0.0a9) (3.0.3)
# Collecting gymnasium<0.30,>=0.28.1 (from stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9)
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 21.4 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (2.1.0+cu121)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (3.7.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl_zoo3==2.0.0a9) (2.8.2)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.10/dist-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl_zoo3==2.0.0a9) (2023.3.post1)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.8.0->typepy[datetime]<2,>=1.2.0->pytablewriter~=0.64->rl_zoo3==2.0.0a9) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (2.1.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna->rl_zoo3==2.0.0a9) (2.1.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface-sb3>=2.2.1->rl_zoo3==2.0.0a9) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3<3.0,>=2.3.0a0->sb3-contrib>=2.0.0a9->rl_zoo3==2.0.0a9) (1.3.0)
# Building wheels for collected packages: rl_zoo3, gym
#   Building wheel for rl_zoo3 (pyproject.toml) ... done
#   Created wheel for rl_zoo3: filename=rl_zoo3-2.0.0a9-py3-none-any.whl size=76403 sha256=a2b220fe7a55a542b3a28c656587cb1a98c3566a733df8a53d1f163dc97f6813
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5eaoo2cz/wheels/fc/36/d5/2ef574649d85327de098075c8523da50be2612f3e5807261f7
#   Building wheel for gym (pyproject.toml) ... done
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827622 sha256=771874c3436ff1226a8e29734558b3ff9c6459a6b19d04ae1efdffe708f8f16d
#   Stored in directory: /root/.cache/pip/wheels/b9/22/6d/3e7b32d98451b4cd9d12417052affbeeeea012955d437da1da
# Successfully built rl_zoo3 gym
# Installing collected packages: farama-notifications, tcolorpy, pathvalidate, mbstrdecoder, Mako, gymnasium, gym, colorlog, typepy, alembic, stable-baselines3, optuna, huggingface-sb3, sb3-contrib, DataProperty, tabledata, pytablewriter, rl_zoo3
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.0.6 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
# Successfully installed DataProperty-1.0.1 Mako-1.3.0 alembic-1.13.1 colorlog-6.8.2 farama-notifications-0.0.4 gym-0.26.2 gymnasium-0.29.1 huggingface-sb3-3.0 mbstrdecoder-1.1.3 optuna-3.5.0 pathvalidate-2.5.2 pytablewriter-0.64.2 rl_zoo3-2.0.0a9 sb3-contrib-2.3.0a1 stable-baselines3-2.3.0a1 tabledata-1.3.3 tcolorpy-0.1.4 typepy-1.3.2

# %%
# !apt-get install swig cmake ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.1).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 31 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 1s (1,611 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 121671 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %% [markdown]
# To be able to use Atari games in Gymnasium we need to install atari package. And accept-rom-license to download the rom files (games files).

# %%
# !pip install gymnasium[atari]
# !pip install gymnasium[accept-rom-license]
# Out:
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (0.0.4)
# Collecting shimmy[atari]<1.0,>=0.1.0 (from gymnasium[atari])
#   Downloading Shimmy-0.2.1-py3-none-any.whl (25 kB)
# Collecting ale-py~=0.8.1 (from shimmy[atari]<1.0,>=0.1.0->gymnasium[atari])
#   Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]<1.0,>=0.1.0->gymnasium[atari]) (6.1.1)
# Installing collected packages: ale-py, shimmy
# Successfully installed ale-py-0.8.1 shimmy-0.2.1
# Requirement already satisfied: gymnasium[accept-rom-license] in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[accept-rom-license]) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[accept-rom-license]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[accept-rom-license]) (4.5.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium[accept-rom-license]) (0.0.4)
# Collecting autorom[accept-rom-license]~=0.4.2 (from gymnasium[accept-rom-license])
#   Downloading AutoROM-0.4.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (8.1.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (4.66.1)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 11.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.4.2->gymnasium[accept-rom-license]) (2023.11.17)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446660 sha256=88c55b94ab4ea0914954a264536ff9746d26598ba6bacedc64b9a3be9c8fcba6
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: AutoROM.accept-rom-license, autorom
# Successfully installed AutoROM.accept-rom-license-0.6.1 autorom-0.4.2

# %% [markdown]
# ## Create a virtual display 🔽
#
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install the librairies and create and run a virtual screen 🖥

# %%
# %%capture
# !apt install python-opengl
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ## Train our Deep Q-Learning Agent to Play Space Invaders 👾
#
# To train an agent with RL-Baselines3-Zoo, we just need to do two things:
#
# 1. Create a hyperparameter config file that will contain our training hyperparameters called `dqn.yml`.
#
# This is a template example:
#
# ```
# SpaceInvadersNoFrameskip-v4:
#   env_wrapper:
#     - stable_baselines3.common.atari_wrappers.AtariWrapper
#   frame_stack: 4
#   policy: 'CnnPolicy'
#   n_timesteps: !!float 1e6
#   buffer_size: 100000
#   learning_rate: !!float 1e-4
#   batch_size: 32
#   learning_starts: 100000
#   target_update_interval: 1000
#   train_freq: 4
#   gradient_steps: 1
#   exploration_fraction: 0.1
#   exploration_final_eps: 0.01
#   # If True, you need to deactivate handle_timeout_termination
#   # in the replay_buffer_kwargs
#   optimize_memory_usage: False
# ```

# %% [markdown]
# Here we see that:
# - We use the `Atari Wrapper` that preprocess the input (Frame reduction ,grayscale, stack 4 frames)
# - We use `CnnPolicy`, since we use Convolutional layers to process the frames
# - We train it for 10 million `n_timesteps`
# - Memory (Experience Replay) size is 100000, aka the amount of experience steps you saved to train again your agent with.
#
# 💡 My advice is to **reduce the training timesteps to 1M,** which will take about 90 minutes on a P100. `!nvidia-smi` will tell you what GPU you're using. At 10 million steps, this will take about 9 hours, which could likely result in Colab timing out. I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# In terms of hyperparameters optimization, my advice is to focus on these 3 hyperparameters:
# - `learning_rate`
# - `buffer_size (Experience Memory size)`
# - `batch_size`
#
# As a good practice, you need to **check the documentation to understand what each hyperparameters does**: https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html#parameters

# %% [markdown]
# 2. We start the training and save the models on `logs` folder 📁
#
# - Define the algorithm after `--algo`, where we save the model after `-f` and where the hyperparameter config is after `-c`.

# %%
# !python -m rl_zoo3.train --algo dqn --env SpaceInvadersNoFrameskip-v4  -f logs/  -c /content/dqn.yml
# Out:
# Streaming output truncated to the last 5000 lines.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 421      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2580     |
# |    fps              | 278      |
# |    time_elapsed     | 1890     |
# |    total_timesteps  | 527216   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0267   |
# |    n_updates        | 106803   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 422      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2584     |
# |    fps              | 278      |
# |    time_elapsed     | 1894     |
# |    total_timesteps  | 528256   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0108   |
# |    n_updates        | 107063   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 420      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2588     |
# |    fps              | 278      |
# |    time_elapsed     | 1897     |
# |    total_timesteps  | 529014   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0204   |
# |    n_updates        | 107253   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 421      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2592     |
# |    fps              | 278      |
# |    time_elapsed     | 1900     |
# |    total_timesteps  | 529924   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0244   |
# |    n_updates        | 107480   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 415      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2596     |
# |    fps              | 278      |
# |    time_elapsed     | 1906     |
# |    total_timesteps  | 531456   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0213   |
# |    n_updates        | 107863   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 414      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2600     |
# |    fps              | 278      |
# |    time_elapsed     | 1911     |
# |    total_timesteps  | 532954   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.047    |
# |    n_updates        | 108238   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 419      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2604     |
# |    fps              | 278      |
# |    time_elapsed     | 1914     |
# |    total_timesteps  | 533721   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0095   |
# |    n_updates        | 108430   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 420      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2608     |
# |    fps              | 278      |
# |    time_elapsed     | 1918     |
# |    total_timesteps  | 534689   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0131   |
# |    n_updates        | 108672   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 417      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2612     |
# |    fps              | 278      |
# |    time_elapsed     | 1923     |
# |    total_timesteps  | 536004   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0166   |
# |    n_updates        | 109000   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 418      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2616     |
# |    fps              | 278      |
# |    time_elapsed     | 1926     |
# |    total_timesteps  | 536918   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0253   |
# |    n_updates        | 109229   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 419      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2620     |
# |    fps              | 278      |
# |    time_elapsed     | 1931     |
# |    total_timesteps  | 538292   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0346   |
# |    n_updates        | 109572   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 414      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2624     |
# |    fps              | 278      |
# |    time_elapsed     | 1935     |
# |    total_timesteps  | 539273   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0288   |
# |    n_updates        | 109818   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 412      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2628     |
# |    fps              | 278      |
# |    time_elapsed     | 1939     |
# |    total_timesteps  | 540208   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0471   |
# |    n_updates        | 110051   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 413      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2632     |
# |    fps              | 278      |
# |    time_elapsed     | 1943     |
# |    total_timesteps  | 541341   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0154   |
# |    n_updates        | 110335   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 409      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2636     |
# |    fps              | 278      |
# |    time_elapsed     | 1948     |
# |    total_timesteps  | 542568   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.036    |
# |    n_updates        | 110641   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 404      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2640     |
# |    fps              | 278      |
# |    time_elapsed     | 1951     |
# |    total_timesteps  | 543332   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0292   |
# |    n_updates        | 110832   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 398      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2644     |
# |    fps              | 278      |
# |    time_elapsed     | 1954     |
# |    total_timesteps  | 544249   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.043    |
# |    n_updates        | 111062   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 390      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2648     |
# |    fps              | 278      |
# |    time_elapsed     | 1958     |
# |    total_timesteps  | 545410   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0222   |
# |    n_updates        | 111352   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 391      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2652     |
# |    fps              | 278      |
# |    time_elapsed     | 1961     |
# |    total_timesteps  | 546209   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0245   |
# |    n_updates        | 111552   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 390      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2656     |
# |    fps              | 278      |
# |    time_elapsed     | 1967     |
# |    total_timesteps  | 547651   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0239   |
# |    n_updates        | 111912   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 391      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2660     |
# |    fps              | 278      |
# |    time_elapsed     | 1970     |
# |    total_timesteps  | 548727   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.015    |
# |    n_updates        | 112181   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 389      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2664     |
# |    fps              | 278      |
# |    time_elapsed     | 1975     |
# |    total_timesteps  | 549974   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0392   |
# |    n_updates        | 112493   |
# ----------------------------------
# Eval num_timesteps=550000, episode_reward=307.00 +/- 77.37
# Episode length: 3293.40 +/- 376.84
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.29e+03 |
# |    mean_reward      | 307      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 550000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0221   |
# |    n_updates        | 112499   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 396      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2668     |
# |    fps              | 277      |
# |    time_elapsed     | 1991     |
# |    total_timesteps  | 551693   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0198   |
# |    n_updates        | 112923   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 399      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2672     |
# |    fps              | 276      |
# |    time_elapsed     | 1997     |
# |    total_timesteps  | 553239   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0187   |
# |    n_updates        | 113309   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 397      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2676     |
# |    fps              | 277      |
# |    time_elapsed     | 2001     |
# |    total_timesteps  | 554519   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0268   |
# |    n_updates        | 113629   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 400      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2680     |
# |    fps              | 277      |
# |    time_elapsed     | 2004     |
# |    total_timesteps  | 555246   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0124   |
# |    n_updates        | 113811   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 400      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2684     |
# |    fps              | 276      |
# |    time_elapsed     | 2009     |
# |    total_timesteps  | 556695   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0298   |
# |    n_updates        | 114173   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 400      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2688     |
# |    fps              | 276      |
# |    time_elapsed     | 2014     |
# |    total_timesteps  | 557896   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0266   |
# |    n_updates        | 114473   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 400      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2692     |
# |    fps              | 276      |
# |    time_elapsed     | 2019     |
# |    total_timesteps  | 559349   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0197   |
# |    n_updates        | 114837   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 398      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2696     |
# |    fps              | 276      |
# |    time_elapsed     | 2024     |
# |    total_timesteps  | 560606   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0381   |
# |    n_updates        | 115151   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 404      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2700     |
# |    fps              | 276      |
# |    time_elapsed     | 2027     |
# |    total_timesteps  | 561672   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0154   |
# |    n_updates        | 115417   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.16e+03 |
# |    ep_rew_mean      | 407      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2704     |
# |    fps              | 276      |
# |    time_elapsed     | 2032     |
# |    total_timesteps  | 562835   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0162   |
# |    n_updates        | 115708   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 410      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2708     |
# |    fps              | 276      |
# |    time_elapsed     | 2036     |
# |    total_timesteps  | 564044   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0124   |
# |    n_updates        | 116010   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.19e+03 |
# |    ep_rew_mean      | 410      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2712     |
# |    fps              | 276      |
# |    time_elapsed     | 2045     |
# |    total_timesteps  | 566186   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0412   |
# |    n_updates        | 116546   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.21e+03 |
# |    ep_rew_mean      | 414      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2716     |
# |    fps              | 276      |
# |    time_elapsed     | 2048     |
# |    total_timesteps  | 567225   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0236   |
# |    n_updates        | 116806   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 417      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2720     |
# |    fps              | 276      |
# |    time_elapsed     | 2055     |
# |    total_timesteps  | 568890   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0411   |
# |    n_updates        | 117222   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 418      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2724     |
# |    fps              | 276      |
# |    time_elapsed     | 2057     |
# |    total_timesteps  | 569508   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0221   |
# |    n_updates        | 117376   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.24e+03 |
# |    ep_rew_mean      | 421      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2728     |
# |    fps              | 276      |
# |    time_elapsed     | 2063     |
# |    total_timesteps  | 571073   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0627   |
# |    n_updates        | 117768   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 416      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2732     |
# |    fps              | 276      |
# |    time_elapsed     | 2068     |
# |    total_timesteps  | 572315   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0202   |
# |    n_updates        | 118078   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 415      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2736     |
# |    fps              | 276      |
# |    time_elapsed     | 2071     |
# |    total_timesteps  | 573321   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0107   |
# |    n_updates        | 118330   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.22e+03 |
# |    ep_rew_mean      | 414      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2740     |
# |    fps              | 276      |
# |    time_elapsed     | 2075     |
# |    total_timesteps  | 574554   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0257   |
# |    n_updates        | 118638   |
# ----------------------------------
# Eval num_timesteps=575000, episode_reward=378.00 +/- 197.55
# Episode length: 2861.60 +/- 930.27
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.86e+03 |
# |    mean_reward      | 378      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 575000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0498   |
# |    n_updates        | 118749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.25e+03 |
# |    ep_rew_mean      | 418      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2744     |
# |    fps              | 275      |
# |    time_elapsed     | 2088     |
# |    total_timesteps  | 575791   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.03     |
# |    n_updates        | 118947   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 419      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2748     |
# |    fps              | 275      |
# |    time_elapsed     | 2092     |
# |    total_timesteps  | 577014   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0293   |
# |    n_updates        | 119253   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.27e+03 |
# |    ep_rew_mean      | 421      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2752     |
# |    fps              | 275      |
# |    time_elapsed     | 2098     |
# |    total_timesteps  | 578679   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0121   |
# |    n_updates        | 119669   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.3e+03  |
# |    ep_rew_mean      | 426      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2756     |
# |    fps              | 275      |
# |    time_elapsed     | 2103     |
# |    total_timesteps  | 580002   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0238   |
# |    n_updates        | 120000   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.31e+03 |
# |    ep_rew_mean      | 428      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2760     |
# |    fps              | 275      |
# |    time_elapsed     | 2108     |
# |    total_timesteps  | 581376   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0399   |
# |    n_updates        | 120343   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.31e+03 |
# |    ep_rew_mean      | 429      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2764     |
# |    fps              | 275      |
# |    time_elapsed     | 2114     |
# |    total_timesteps  | 582869   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0503   |
# |    n_updates        | 120717   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.35e+03 |
# |    ep_rew_mean      | 436      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2768     |
# |    fps              | 275      |
# |    time_elapsed     | 2118     |
# |    total_timesteps  | 583937   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0391   |
# |    n_updates        | 120984   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.34e+03 |
# |    ep_rew_mean      | 433      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2772     |
# |    fps              | 275      |
# |    time_elapsed     | 2122     |
# |    total_timesteps  | 585143   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0105   |
# |    n_updates        | 121285   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.34e+03 |
# |    ep_rew_mean      | 435      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2776     |
# |    fps              | 275      |
# |    time_elapsed     | 2125     |
# |    total_timesteps  | 585841   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0224   |
# |    n_updates        | 121460   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.36e+03 |
# |    ep_rew_mean      | 433      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2780     |
# |    fps              | 275      |
# |    time_elapsed     | 2130     |
# |    total_timesteps  | 587358   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0181   |
# |    n_updates        | 121839   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.35e+03 |
# |    ep_rew_mean      | 435      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2784     |
# |    fps              | 275      |
# |    time_elapsed     | 2135     |
# |    total_timesteps  | 588588   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0287   |
# |    n_updates        | 122146   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.35e+03 |
# |    ep_rew_mean      | 430      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2788     |
# |    fps              | 275      |
# |    time_elapsed     | 2140     |
# |    total_timesteps  | 589992   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0421   |
# |    n_updates        | 122497   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.37e+03 |
# |    ep_rew_mean      | 436      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2792     |
# |    fps              | 275      |
# |    time_elapsed     | 2144     |
# |    total_timesteps  | 590831   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0645   |
# |    n_updates        | 122707   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.39e+03 |
# |    ep_rew_mean      | 436      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2796     |
# |    fps              | 275      |
# |    time_elapsed     | 2148     |
# |    total_timesteps  | 591976   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0297   |
# |    n_updates        | 122993   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.37e+03 |
# |    ep_rew_mean      | 434      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2800     |
# |    fps              | 275      |
# |    time_elapsed     | 2152     |
# |    total_timesteps  | 593195   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 123298   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.38e+03 |
# |    ep_rew_mean      | 432      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2804     |
# |    fps              | 275      |
# |    time_elapsed     | 2157     |
# |    total_timesteps  | 594458   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0272   |
# |    n_updates        | 123614   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.38e+03 |
# |    ep_rew_mean      | 433      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2808     |
# |    fps              | 275      |
# |    time_elapsed     | 2163     |
# |    total_timesteps  | 596001   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 124000   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.39e+03 |
# |    ep_rew_mean      | 431      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2812     |
# |    fps              | 275      |
# |    time_elapsed     | 2166     |
# |    total_timesteps  | 597054   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0161   |
# |    n_updates        | 124263   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.38e+03 |
# |    ep_rew_mean      | 433      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2816     |
# |    fps              | 275      |
# |    time_elapsed     | 2169     |
# |    total_timesteps  | 597877   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0119   |
# |    n_updates        | 124469   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.39e+03 |
# |    ep_rew_mean      | 436      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2820     |
# |    fps              | 275      |
# |    time_elapsed     | 2174     |
# |    total_timesteps  | 598989   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0281   |
# |    n_updates        | 124747   |
# ----------------------------------
# Eval num_timesteps=600000, episode_reward=405.00 +/- 154.18
# Episode length: 3921.80 +/- 832.20
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.92e+03 |
# |    mean_reward      | 405      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 600000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0124   |
# |    n_updates        | 124999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.39e+03 |
# |    ep_rew_mean      | 437      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2824     |
# |    fps              | 274      |
# |    time_elapsed     | 2189     |
# |    total_timesteps  | 600231   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0745   |
# |    n_updates        | 125057   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.39e+03 |
# |    ep_rew_mean      | 441      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2828     |
# |    fps              | 274      |
# |    time_elapsed     | 2193     |
# |    total_timesteps  | 601322   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0182   |
# |    n_updates        | 125330   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.41e+03 |
# |    ep_rew_mean      | 444      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2832     |
# |    fps              | 274      |
# |    time_elapsed     | 2198     |
# |    total_timesteps  | 602734   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0575   |
# |    n_updates        | 125683   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.38e+03 |
# |    ep_rew_mean      | 437      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2836     |
# |    fps              | 274      |
# |    time_elapsed     | 2202     |
# |    total_timesteps  | 603653   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0124   |
# |    n_updates        | 125913   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.4e+03  |
# |    ep_rew_mean      | 442      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2840     |
# |    fps              | 274      |
# |    time_elapsed     | 2206     |
# |    total_timesteps  | 605058   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0615   |
# |    n_updates        | 126264   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.4e+03  |
# |    ep_rew_mean      | 443      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2844     |
# |    fps              | 274      |
# |    time_elapsed     | 2211     |
# |    total_timesteps  | 606221   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0296   |
# |    n_updates        | 126555   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.38e+03 |
# |    ep_rew_mean      | 438      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2848     |
# |    fps              | 274      |
# |    time_elapsed     | 2213     |
# |    total_timesteps  | 606926   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0696   |
# |    n_updates        | 126731   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.38e+03 |
# |    ep_rew_mean      | 436      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2852     |
# |    fps              | 274      |
# |    time_elapsed     | 2218     |
# |    total_timesteps  | 608092   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0158   |
# |    n_updates        | 127022   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.4e+03  |
# |    ep_rew_mean      | 436      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2856     |
# |    fps              | 274      |
# |    time_elapsed     | 2222     |
# |    total_timesteps  | 609109   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0314   |
# |    n_updates        | 127277   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.4e+03  |
# |    ep_rew_mean      | 434      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2860     |
# |    fps              | 274      |
# |    time_elapsed     | 2225     |
# |    total_timesteps  | 610163   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0386   |
# |    n_updates        | 127540   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.4e+03  |
# |    ep_rew_mean      | 435      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2864     |
# |    fps              | 274      |
# |    time_elapsed     | 2230     |
# |    total_timesteps  | 611556   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0124   |
# |    n_updates        | 127888   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.44e+03 |
# |    ep_rew_mean      | 440      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2868     |
# |    fps              | 274      |
# |    time_elapsed     | 2235     |
# |    total_timesteps  | 612774   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.016    |
# |    n_updates        | 128193   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.44e+03 |
# |    ep_rew_mean      | 443      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2872     |
# |    fps              | 274      |
# |    time_elapsed     | 2239     |
# |    total_timesteps  | 613739   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0531   |
# |    n_updates        | 128434   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.46e+03 |
# |    ep_rew_mean      | 448      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2876     |
# |    fps              | 274      |
# |    time_elapsed     | 2245     |
# |    total_timesteps  | 615278   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0178   |
# |    n_updates        | 128819   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.47e+03 |
# |    ep_rew_mean      | 451      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2880     |
# |    fps              | 274      |
# |    time_elapsed     | 2250     |
# |    total_timesteps  | 616536   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0269   |
# |    n_updates        | 129133   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.49e+03 |
# |    ep_rew_mean      | 453      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2884     |
# |    fps              | 274      |
# |    time_elapsed     | 2254     |
# |    total_timesteps  | 617902   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0186   |
# |    n_updates        | 129475   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.49e+03 |
# |    ep_rew_mean      | 451      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2888     |
# |    fps              | 273      |
# |    time_elapsed     | 2259     |
# |    total_timesteps  | 619203   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0715   |
# |    n_updates        | 129800   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.49e+03 |
# |    ep_rew_mean      | 449      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2892     |
# |    fps              | 274      |
# |    time_elapsed     | 2264     |
# |    total_timesteps  | 620518   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0119   |
# |    n_updates        | 130129   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.49e+03 |
# |    ep_rew_mean      | 450      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2896     |
# |    fps              | 273      |
# |    time_elapsed     | 2270     |
# |    total_timesteps  | 621953   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0479   |
# |    n_updates        | 130488   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.49e+03 |
# |    ep_rew_mean      | 450      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2900     |
# |    fps              | 273      |
# |    time_elapsed     | 2275     |
# |    total_timesteps  | 623446   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0197   |
# |    n_updates        | 130861   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.48e+03 |
# |    ep_rew_mean      | 448      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2904     |
# |    fps              | 273      |
# |    time_elapsed     | 2278     |
# |    total_timesteps  | 624184   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0116   |
# |    n_updates        | 131045   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.47e+03 |
# |    ep_rew_mean      | 445      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2908     |
# |    fps              | 273      |
# |    time_elapsed     | 2281     |
# |    total_timesteps  | 624913   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0295   |
# |    n_updates        | 131228   |
# ----------------------------------
# Eval num_timesteps=625000, episode_reward=308.00 +/- 61.69
# Episode length: 3110.20 +/- 779.96
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.11e+03 |
# |    mean_reward      | 308      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 625000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00997  |
# |    n_updates        | 131249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.5e+03  |
# |    ep_rew_mean      | 451      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2912     |
# |    fps              | 272      |
# |    time_elapsed     | 2298     |
# |    total_timesteps  | 627079   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0244   |
# |    n_updates        | 131769   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.49e+03 |
# |    ep_rew_mean      | 451      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2916     |
# |    fps              | 272      |
# |    time_elapsed     | 2302     |
# |    total_timesteps  | 628177   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0232   |
# |    n_updates        | 132044   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.49e+03 |
# |    ep_rew_mean      | 452      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2920     |
# |    fps              | 272      |
# |    time_elapsed     | 2304     |
# |    total_timesteps  | 628793   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0301   |
# |    n_updates        | 132198   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.51e+03 |
# |    ep_rew_mean      | 455      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2924     |
# |    fps              | 272      |
# |    time_elapsed     | 2310     |
# |    total_timesteps  | 630418   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0213   |
# |    n_updates        | 132604   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0156   |
# |    n_updates        | 213502   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11e+03 |
# |    ep_rew_mean      | 605      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3724     |
# |    fps              | 261      |
# |    time_elapsed     | 3649     |
# |    total_timesteps  | 954870   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0587   |
# |    n_updates        | 213717   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.11e+03 |
# |    ep_rew_mean      | 605      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3728     |
# |    fps              | 261      |
# |    time_elapsed     | 3653     |
# |    total_timesteps  | 956044   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0406   |
# |    n_updates        | 214010   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.09e+03 |
# |    ep_rew_mean      | 598      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3732     |
# |    fps              | 261      |
# |    time_elapsed     | 3660     |
# |    total_timesteps  | 958090   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0262   |
# |    n_updates        | 214522   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.12e+03 |
# |    ep_rew_mean      | 598      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3736     |
# |    fps              | 261      |
# |    time_elapsed     | 3665     |
# |    total_timesteps  | 959550   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0246   |
# |    n_updates        | 214887   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.12e+03 |
# |    ep_rew_mean      | 597      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3740     |
# |    fps              | 261      |
# |    time_elapsed     | 3672     |
# |    total_timesteps  | 961264   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0202   |
# |    n_updates        | 215315   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.12e+03 |
# |    ep_rew_mean      | 595      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3744     |
# |    fps              | 261      |
# |    time_elapsed     | 3678     |
# |    total_timesteps  | 962908   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0178   |
# |    n_updates        | 215726   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.07e+03 |
# |    ep_rew_mean      | 590      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3748     |
# |    fps              | 261      |
# |    time_elapsed     | 3684     |
# |    total_timesteps  | 964505   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0175   |
# |    n_updates        | 216126   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.07e+03 |
# |    ep_rew_mean      | 590      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3752     |
# |    fps              | 261      |
# |    time_elapsed     | 3689     |
# |    total_timesteps  | 965794   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0182   |
# |    n_updates        | 216448   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.07e+03 |
# |    ep_rew_mean      | 593      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3756     |
# |    fps              | 261      |
# |    time_elapsed     | 3695     |
# |    total_timesteps  | 967185   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0431   |
# |    n_updates        | 216796   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.09e+03 |
# |    ep_rew_mean      | 592      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3760     |
# |    fps              | 261      |
# |    time_elapsed     | 3700     |
# |    total_timesteps  | 968683   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0179   |
# |    n_updates        | 217170   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08e+03 |
# |    ep_rew_mean      | 591      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3764     |
# |    fps              | 261      |
# |    time_elapsed     | 3706     |
# |    total_timesteps  | 970340   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0313   |
# |    n_updates        | 217584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.08e+03 |
# |    ep_rew_mean      | 589      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3768     |
# |    fps              | 261      |
# |    time_elapsed     | 3714     |
# |    total_timesteps  | 972540   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0106   |
# |    n_updates        | 218134   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06e+03 |
# |    ep_rew_mean      | 588      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3772     |
# |    fps              | 261      |
# |    time_elapsed     | 3721     |
# |    total_timesteps  | 974576   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0396   |
# |    n_updates        | 218643   |
# ----------------------------------
# Eval num_timesteps=975000, episode_reward=678.00 +/- 172.99
# Episode length: 4021.00 +/- 717.87
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 4.02e+03 |
# |    mean_reward      | 678      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 975000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0156   |
# |    n_updates        | 218749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4e+03    |
# |    ep_rew_mean      | 580      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3776     |
# |    fps              | 261      |
# |    time_elapsed     | 3739     |
# |    total_timesteps  | 976354   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.038    |
# |    n_updates        | 219088   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.01e+03 |
# |    ep_rew_mean      | 582      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3780     |
# |    fps              | 261      |
# |    time_elapsed     | 3745     |
# |    total_timesteps  | 978187   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00861  |
# |    n_updates        | 219546   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.01e+03 |
# |    ep_rew_mean      | 585      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3784     |
# |    fps              | 261      |
# |    time_elapsed     | 3749     |
# |    total_timesteps  | 979222   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0112   |
# |    n_updates        | 219805   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | 586      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3788     |
# |    fps              | 261      |
# |    time_elapsed     | 3757     |
# |    total_timesteps  | 981379   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0672   |
# |    n_updates        | 220344   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | 584      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3792     |
# |    fps              | 261      |
# |    time_elapsed     | 3763     |
# |    total_timesteps  | 982827   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0165   |
# |    n_updates        | 220706   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | 583      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3796     |
# |    fps              | 261      |
# |    time_elapsed     | 3767     |
# |    total_timesteps  | 984027   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0189   |
# |    n_updates        | 221006   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02e+03 |
# |    ep_rew_mean      | 586      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3800     |
# |    fps              | 261      |
# |    time_elapsed     | 3774     |
# |    total_timesteps  | 985956   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0429   |
# |    n_updates        | 221488   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | 588      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3804     |
# |    fps              | 261      |
# |    time_elapsed     | 3780     |
# |    total_timesteps  | 987781   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0163   |
# |    n_updates        | 221945   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4e+03    |
# |    ep_rew_mean      | 585      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3808     |
# |    fps              | 261      |
# |    time_elapsed     | 3783     |
# |    total_timesteps  | 988499   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0104   |
# |    n_updates        | 222124   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.02e+03 |
# |    ep_rew_mean      | 589      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3812     |
# |    fps              | 261      |
# |    time_elapsed     | 3790     |
# |    total_timesteps  | 990373   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0225   |
# |    n_updates        | 222593   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | 588      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3816     |
# |    fps              | 261      |
# |    time_elapsed     | 3796     |
# |    total_timesteps  | 991924   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0333   |
# |    n_updates        | 222980   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | 589      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3820     |
# |    fps              | 261      |
# |    time_elapsed     | 3802     |
# |    total_timesteps  | 993345   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0235   |
# |    n_updates        | 223336   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.03e+03 |
# |    ep_rew_mean      | 588      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3824     |
# |    fps              | 261      |
# |    time_elapsed     | 3808     |
# |    total_timesteps  | 995275   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0347   |
# |    n_updates        | 223818   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05e+03 |
# |    ep_rew_mean      | 587      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3828     |
# |    fps              | 261      |
# |    time_elapsed     | 3816     |
# |    total_timesteps  | 997211   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0212   |
# |    n_updates        | 224302   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.05e+03 |
# |    ep_rew_mean      | 589      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3832     |
# |    fps              | 261      |
# |    time_elapsed     | 3825     |
# |    total_timesteps  | 999624   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0201   |
# |    n_updates        | 224905   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=494.00 +/- 33.23
# Episode length: 3861.80 +/- 269.91
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.86e+03 |
# |    mean_reward      | 494      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0175   |
# |    n_updates        | 224999   |
# ----------------------------------
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_1

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/

# %% [markdown]
# By using `rl_zoo3.push_to_hub` **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉  https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">

# %% [markdown]
# - Copy the token
# - Run the cell below and past the token

# %%
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
notebook_login()
# !git config --global credential.helper store
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥

# %% [markdown]
# Let's run push_to_hub.py file to upload our trained agent to the Hub.
#
# `--repo-name `: The name of the repo
#
# `-orga`: Your Hugging Face username
#
# `-f`: Where the trained model folder is (in our case `logs`)
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/select-id.png" alt="Select Id">

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4 -orga vadhri -f logs/
# Out:
# 2024-01-27 06:18:53.146629: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-27 06:18:53.146680: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-27 06:18:53.148540: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-27 06:18:53.159427: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-27 06:18:54.682477: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Loading latest experiment, id=1
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_1/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Uploading to vadhri/dqn-SpaceInvadersNoFrameskip-v4, make sure to have the rights
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to some
# minutes if video generation is activated. This is a work in progress: if you
# encounter a bug, please open an issue.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'Repository' (from 'huggingface_hub.repository') is deprecated and will be removed from version '1.0'. Please prefer the http-based alternatives instead. Given its large adoption in legacy code, the complete removal is only planned on next major release.
# For more details, please read https://huggingface.co/docs/huggingface_hub/concepts/git_vs_http.
#   warnings.warn(warning_message, FutureWarning)
# Cloning https://huggingface.co/vadhri/dqn-SpaceInvadersNoFrameskip-v4 into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/vadhri/dqn-SpaceInvadersNoFrameskip-v4 into local empty directory.
# Saving model to: hub/dqn-SpaceInvadersNoFrameskip-v4/dqn-SpaceInvadersNoFrameskip-v4
# /usr/local/lib/python3.10/dist-packages/gymnasium/utils/passive_env_checker.py:335: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# Saving video to /tmp/tmp4vk6zwvl/-step-0-to-step-1000.mp4
# Moviepy - Building video /tmp/tmp4vk6zwvl/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /tmp/tmp4vk6zwvl/-step-0-to-step-1000.mp4
#
# Moviepy - Done !
# Moviepy - video ready /tmp/tmp4vk6zwvl/-step-0-to-step-1000.mp4
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/tmp/tmp4vk6zwvl/-step-0-to-step-1000.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:33.40, start: 0.000000, bitrate: 59 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 160x210, 56 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5c24b2dc8740] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5c24b2dc8740] profile High, level 1.2, 4:2:0, 8-bit
# [libx264 @ 0x5c24b2dc8740] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'hub/dqn-SpaceInvadersNoFrameskip-v4/replay.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 160x210, q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame= 1002 fps=0.0 q=-1.0 Lsize=     236kB time=00:00:33.30 bitrate=  58.1kbits/s speed=40.5x
# video:225kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 5.067670%
# [libx264 @ 0x5c24b2dc8740] frame I:5     Avg QP:16.74  size:  3829
# [libx264 @ 0x5c24b2dc8740] frame P:445   Avg QP:22.55  size:   412
# [libx264 @ 0x5c24b2dc8740] frame B:552   Avg QP:28.74  size:    49
# [libx264 @ 0x5c24b2dc8740] consecutive B-frames: 20.2% 17.2%  6.0% 56.7%
# [libx264 @ 0x5c24b2dc8740] mb I  I16..4: 23.7% 29.4% 46.9%
# [libx264 @ 0x5c24b2dc8740] mb P  I16..4:  0.5%  1.0%  1.0%  P16..4:  7.9%  3.1%  2.1%  0.0%  0.0%    skip:84.4%
# [libx264 @ 0x5c24b2dc8740] mb B  I16..4:  0.2%  0.1%  0.1%  B16..8:  9.7%  0.8%  0.0%  direct: 0.1%  skip:88.9%  L0:51.5% L1:48.1% BI: 0.4%
# [libx264 @ 0x5c24b2dc8740] 8x8 transform intra:36.8% inter:6.2%
# [libx264 @ 0x5c24b2dc8740] coded y,uvDC,uvAC intra: 26.0% 44.0% 41.6% inter: 1.5% 2.1% 1.8%
# [libx264 @ 0x5c24b2dc8740] i16 v,h,dc,p: 51% 44%  5%  0%
# [libx264 @ 0x5c24b2dc8740] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 10% 65%  2%  0%  0%  0%  0%  0%
# [libx264 @ 0x5c24b2dc8740] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 33% 12% 41%  3%  2%  3%  2%  3%  2%
# [libx264 @ 0x5c24b2dc8740] i8c dc,h,v,p: 50% 33% 15%  2%
# [libx264 @ 0x5c24b2dc8740] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5c24b2dc8740] ref P L0: 76.2%  6.0%  9.5%  8.3%
# [libx264 @ 0x5c24b2dc8740] ref B L0: 84.4% 12.2%  3.4%
# [libx264 @ 0x5c24b2dc8740] ref B L1: 96.1%  3.9%
# [libx264 @ 0x5c24b2dc8740] kb/s:54.95
# ℹ Pushing repo dqn-SpaceInvadersNoFrameskip-v4 to the Hugging Face
# Hub
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:   0% 1.00/26.0M [00:00<?, ?B/s]
# Upload file replay.mp4:   0% 1.00/236k [00:00<?, ?B/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:   0% 1.00/12.9M [00:00<?, ?B/s]
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth:   0% 1.00/864 [00:00<?, ?B/s]
#
#
#
# Upload file train_eval_metrics.zip:   0% 1.00/35.8k [00:00<?, ?B/s]
#
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:   0% 1.00/12.9M [00:00<?, ?B/s]
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 15.3MB [00:01, 16.0MB/s]
#
#
#
# Upload file train_eval_metrics.zip: 15.3MB [00:01, 16.0MB/s]
# Upload file replay.mp4: 15.3MB [00:01, 16.0MB/s]
#
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:  59% 15.3M/26.0M [00:01<00:00, 16.0MB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip: 30.5MB [00:02, 16.0MB/s]                To https://huggingface.co/vadhri/dqn-SpaceInvadersNoFrameskip-v4
#    90c65b4..566d8e7  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/vadhri/dqn-SpaceInvadersNoFrameskip-v4
#    90c65b4..566d8e7  main -> main
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip: 100% 26.0M/26.0M [00:03<00:00, 9.06MB/s]
#
# Upload file replay.mp4: 100% 236k/236k [00:03<00:00, 80.5kB/s]
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth: 100% 12.9M/12.9M [00:03<00:00, 4.50MB/s]
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 100% 864/864 [00:03<00:00, 287B/s]
#
#
#
#
# Upload file train_eval_metrics.zip: 100% 35.8k/35.8k [00:03<00:00, 12.2kB/s]
#
#
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 100% 12.9M/12.9M [00:03<00:00, 4.50MB/s]
# ℹ Your model is pushed to the hub. You can view your model here:
# https://huggingface.co/vadhri/dqn-SpaceInvadersNoFrameskip-v4

# %% [markdown]
# ###.
