# %%
# !git clone --depth 1 https://github.com/Unity-Technologies/ml-agents
# Out:
# Cloning into 'ml-agents'...
# remote: Enumerating objects: 2386, done.
# remote: Counting objects: 100% (2386/2386), done.
# remote: Compressing objects: 100% (1902/1902), done.
# remote: Total 2386 (delta 901), reused 1227 (delta 465), pack-reused 0
# Receiving objects: 100% (2386/2386), 97.66 MiB | 15.68 MiB/s, done.
# Resolving deltas: 100% (901/901), done.
# Updating files: 100% (2215/2215), done.

# %%
# %cd ../ml-agents-envs
# !pip3 install -e .
# Out:
# /content/ml-agents/ml-agents-envs
# WARNING: Ignoring invalid distribution -orch (/usr/local/lib/python3.10/dist-packages)
# Obtaining file:///content/ml-agents/ml-agents-envs
#   Preparing metadata (setup.py) ... done
#   WARNING: Ignoring invalid distribution -orch (/usr/local/lib/python3.10/dist-packages)
# ...
# WARNING: Ignoring invalid distribution -orch (/usr/local/lib/python3.10/dist-packages)
# ...
#   Attempting uninstall: mlagents-envs
#     WARNING: Ignoring invalid distribution -orch (/usr/local/lib/python3.10/dist-packages)
#     Found existing installation: mlagents-envs 1.1.0.dev0
#     Uninstalling mlagents-envs-1.1.0.dev0:
#       Successfully uninstalled mlagents-envs-1.1.0.dev0
#   Running setup.py develop for mlagents-envs
# WARNING: Ignoring invalid distribution -orch (/usr/local/lib/python3.10/dist-packages)
# WARNING: Ignoring invalid distribution -orch (/usr/local/lib/python3.10/dist-packages)
# ...

# %%
# !git lfs install
# Out:
# Updated git hooks.
# Git LFS initialized.

# %% [markdown]
# ---

# %%
# !mkdir ./training-envs-executables
# !mkdir ./training-envs-executables/linux

# %%
# !wget "https://drive.google.com/file/d/1KuqBKYiXiIcU4kNMqEzhgypuFP5_45CL/view?usp=sharing" -O ./training-envs-executables/linux/SoccerTwos.zip
# Out:
# --2024-02-20 08:49:10--  https://drive.google.com/file/d/1KuqBKYiXiIcU4kNMqEzhgypuFP5_45CL/view?usp=sharing
# Resolving drive.google.com (drive.google.com)... 142.251.175.138, 142.251.175.113, 142.251.175.102, ...
# Connecting to drive.google.com (drive.google.com)|142.251.175.138|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘./training-envs-executables/linux/SoccerTwos.zip’
#
# ./training-envs-exe     [ <=>                ]  83.16K  --.-KB/s    in 0.02s
#
# 2024-02-20 08:49:11 (3.79 MB/s) - ‘./training-envs-executables/linux/SoccerTwos.zip’ saved [85156]

# %%
# %%capture
# !unzip -d ./training-envs-executables/linux/ ./training-envs-executables/linux/SoccerTwos.zip

# %%
# !chmod -R 755 /content/ml-agents/ml-agents/training-envs-executables/linux/SoccerTwos.x86_64

# %%
# %cd /content/ml-agents/
# !mlagents-learn ./config/poca/SoccerTwos.yaml --env=/content/ml-agents/ml-agents/training-envs-executables/linux/SoccerTwos.x86_64 --run-id="SoccerTwos" --no-graphics --force
# Out:
# /content/ml-agents
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py:690: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:451.)
#   _C._set_default_tensor_type(t)
#
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
# ...

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
# !mlagents-push-to-hf  --run-id="SoccerTwos" --local-dir="./results/SoccerTwos" --repo-id="vadhri/poca-SoccerTwos" --commit-message="First Push"
# !mlagents-push-to-hf --run-id="SnowballTarget1" --local-dir="./results/SnowballTarget1" --repo-id="vadhri/snowball-target" --commit-message="First Push"
