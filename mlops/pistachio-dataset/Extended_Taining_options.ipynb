# %% [markdown]
# <a href="https://colab.research.google.com/github/vadhri/ai-notebook/blob/main/mlops/pistachio-dataset/Extended_Taining_options.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The explanation fo the results for the tail end case using random forest is as below.
#
# [Wandb report](https://wandb.ai/vadhri-venkat/pistachio-classification/reports/Parameter-optimization--VmlldzoxMjI2NjY3Ng?accessToken=qdxrp7pn1hf3t5bb027c70hp6owkwqn3s4a8h1e346766q13nm7uwvawsczv1qo8)

# %%
# %%writefile train.py

import argparse
import wandb
import pandas as pd
import numpy as np
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import accuracy_score
from fastai.vision.all import *

from sklearn.model_selection import StratifiedKFold
import pandas as pd
import wandb
from pathlib import Path

# Defaults for sweep overrides or direct usage
default_config = SimpleNamespace(
    loss_function="log_loss",
    learning_rate="optimal",
    num_iterations=1000,
    log_interval=100,
    wandb_project="pistachio-classification",
    wandb_run_name="data-partioning-model-eval",
    use_wandb=True
)

def parse_args():
    """Override default arguments"""
    parser = argparse.ArgumentParser(description="SGD classifier training script")
    parser.add_argument("--loss_function", type=str, default=default_config.loss_function)
    parser.add_argument("--learning_rate", type=str, default=default_config.learning_rate)
    parser.add_argument("--num_iterations", type=int, default=default_config.num_iterations)
    parser.add_argument("--log_interval", type=int, default=default_config.log_interval)
    parser.add_argument("--wandb_project", type=str, default=default_config.wandb_project)
    parser.add_argument("--wandb_run_name", type=str, default=default_config.wandb_run_name)
    parser.add_argument("--use_wandb", type=bool, default=default_config.use_wandb)
    args = parser.parse_args()
    vars(default_config).update(vars(args))
    return

def load_data(n_splits=2):
# Check if the directory exists and download the processed dataset if not
    import os
    if not os.path.exists('./artifacts/pistachio-image-classification-data-split:v0/data_split.csv'):
        processed_data_at = wandb.use_artifact('pistachio-image-classification-data-split:latest')
        processed_dataset_dir = Path(processed_data_at.download())

    # Load the CSV with the data
    data_path = './artifacts/pistachio-image-classification-data-split:v0/data_split.csv'
    df = pd.read_csv(data_path)

    # Separate features and target variable
    X = df.drop(['Class', 'Stage'], axis=1)
    y = df['Class']

    # Initialize Stratified K-Fold
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

    # Create lists to store each fold's splits
    X_train_list = []
    y_train_list = []
    X_val_list = []
    y_val_list = []
    X_test_list = []
    y_test_list = []

    # Loop through each fold and store the splits
    for train_idx, val_idx in skf.split(X, y):
        # Get the train and validation splits for this fold
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

        # Convert y_train, y_val to NumPy arrays (flatten them if needed)
        y_train_flat = y_train.to_numpy()  # Ensure it's a 1D array
        y_val_flat = y_val.to_numpy()      # Ensure it's a 1D array

        # Test data remains constant, separate from the training/validation data
        X_test = X[df['Stage'] == 'test']
        y_test = y[df['Stage'] == 'test']
        y_test_flat = y_test.to_numpy()    # Ensure it's a 1D array

        # Append the current fold's splits to the corresponding lists as 1D arrays
        X_train_list.extend(X_train.to_numpy())  # Add each fold's X_train directly
        y_train_list.extend(y_train_flat)       # Add each fold's y_train directly
        X_val_list.extend(X_val.to_numpy())      # Add each fold's X_val directly
        y_val_list.extend(y_val_flat)           # Add each fold's y_val directly
        X_test_list.extend(X_test.to_numpy())    # Add each fold's X_test directly
        y_test_list.extend(y_test_flat)         # Add each fold's y_test directly

    # Return flattened lists (1D arrays) for all splits
    return X_train_list, y_train_list, X_val_list, y_val_list, X_test_list, y_test_list

def run_experiment(config):
    run = None
    if config.use_wandb:
        run = wandb.init(project=config.wandb_project, name=config.wandb_run_name)

    X_train, y_train, X_val, y_val, X_test, y_test = load_data()

    le = LabelEncoder()
    y_train_enc = le.fit_transform(y_train)
    y_val_enc = le.transform(y_val)
    y_test_enc = le.transform(y_test)

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)
    X_test_scaled = scaler.transform(X_test)

    classes = np.unique(y_train_enc)
    class_weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_train_enc)
    class_weight_dict = dict(zip(classes, class_weights))

    model = SGDClassifier(loss=config.loss_function, learning_rate=config.learning_rate, random_state=42, eta0=0.0001)

    results = []
    for i in range(config.num_iterations):
        model.partial_fit(X_train_scaled, y_train_enc, classes=classes)
        train_acc = accuracy_score(y_train_enc, model.predict(X_train_scaled))
        test_acc = accuracy_score(y_test_enc, model.predict(X_test_scaled))

        if i % config.log_interval == 0:
            print(f"Iteration {i+1}: Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}")

        if config.use_wandb:
            wandb.log({"iteration": i + 1, "train_accuracy": train_acc, "test_accuracy": test_acc})

        results.append({"iteration": i + 1, "train_accuracy": train_acc, "test_accuracy": test_acc})

    val_acc = accuracy_score(y_val_enc, model.predict(X_val_scaled))
    print(f"Final Validation Accuracy: {val_acc:.4f}")

    if config.use_wandb:
        wandb.log({"final_val_accuracy": val_acc})
        result_table = wandb.Table(columns=["iteration", "train_accuracy", "test_accuracy"])
        for res in results:
            result_table.add_data(res["iteration"], res["train_accuracy"], res["test_accuracy"])
        wandb.log({"training_results": result_table})
        # run.finish() # already commented out intentionally

    return {
        "model": model,
        "scaler": scaler,
        "label_encoder": le,
        "val_accuracy": val_acc,
        "training_log": results
    }

if __name__ == '__main__':
    parse_args()
    run_experiment(default_config)
# Out:
# Writing train.py

# %%
# !python train.py --learning_rate=adaptive --loss_function=modified_huber --num_iterations=500 --wandb_project "pistachio-classification" --wandb_run_name "sgd_classifier_run"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_155823-hwg7lwkk
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run sgd_classifier_run
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/hwg7lwkk
# wandb: Downloading large artifact pistachio-image-classification-data-split:latest, 233.35MB. 4190 files...
# 6a1da79d93fb9d76d6ff09676cefbf02d7ec54c5
# wandb:   4190 of 4190 files downloaded.
# Done. 0:0:35.6
# Iteration 1: Train Acc: 0.8631, Test Acc: 0.8744
# Iteration 101: Train Acc: 0.8706, Test Acc: 0.8791
# Iteration 201: Train Acc: 0.8729, Test Acc: 0.8791
# Iteration 301: Train Acc: 0.8715, Test Acc: 0.8791
# Iteration 401: Train Acc: 0.8715, Test Acc: 0.8791
# Final Validation Accuracy: 0.8724
# wandb:
# wandb: 🚀 View run sgd_classifier_run at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/hwg7lwkk
# wandb: Find logs at: wandb/run-20250413_155823-hwg7lwkk/logs

# %%
# %%writefile sweep.yaml
# program: train.py
#
# # Method can be grid, random or bayes
# method: random
#
# # Project this sweep is part of
# project: pistachio-classification
#
# # Metric to optimize
# metric:
#   name: final_val_accuracy
#   goal: maximize
#
# parameters:
#   num_iterations:
#     values: [1000, 1500, 2500]
#
#   loss:
#     values: ["log_loss", "hinge", "modified_huber"]
#
#   learning_rate:
#     values: ["constant", "optimal", "invscaling", "adaptive"]
# Out:
# Writing sweep.yaml

# %%
# !wandb login
# !wandb sweep ./sweep.yaml
# Out:
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Creating sweep from: ./sweep.yaml
# wandb: Creating sweep with ID: lsapjzjg
# wandb: View sweep at: https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/lsapjzjg
# wandb: Run sweep agent with: wandb agent vadhri-venkat/pistachio-classification/lsapjzjg

# %%
# !wandb agent vadhri-venkat/pistachio-classification/lsapjzjg --count=50
# Out:
# wandb: Starting wandb agent 🕵️
# 2025-04-13 16:00:20,765 - wandb.wandb_agent - INFO - Running runs: []
# 2025-04-13 16:00:21,104 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:00:21,104 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	learning_rate: invscaling
# 	loss: hinge
# 	num_iterations: 1500
# 2025-04-13 16:00:21,105 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --learning_rate=invscaling --loss=hinge --num_iterations=1500
# 2025-04-13 16:00:26,117 - wandb.wandb_agent - INFO - Running runs: ['bwkeew6e']
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_160030-bwkeew6e
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/lsapjzjg
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/bwkeew6e
# Iteration 1: Train Acc: 0.8561, Test Acc: 0.8651
# Iteration 101: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 201: Train Acc: 0.8571, Test Acc: 0.8744
# Iteration 301: Train Acc: 0.8571, Test Acc: 0.8744
# Iteration 401: Train Acc: 0.8566, Test Acc: 0.8744
# Iteration 501: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 601: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 701: Train Acc: 0.8575, Test Acc: 0.8651
# Iteration 801: Train Acc: 0.8580, Test Acc: 0.8698
# Iteration 901: Train Acc: 0.8575, Test Acc: 0.8698
# Iteration 1001: Train Acc: 0.8575, Test Acc: 0.8698
# Iteration 1101: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1201: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 1301: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1401: Train Acc: 0.8585, Test Acc: 0.8744
# Final Validation Accuracy: 0.8585
# wandb: 0.137 MB of 0.137 MB uploaded
# wandb:
# wandb: 0.137 MB of 0.137 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:          iteration ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      test_accuracy ▄████████████████▁▁▁▄▄▄▄▄▄▄▄▄███████████
# wandb:     train_accuracy ██▆▅▃▃▃▅▃▁▁▁▃▆███▃▅▅▆▆▆▆▅▅▅█▆███▆▆████▆▆
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.85847
# wandb:          iteration 1500
# wandb:      test_accuracy 0.87442
# wandb:     train_accuracy 0.85847
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/bwkeew6e
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_160030-bwkeew6e/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:00:46,326 - wandb.wandb_agent - INFO - Cleaning up finished run: bwkeew6e
# 2025-04-13 16:00:47,068 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:00:47,068 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	learning_rate: invscaling
# 	loss: hinge
# 	num_iterations: 2500
# 2025-04-13 16:00:47,070 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --learning_rate=invscaling --loss=hinge --num_iterations=2500
# 2025-04-13 16:00:52,081 - wandb.wandb_agent - INFO - Running runs: ['27u2lgrl']
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_160056-27u2lgrl
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/lsapjzjg
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/27u2lgrl
# Iteration 1: Train Acc: 0.8561, Test Acc: 0.8651
# Iteration 101: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 201: Train Acc: 0.8571, Test Acc: 0.8744
# Iteration 301: Train Acc: 0.8571, Test Acc: 0.8744
# Iteration 401: Train Acc: 0.8566, Test Acc: 0.8744
# Iteration 501: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 601: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 701: Train Acc: 0.8575, Test Acc: 0.8651
# Iteration 801: Train Acc: 0.8580, Test Acc: 0.8698
# Iteration 901: Train Acc: 0.8575, Test Acc: 0.8698
# Iteration 1001: Train Acc: 0.8575, Test Acc: 0.8698
# Iteration 1101: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1201: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 1301: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1401: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1501: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1601: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1701: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1801: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 1901: Train Acc: 0.8589, Test Acc: 0.8744
# Iteration 2001: Train Acc: 0.8599, Test Acc: 0.8744
# Iteration 2101: Train Acc: 0.8599, Test Acc: 0.8744
# Iteration 2201: Train Acc: 0.8603, Test Acc: 0.8744
# Iteration 2301: Train Acc: 0.8608, Test Acc: 0.8744
# Iteration 2401: Train Acc: 0.8608, Test Acc: 0.8744
# Final Validation Accuracy: 0.8608
# wandb: 0.115 MB of 0.228 MB uploaded
# wandb: 0.242 MB of 0.242 MB uploaded
# wandb:
# wandb: 0.242 MB of 0.242 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:          iteration ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      test_accuracy ▄█████████▁▁▄▄▄▄▄▄██████████████████████
# wandb:     train_accuracy ▃▄▃▂▂▁▁▁▃▄▂▃▃▃▃▃▄▃▄▃▄▄▄▃▄▄▄▄▃▅▆▆▆▇▇▇████
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.8608
# wandb:          iteration 2500
# wandb:      test_accuracy 0.87442
# wandb:     train_accuracy 0.8608
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/27u2lgrl
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_160056-27u2lgrl/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:01:22,358 - wandb.wandb_agent - INFO - Cleaning up finished run: 27u2lgrl
# 2025-04-13 16:01:22,538 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:01:22,538 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	learning_rate: invscaling
# 	loss: hinge
# 	num_iterations: 2500
# 2025-04-13 16:01:22,539 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --learning_rate=invscaling --loss=hinge --num_iterations=2500
# 2025-04-13 16:01:27,550 - wandb.wandb_agent - INFO - Running runs: ['71jumwri']
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_160130-71jumwri
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/lsapjzjg
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/71jumwri
# Iteration 1: Train Acc: 0.8561, Test Acc: 0.8651
# Iteration 101: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 201: Train Acc: 0.8571, Test Acc: 0.8744
# Iteration 301: Train Acc: 0.8571, Test Acc: 0.8744
# Iteration 401: Train Acc: 0.8566, Test Acc: 0.8744
# Iteration 501: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 601: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 701: Train Acc: 0.8575, Test Acc: 0.8651
# Iteration 801: Train Acc: 0.8580, Test Acc: 0.8698
# Iteration 901: Train Acc: 0.8575, Test Acc: 0.8698
# Iteration 1001: Train Acc: 0.8575, Test Acc: 0.8698
# Iteration 1101: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1201: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 1301: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1401: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1501: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1601: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1701: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1801: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 1901: Train Acc: 0.8589, Test Acc: 0.8744
# Iteration 2001: Train Acc: 0.8599, Test Acc: 0.8744
# Iteration 2101: Train Acc: 0.8599, Test Acc: 0.8744
# Iteration 2201: Train Acc: 0.8603, Test Acc: 0.8744
# Iteration 2301: Train Acc: 0.8608, Test Acc: 0.8744
# Iteration 2401: Train Acc: 0.8608, Test Acc: 0.8744
# Final Validation Accuracy: 0.8608
# wandb: 0.228 MB of 0.228 MB uploaded
# wandb: 0.242 MB of 0.242 MB uploaded
# wandb:
# wandb: 0.242 MB of 0.242 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:          iteration ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      test_accuracy ▄█████████▁▁▄▄▄▄▄▄██████████████████████
# wandb:     train_accuracy ▃▄▃▂▂▁▁▁▃▄▂▃▃▃▃▃▄▃▄▃▄▄▄▃▄▄▄▄▃▅▆▆▆▇▇▇████
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.8608
# wandb:          iteration 2500
# wandb:      test_accuracy 0.87442
# wandb:     train_accuracy 0.8608
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/71jumwri
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_160130-71jumwri/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:01:52,811 - wandb.wandb_agent - INFO - Cleaning up finished run: 71jumwri
# 2025-04-13 16:01:52,956 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:01:52,956 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	learning_rate: adaptive
# 	loss: log_loss
# 	num_iterations: 1000
# 2025-04-13 16:01:52,958 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --learning_rate=adaptive --loss=log_loss --num_iterations=1000
# 2025-04-13 16:01:57,974 - wandb.wandb_agent - INFO - Running runs: ['qi56bq4j']
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_160202-qi56bq4j
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/lsapjzjg
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/qi56bq4j
# Iteration 1: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 101: Train Acc: 0.8701, Test Acc: 0.8837
# Iteration 201: Train Acc: 0.8696, Test Acc: 0.8837
# Iteration 301: Train Acc: 0.8692, Test Acc: 0.8837
# Iteration 401: Train Acc: 0.8682, Test Acc: 0.8837
# Iteration 501: Train Acc: 0.8692, Test Acc: 0.8837
# Iteration 601: Train Acc: 0.8701, Test Acc: 0.8837
# Iteration 701: Train Acc: 0.8692, Test Acc: 0.8791
# Iteration 801: Train Acc: 0.8706, Test Acc: 0.8837
# Iteration 901: Train Acc: 0.8710, Test Acc: 0.8837
# Final Validation Accuracy: 0.8710
# wandb: 0.091 MB of 0.091 MB uploaded
# wandb: 0.104 MB of 0.104 MB uploaded
# wandb:
# wandb: 0.104 MB of 0.104 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:          iteration ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      test_accuracy ▁▅▃▁▅▆█▅▆▆▅▅▅▅▅▅▅▅▅▅▅▅▅▅▃▃▃▃▃▅▅▅▅▅▅▅▅▅▅▅
# wandb:     train_accuracy ▁█▆▆▇▆▇▆▇▇▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▆▆▇▇▇▇▇▇▇█████
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.87104
# wandb:          iteration 1000
# wandb:      test_accuracy 0.88372
# wandb:     train_accuracy 0.87104
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/qi56bq4j
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_160202-qi56bq4j/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:02:19,774 - wandb.wandb_agent - INFO - Cleaning up finished run: qi56bq4j
# 2025-04-13 16:02:19,945 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:02:19,945 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	learning_rate: constant
# 	loss: modified_huber
# 	num_iterations: 1500
# 2025-04-13 16:02:19,947 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --learning_rate=constant --loss=modified_huber --num_iterations=1500
# 2025-04-13 16:02:24,962 - wandb.wandb_agent - INFO - Running runs: ['ysxqqg72']
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_160228-ysxqqg72
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/lsapjzjg
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/ysxqqg72
# Iteration 1: Train Acc: 0.8631, Test Acc: 0.8744
# Iteration 101: Train Acc: 0.8706, Test Acc: 0.8791
# Iteration 201: Train Acc: 0.8729, Test Acc: 0.8791
# Iteration 301: Train Acc: 0.8715, Test Acc: 0.8791
# Iteration 401: Train Acc: 0.8715, Test Acc: 0.8791
# Iteration 501: Train Acc: 0.8724, Test Acc: 0.8791
# Iteration 601: Train Acc: 0.8743, Test Acc: 0.8791
# Iteration 701: Train Acc: 0.8748, Test Acc: 0.8791
# Iteration 801: Train Acc: 0.8748, Test Acc: 0.8791
# Iteration 901: Train Acc: 0.8743, Test Acc: 0.8791
# Iteration 1001: Train Acc: 0.8738, Test Acc: 0.8791
# Iteration 1101: Train Acc: 0.8743, Test Acc: 0.8791
# Iteration 1201: Train Acc: 0.8743, Test Acc: 0.8791
# Iteration 1301: Train Acc: 0.8752, Test Acc: 0.8837
# Iteration 1401: Train Acc: 0.8748, Test Acc: 0.8837
# Final Validation Accuracy: 0.8743
# wandb:
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:          iteration ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      test_accuracy █▅▅▅▅▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▅▅▅▅▅▅▅
# wandb:     train_accuracy ▁▁▁▅▄▄▄▄▃▄▃▄▅▄▅▅▇▇▇▇▇▇▇▇▇▇▆▆▆▇▇▇▇▇██▇▇▇▇
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.8743
# wandb:          iteration 1500
# wandb:      test_accuracy 0.88372
# wandb:     train_accuracy 0.8743
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/ysxqqg72
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_160228-ysxqqg72/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:02:45,163 - wandb.wandb_agent - INFO - Cleaning up finished run: ysxqqg72
# 2025-04-13 16:02:45,321 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:02:45,321 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	learning_rate: adaptive
# 	loss: log_loss
# 	num_iterations: 1500
# 2025-04-13 16:02:45,323 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --learning_rate=adaptive --loss=log_loss --num_iterations=1500
# 2025-04-13 16:02:50,339 - wandb.wandb_agent - INFO - Running runs: ['j0tsshb6']
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_160254-j0tsshb6
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/lsapjzjg
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/j0tsshb6
# Iteration 1: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 101: Train Acc: 0.8701, Test Acc: 0.8837
# Iteration 201: Train Acc: 0.8696, Test Acc: 0.8837
# Iteration 301: Train Acc: 0.8692, Test Acc: 0.8837
# Iteration 401: Train Acc: 0.8682, Test Acc: 0.8837
# Iteration 501: Train Acc: 0.8692, Test Acc: 0.8837
# Iteration 601: Train Acc: 0.8701, Test Acc: 0.8837
# Iteration 701: Train Acc: 0.8692, Test Acc: 0.8791
# Iteration 801: Train Acc: 0.8706, Test Acc: 0.8837
# Iteration 901: Train Acc: 0.8710, Test Acc: 0.8837
# Iteration 1001: Train Acc: 0.8710, Test Acc: 0.8837
# Iteration 1101: Train Acc: 0.8706, Test Acc: 0.8791
# Iteration 1201: Train Acc: 0.8706, Test Acc: 0.8791
# Iteration 1301: Train Acc: 0.8706, Test Acc: 0.8791
# Iteration 1401: Train Acc: 0.8715, Test Acc: 0.8791
# Final Validation Accuracy: 0.8706
# wandb:
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:          iteration ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      test_accuracy ▃▃▁▆█▅▅▅▅▅▅▅▅▅▅▅▃▃▃▃▅▅▅▅▅▅▅▅▅▃▃▃▃▃▃▃▃▃▃▃
# wandb:     train_accuracy ▁▇▅▅▆▅▅▅▅▄▄▄▅▅▆▇▅▅▅▅▇▇▇▇█▇▇▇▇▇▇▇▇▇▇▇▇██▇
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.87058
# wandb:          iteration 1500
# wandb:      test_accuracy 0.87907
# wandb:     train_accuracy 0.87058
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/j0tsshb6
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_160254-j0tsshb6/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:03:10,520 - wandb.wandb_agent - INFO - Cleaning up finished run: j0tsshb6
# 2025-04-13 16:03:10,725 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:03:10,725 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	learning_rate: invscaling
# 	loss: hinge
# 	num_iterations: 2500
# 2025-04-13 16:03:10,726 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --learning_rate=invscaling --loss=hinge --num_iterations=2500
# 2025-04-13 16:03:15,740 - wandb.wandb_agent - INFO - Running runs: ['lebmfvjt']
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_160319-lebmfvjt
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/lsapjzjg
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/lebmfvjt
# Iteration 1: Train Acc: 0.8561, Test Acc: 0.8651
# Iteration 101: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 201: Train Acc: 0.8571, Test Acc: 0.8744
# Iteration 301: Train Acc: 0.8571, Test Acc: 0.8744
# Iteration 401: Train Acc: 0.8566, Test Acc: 0.8744
# Iteration 501: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 601: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 701: Train Acc: 0.8575, Test Acc: 0.8651
# Iteration 801: Train Acc: 0.8580, Test Acc: 0.8698
# Iteration 901: Train Acc: 0.8575, Test Acc: 0.8698
# Iteration 1001: Train Acc: 0.8575, Test Acc: 0.8698
# Iteration 1101: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1201: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 1301: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1401: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1501: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1601: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1701: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1801: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 1901: Train Acc: 0.8589, Test Acc: 0.8744
# Iteration 2001: Train Acc: 0.8599, Test Acc: 0.8744
# Iteration 2101: Train Acc: 0.8599, Test Acc: 0.8744
# Iteration 2201: Train Acc: 0.8603, Test Acc: 0.8744
# Iteration 2301: Train Acc: 0.8608, Test Acc: 0.8744
# Iteration 2401: Train Acc: 0.8608, Test Acc: 0.8744
# Final Validation Accuracy: 0.8608
# wandb: 0.228 MB of 0.228 MB uploaded
# wandb:
# wandb: 0.228 MB of 0.228 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:          iteration ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      test_accuracy ▄█████████▁▁▄▄▄▄▄▄██████████████████████
# wandb:     train_accuracy ▃▄▃▂▂▁▁▁▃▄▂▃▃▃▃▃▄▃▄▃▄▄▄▃▄▄▄▄▃▅▆▆▆▇▇▇████
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.8608
# wandb:          iteration 2500
# wandb:      test_accuracy 0.87442
# wandb:     train_accuracy 0.8608
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/lebmfvjt
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_160319-lebmfvjt/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:03:40,983 - wandb.wandb_agent - INFO - Cleaning up finished run: lebmfvjt
# 2025-04-13 16:03:41,130 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:03:41,130 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	learning_rate: invscaling
# 	loss: hinge
# 	num_iterations: 2500
# 2025-04-13 16:03:41,131 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --learning_rate=invscaling --loss=hinge --num_iterations=2500
# 2025-04-13 16:03:46,142 - wandb.wandb_agent - INFO - Running runs: ['kqu0jcxd']
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_160350-kqu0jcxd
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/lsapjzjg
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/kqu0jcxd
# Iteration 1: Train Acc: 0.8561, Test Acc: 0.8651
# Iteration 101: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 201: Train Acc: 0.8571, Test Acc: 0.8744
# Iteration 301: Train Acc: 0.8571, Test Acc: 0.8744
# Iteration 401: Train Acc: 0.8566, Test Acc: 0.8744
# Iteration 501: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 601: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 701: Train Acc: 0.8575, Test Acc: 0.8651
# Iteration 801: Train Acc: 0.8580, Test Acc: 0.8698
# Iteration 901: Train Acc: 0.8575, Test Acc: 0.8698
# Iteration 1001: Train Acc: 0.8575, Test Acc: 0.8698
# Iteration 1101: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1201: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 1301: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1401: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1501: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1601: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1701: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1801: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 1901: Train Acc: 0.8589, Test Acc: 0.8744
# Iteration 2001: Train Acc: 0.8599, Test Acc: 0.8744
# Iteration 2101: Train Acc: 0.8599, Test Acc: 0.8744
# Iteration 2201: Train Acc: 0.8603, Test Acc: 0.8744
# Iteration 2301: Train Acc: 0.8608, Test Acc: 0.8744
# Iteration 2401: Train Acc: 0.8608, Test Acc: 0.8744
# Final Validation Accuracy: 0.8608
# wandb:
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:          iteration ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      test_accuracy ▄█████████▁▁▄▄▄▄▄▄██████████████████████
# wandb:     train_accuracy ▃▄▃▂▂▁▁▁▃▄▂▃▃▃▃▃▄▃▄▃▄▄▄▃▄▄▄▄▃▅▆▆▆▇▇▇████
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.8608
# wandb:          iteration 2500
# wandb:      test_accuracy 0.87442
# wandb:     train_accuracy 0.8608
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/kqu0jcxd
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_160350-kqu0jcxd/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:04:11,374 - wandb.wandb_agent - INFO - Cleaning up finished run: kqu0jcxd
# 2025-04-13 16:04:11,514 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:04:11,514 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	learning_rate: constant
# 	loss: hinge
# 	num_iterations: 2500
# 2025-04-13 16:04:11,516 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --learning_rate=constant --loss=hinge --num_iterations=2500
# 2025-04-13 16:04:16,528 - wandb.wandb_agent - INFO - Running runs: ['prkhqbvy']
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_160420-prkhqbvy
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/lsapjzjg
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/prkhqbvy
# Iteration 1: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 101: Train Acc: 0.8715, Test Acc: 0.8837
# Iteration 201: Train Acc: 0.8729, Test Acc: 0.8884
# Iteration 301: Train Acc: 0.8720, Test Acc: 0.8837
# Iteration 401: Train Acc: 0.8701, Test Acc: 0.8791
# Iteration 501: Train Acc: 0.8701, Test Acc: 0.8791
# Iteration 601: Train Acc: 0.8701, Test Acc: 0.8791
# Iteration 701: Train Acc: 0.8701, Test Acc: 0.8791
# Iteration 801: Train Acc: 0.8706, Test Acc: 0.8791
# Iteration 901: Train Acc: 0.8701, Test Acc: 0.8791
# Iteration 1001: Train Acc: 0.8706, Test Acc: 0.8791
# Iteration 1101: Train Acc: 0.8701, Test Acc: 0.8791
# Iteration 1201: Train Acc: 0.8696, Test Acc: 0.8791
# Iteration 1301: Train Acc: 0.8692, Test Acc: 0.8744
# Iteration 1401: Train Acc: 0.8682, Test Acc: 0.8744
# Iteration 1501: Train Acc: 0.8692, Test Acc: 0.8791
# Iteration 1601: Train Acc: 0.8696, Test Acc: 0.8791
# Iteration 1701: Train Acc: 0.8701, Test Acc: 0.8791
# Iteration 1801: Train Acc: 0.8701, Test Acc: 0.8791
# Iteration 1901: Train Acc: 0.8701, Test Acc: 0.8791
# Iteration 2001: Train Acc: 0.8701, Test Acc: 0.8791
# Iteration 2101: Train Acc: 0.8696, Test Acc: 0.8791
# Iteration 2201: Train Acc: 0.8706, Test Acc: 0.8791
# Iteration 2301: Train Acc: 0.8710, Test Acc: 0.8791
# Iteration 2401: Train Acc: 0.8710, Test Acc: 0.8791
# Final Validation Accuracy: 0.8706
# wandb: 0.228 MB of 0.228 MB uploaded
# wandb: 0.242 MB of 0.242 MB uploaded
# wandb:
# wandb: 0.242 MB of 0.242 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:          iteration ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      test_accuracy ▆█▅▆▆▅▃▃▃▃▅▃▃▃▃▃▃▃▃▁▁▁▁▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃
# wandb:     train_accuracy ▇▆▇▇█▄▄▄▄▄▄▄▅▄▄▄▄▄▃▂▂▂▁▂▂▃▃▄▄▄▄▄▃▄▄▅▅▅▄▄
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.87058
# wandb:          iteration 2500
# wandb:      test_accuracy 0.87907
# wandb:     train_accuracy 0.87058
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/prkhqbvy
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_160420-prkhqbvy/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:04:42,000 - wandb.wandb_agent - INFO - Cleaning up finished run: prkhqbvy
# 2025-04-13 16:04:42,142 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:04:42,142 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	learning_rate: optimal
# 	loss: log_loss
# 	num_iterations: 1000
# 2025-04-13 16:04:42,144 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --learning_rate=optimal --loss=log_loss --num_iterations=1000
# 2025-04-13 16:04:47,158 - wandb.wandb_agent - INFO - Running runs: ['s5gncbmu']
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_160450-s5gncbmu
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/lsapjzjg
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/s5gncbmu
# Iteration 1: Train Acc: 0.8333, Test Acc: 0.8419
# Iteration 101: Train Acc: 0.8752, Test Acc: 0.8791
# Iteration 201: Train Acc: 0.8757, Test Acc: 0.8837
# Iteration 301: Train Acc: 0.8762, Test Acc: 0.8837
# Iteration 401: Train Acc: 0.8762, Test Acc: 0.8837
# Iteration 501: Train Acc: 0.8757, Test Acc: 0.8837
# Iteration 601: Train Acc: 0.8752, Test Acc: 0.8837
# Iteration 701: Train Acc: 0.8752, Test Acc: 0.8837
# Iteration 801: Train Acc: 0.8752, Test Acc: 0.8837
# Iteration 901: Train Acc: 0.8752, Test Acc: 0.8837
# Final Validation Accuracy: 0.8752
# wandb: 0.091 MB of 0.104 MB uploaded
# wandb: 0.104 MB of 0.104 MB uploaded
# wandb:
# wandb: 0.104 MB of 0.104 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:          iteration ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      test_accuracy ▁▇▇▇▇▇▇▇███▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇
# wandb:     train_accuracy ▁██▇▇▇█████████████████▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.87523
# wandb:          iteration 1000
# wandb:      test_accuracy 0.88372
# wandb:     train_accuracy 0.87523
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/s5gncbmu
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_160450-s5gncbmu/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:05:07,346 - wandb.wandb_agent - INFO - Cleaning up finished run: s5gncbmu
# 2025-04-13 16:05:07,625 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:05:07,625 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	learning_rate: optimal
# 	loss: hinge
# 	num_iterations: 1000
# 2025-04-13 16:05:07,626 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --learning_rate=optimal --loss=hinge --num_iterations=1000
# 2025-04-13 16:05:12,636 - wandb.wandb_agent - INFO - Running runs: ['edq8gcro']
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_160516-edq8gcro
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/lsapjzjg
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/edq8gcro
# Iteration 1: Train Acc: 0.8585, Test Acc: 0.8558
# Iteration 101: Train Acc: 0.8738, Test Acc: 0.8791
# Iteration 201: Train Acc: 0.8720, Test Acc: 0.8744
# Iteration 301: Train Acc: 0.8734, Test Acc: 0.8791
# Iteration 401: Train Acc: 0.8766, Test Acc: 0.8884
# Iteration 501: Train Acc: 0.8776, Test Acc: 0.8930
# Iteration 601: Train Acc: 0.8771, Test Acc: 0.8884
# Iteration 701: Train Acc: 0.8780, Test Acc: 0.8884
# Iteration 801: Train Acc: 0.8794, Test Acc: 0.8837
# Iteration 901: Train Acc: 0.8780, Test Acc: 0.8837
# Final Validation Accuracy: 0.8771
# wandb: 0.091 MB of 0.091 MB uploaded
# wandb:
# wandb: 0.091 MB of 0.091 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:          iteration ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      test_accuracy ▁▂▇▅▂▄▄▅▅▅▆▅▆▅▇▇█▆▆█▅▆▆▇▆▇▆▇▆▆▇▆█▆▅▆▆▅▆▆
# wandb:     train_accuracy ▁▃▆▅▄▅▄▄▇▆▅▅▆▅▆▇▇▇▇▇▇▇▇▇█▇█▇█▇██▇▇▇▇▆▇▇█
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.87709
# wandb:          iteration 1000
# wandb:      test_accuracy 0.88372
# wandb:     train_accuracy 0.87709
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/edq8gcro
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_160516-edq8gcro/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:05:32,900 - wandb.wandb_agent - INFO - Cleaning up finished run: edq8gcro
# 2025-04-13 16:05:33,106 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:05:33,107 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	learning_rate: optimal
# 	loss: hinge
# 	num_iterations: 1500
# 2025-04-13 16:05:33,108 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --learning_rate=optimal --loss=hinge --num_iterations=1500
# 2025-04-13 16:05:38,120 - wandb.wandb_agent - INFO - Running runs: ['3ugdwpo1']
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_160542-3ugdwpo1
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/lsapjzjg
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/3ugdwpo1
# Iteration 1: Train Acc: 0.8585, Test Acc: 0.8558
# Iteration 101: Train Acc: 0.8738, Test Acc: 0.8791
# Iteration 201: Train Acc: 0.8720, Test Acc: 0.8744
# Iteration 301: Train Acc: 0.8734, Test Acc: 0.8791
# Iteration 401: Train Acc: 0.8766, Test Acc: 0.8884
# Iteration 501: Train Acc: 0.8776, Test Acc: 0.8930
# Iteration 601: Train Acc: 0.8771, Test Acc: 0.8884
# Iteration 701: Train Acc: 0.8780, Test Acc: 0.8884
# Iteration 801: Train Acc: 0.8794, Test Acc: 0.8837
# Iteration 901: Train Acc: 0.8780, Test Acc: 0.8837
# Iteration 1001: Train Acc: 0.8776, Test Acc: 0.8837
# Iteration 1101: Train Acc: 0.8766, Test Acc: 0.8837
# Iteration 1201: Train Acc: 0.8780, Test Acc: 0.8837
# Iteration 1301: Train Acc: 0.8780, Test Acc: 0.8884
# Iteration 1401: Train Acc: 0.8780, Test Acc: 0.8837
# Final Validation Accuracy: 0.8790
# wandb: 0.136 MB of 0.136 MB uploaded
# wandb:
# wandb: 0.136 MB of 0.136 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:          iteration ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      test_accuracy ▁▆▅▄▄▅▅▅▄▇██▇█▇▇█▇█▇█▇▆▇▆▆▇▇▇▇▇▇▇▇▇▇▇▇██
# wandb:     train_accuracy ▁▅▅▆▄▅▇▅▅▆▇▆▇▇▇▇▇▇▇█▇▇▇▇▇▇▇▇▇▇▇▇█▇█▇▇▇█▇
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.87896
# wandb:          iteration 1500
# wandb:      test_accuracy 0.88837
# wandb:     train_accuracy 0.87896
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/3ugdwpo1
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_160542-3ugdwpo1/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:05:58,318 - wandb.wandb_agent - INFO - Cleaning up finished run: 3ugdwpo1
# 2025-04-13 16:06:02,540 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:06:02,540 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	learning_rate: adaptive
# 	loss: log_loss
# 	num_iterations: 1500
# 2025-04-13 16:06:02,542 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --learning_rate=adaptive --loss=log_loss --num_iterations=1500
# 2025-04-13 16:06:07,554 - wandb.wandb_agent - INFO - Running runs: ['6hske77e']
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_160611-6hske77e
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/lsapjzjg
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/6hske77e
# Iteration 1: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 101: Train Acc: 0.8701, Test Acc: 0.8837
# Iteration 201: Train Acc: 0.8696, Test Acc: 0.8837
# Iteration 301: Train Acc: 0.8692, Test Acc: 0.8837
# Iteration 401: Train Acc: 0.8682, Test Acc: 0.8837
# Iteration 501: Train Acc: 0.8692, Test Acc: 0.8837
# Iteration 601: Train Acc: 0.8701, Test Acc: 0.8837
# Iteration 701: Train Acc: 0.8692, Test Acc: 0.8791
# Iteration 801: Train Acc: 0.8706, Test Acc: 0.8837
# Iteration 901: Train Acc: 0.8710, Test Acc: 0.8837
# Iteration 1001: Train Acc: 0.8710, Test Acc: 0.8837
# Iteration 1101: Train Acc: 0.8706, Test Acc: 0.8791
# Iteration 1201: Train Acc: 0.8706, Test Acc: 0.8791
# Iteration 1301: Train Acc: 0.8706, Test Acc: 0.8791
# Iteration 1401: Train Acc: 0.8715, Test Acc: 0.8791
# Final Validation Accuracy: 0.8706
# wandb: 0.137 MB of 0.137 MB uploaded
# wandb: 0.137 MB of 0.150 MB uploaded
# wandb:
# wandb: 0.137 MB of 0.150 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:          iteration ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      test_accuracy ▃▃▁▆█▅▅▅▅▅▅▅▅▅▅▅▃▃▃▃▅▅▅▅▅▅▅▅▅▃▃▃▃▃▃▃▃▃▃▃
# wandb:     train_accuracy ▁▇▅▅▆▅▅▅▅▄▄▄▅▅▆▇▅▅▅▅▇▇▇▇█▇▇▇▇▇▇▇▇▇▇▇▇██▇
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.87058
# wandb:          iteration 1500
# wandb:      test_accuracy 0.87907
# wandb:     train_accuracy 0.87058
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/6hske77e
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_160611-6hske77e/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:06:32,810 - wandb.wandb_agent - INFO - Cleaning up finished run: 6hske77e
# 2025-04-13 16:06:33,026 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:06:33,026 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	learning_rate: invscaling
# 	loss: log_loss
# 	num_iterations: 1500
# 2025-04-13 16:06:33,027 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --learning_rate=invscaling --loss=log_loss --num_iterations=1500
# 2025-04-13 16:06:38,039 - wandb.wandb_agent - INFO - Running runs: ['ajbpq5mb']
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: ⣷ Waiting for wandb.init()...
# wandb: ⣯ Waiting for wandb.init()...
# wandb: ⣟ Waiting for wandb.init()...
# wandb: ⡿ Waiting for wandb.init()...
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: ⣷ Waiting for wandb.init()...
# wandb: ⣯ Waiting for wandb.init()...
# wandb: ⣟ Waiting for wandb.init()...
# wandb: ⡿ Waiting for wandb.init()...
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ Waiting for wandb.init()...
# wandb: ⣽ Waiting for wandb.init()...
# wandb: ⣾ Waiting for wandb.init()...
# wandb: ⣷ Waiting for wandb.init()...
# wandb: ⣯ Waiting for wandb.init()...
# wandb: ⣟ Waiting for wandb.init()...
# wandb: ⡿ Waiting for wandb.init()...
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_160641-ajbpq5mb
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/lsapjzjg
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/ajbpq5mb
# Iteration 1: Train Acc: 0.8561, Test Acc: 0.8605
# Iteration 101: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 201: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 301: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 401: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 501: Train Acc: 0.8575, Test Acc: 0.8744
# Iteration 601: Train Acc: 0.8571, Test Acc: 0.8744
# Iteration 701: Train Acc: 0.8571, Test Acc: 0.8744
# Iteration 801: Train Acc: 0.8571, Test Acc: 0.8744
# Iteration 901: Train Acc: 0.8571, Test Acc: 0.8744
# Iteration 1001: Train Acc: 0.8575, Test Acc: 0.8744
# Iteration 1101: Train Acc: 0.8575, Test Acc: 0.8744
# Iteration 1201: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1301: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1401: Train Acc: 0.8585, Test Acc: 0.8744
# Final Validation Accuracy: 0.8585
# wandb: 0.137 MB of 0.137 MB uploaded
# wandb:
# wandb: 0.137 MB of 0.137 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:          iteration ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      test_accuracy ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:     train_accuracy ▆▆▆▆▃▆▆▆▆▆▆▆▆▃▃▁▁▁▁▁▁▁▁▁▁▁▃▃▃▃▃▆████████
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.85847
# wandb:          iteration 1500
# wandb:      test_accuracy 0.87442
# wandb:     train_accuracy 0.85847
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/ajbpq5mb
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_160641-ajbpq5mb/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:07:08,322 - wandb.wandb_agent - INFO - Cleaning up finished run: ajbpq5mb
# ...
# Iteration 301: Train Acc: 0.8720, Test Acc: 0.8837
# Iteration 401: Train Acc: 0.8701, Test Acc: 0.8791
# Iteration 501: Train Acc: 0.8701, Test Acc: 0.8791
# Iteration 601: Train Acc: 0.8701, Test Acc: 0.8791
# Iteration 701: Train Acc: 0.8701, Test Acc: 0.8791
# Iteration 801: Train Acc: 0.8706, Test Acc: 0.8791
# Iteration 901: Train Acc: 0.8701, Test Acc: 0.8791
# Iteration 1001: Train Acc: 0.8706, Test Acc: 0.8791
# Iteration 1101: Train Acc: 0.8701, Test Acc: 0.8791
# Iteration 1201: Train Acc: 0.8696, Test Acc: 0.8791
# Iteration 1301: Train Acc: 0.8692, Test Acc: 0.8744
# Iteration 1401: Train Acc: 0.8682, Test Acc: 0.8744
# Iteration 1501: Train Acc: 0.8692, Test Acc: 0.8791
# Iteration 1601: Train Acc: 0.8696, Test Acc: 0.8791
# Iteration 1701: Train Acc: 0.8701, Test Acc: 0.8791
# Iteration 1801: Train Acc: 0.8701, Test Acc: 0.8791
# Iteration 1901: Train Acc: 0.8701, Test Acc: 0.8791
# Iteration 2001: Train Acc: 0.8701, Test Acc: 0.8791
# Iteration 2101: Train Acc: 0.8696, Test Acc: 0.8791
# Iteration 2201: Train Acc: 0.8706, Test Acc: 0.8791
# Iteration 2301: Train Acc: 0.8710, Test Acc: 0.8791
# Iteration 2401: Train Acc: 0.8710, Test Acc: 0.8791
# Final Validation Accuracy: 0.8706
# wandb:
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:          iteration ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      test_accuracy ▆█▅▆▆▅▃▃▃▃▅▃▃▃▃▃▃▃▃▁▁▁▁▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃
# wandb:     train_accuracy ▇▆▇▇█▄▄▄▄▄▄▄▅▄▄▄▄▄▃▂▂▂▁▂▂▃▃▄▄▄▄▄▃▄▄▅▅▅▄▄
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.87058
# wandb:          iteration 2500
# wandb:      test_accuracy 0.87907
# wandb:     train_accuracy 0.87058
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/56gj1712
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_162206-56gj1712/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:22:27,593 - wandb.wandb_agent - INFO - Cleaning up finished run: 56gj1712
# 2025-04-13 16:22:27,807 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:22:27,807 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	learning_rate: constant
# 	loss: log_loss
# 	num_iterations: 1500
# 2025-04-13 16:22:27,808 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --learning_rate=constant --loss=log_loss --num_iterations=1500
# 2025-04-13 16:22:32,819 - wandb.wandb_agent - INFO - Running runs: ['wuy7xocj']
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_162236-wuy7xocj
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/lsapjzjg
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/wuy7xocj
# Iteration 1: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 101: Train Acc: 0.8701, Test Acc: 0.8837
# Iteration 201: Train Acc: 0.8696, Test Acc: 0.8837
# Iteration 301: Train Acc: 0.8692, Test Acc: 0.8837
# Iteration 401: Train Acc: 0.8682, Test Acc: 0.8837
# Iteration 501: Train Acc: 0.8692, Test Acc: 0.8837
# Iteration 601: Train Acc: 0.8701, Test Acc: 0.8837
# Iteration 701: Train Acc: 0.8692, Test Acc: 0.8791
# Iteration 801: Train Acc: 0.8706, Test Acc: 0.8837
# Iteration 901: Train Acc: 0.8710, Test Acc: 0.8837
# Iteration 1001: Train Acc: 0.8710, Test Acc: 0.8837
# Iteration 1101: Train Acc: 0.8706, Test Acc: 0.8791
# Iteration 1201: Train Acc: 0.8706, Test Acc: 0.8791
# Iteration 1301: Train Acc: 0.8706, Test Acc: 0.8791
# Iteration 1401: Train Acc: 0.8715, Test Acc: 0.8791
# Final Validation Accuracy: 0.8706
# wandb:
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:          iteration ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      test_accuracy ▃▃▁▆█▅▅▅▅▅▅▅▅▅▅▅▃▃▃▃▅▅▅▅▅▅▅▅▅▃▃▃▃▃▃▃▃▃▃▃
# wandb:     train_accuracy ▁▇▅▅▆▅▅▅▅▄▄▄▅▅▆▇▅▅▅▅▇▇▇▇█▇▇▇▇▇▇▇▇▇▇▇▇██▇
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.87058
# wandb:          iteration 1500
# wandb:      test_accuracy 0.87907
# wandb:     train_accuracy 0.87058
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/wuy7xocj
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_162236-wuy7xocj/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:22:53,013 - wandb.wandb_agent - INFO - Cleaning up finished run: wuy7xocj
# 2025-04-13 16:22:53,235 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:22:53,235 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	learning_rate: optimal
# 	loss: log_loss
# 	num_iterations: 2500
# 2025-04-13 16:22:53,236 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --learning_rate=optimal --loss=log_loss --num_iterations=2500
# 2025-04-13 16:22:58,248 - wandb.wandb_agent - INFO - Running runs: ['q0vx0twc']
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_162301-q0vx0twc
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/lsapjzjg
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/q0vx0twc
# Iteration 1: Train Acc: 0.8333, Test Acc: 0.8419
# Iteration 101: Train Acc: 0.8752, Test Acc: 0.8791
# Iteration 201: Train Acc: 0.8757, Test Acc: 0.8837
# Iteration 301: Train Acc: 0.8762, Test Acc: 0.8837
# Iteration 401: Train Acc: 0.8762, Test Acc: 0.8837
# Iteration 501: Train Acc: 0.8757, Test Acc: 0.8837
# Iteration 601: Train Acc: 0.8752, Test Acc: 0.8837
# Iteration 701: Train Acc: 0.8752, Test Acc: 0.8837
# Iteration 801: Train Acc: 0.8752, Test Acc: 0.8837
# Iteration 901: Train Acc: 0.8752, Test Acc: 0.8837
# Iteration 1001: Train Acc: 0.8752, Test Acc: 0.8837
# Iteration 1101: Train Acc: 0.8748, Test Acc: 0.8837
# Iteration 1201: Train Acc: 0.8748, Test Acc: 0.8837
# Iteration 1301: Train Acc: 0.8738, Test Acc: 0.8837
# Iteration 1401: Train Acc: 0.8738, Test Acc: 0.8837
# Iteration 1501: Train Acc: 0.8738, Test Acc: 0.8837
# Iteration 1601: Train Acc: 0.8738, Test Acc: 0.8837
# Iteration 1701: Train Acc: 0.8738, Test Acc: 0.8837
# Iteration 1801: Train Acc: 0.8738, Test Acc: 0.8837
# Iteration 1901: Train Acc: 0.8738, Test Acc: 0.8837
# Iteration 2001: Train Acc: 0.8738, Test Acc: 0.8837
# Iteration 2101: Train Acc: 0.8738, Test Acc: 0.8837
# Iteration 2201: Train Acc: 0.8734, Test Acc: 0.8791
# Iteration 2301: Train Acc: 0.8734, Test Acc: 0.8791
# Iteration 2401: Train Acc: 0.8734, Test Acc: 0.8791
# Final Validation Accuracy: 0.8734
# wandb:
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:          iteration ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      test_accuracy ▁█▅▅█▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▁▁▁▁▁▁
# wandb:     train_accuracy ██▄▅▅▆▆▅▅▅▄▄▄▄▄▄▄▄▄▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.87337
# wandb:          iteration 2500
# wandb:      test_accuracy 0.87907
# wandb:     train_accuracy 0.87337
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/q0vx0twc
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_162301-q0vx0twc/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:23:23,485 - wandb.wandb_agent - INFO - Cleaning up finished run: q0vx0twc
# 2025-04-13 16:23:23,632 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:23:23,632 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	learning_rate: invscaling
# 	loss: hinge
# 	num_iterations: 2500
# 2025-04-13 16:23:23,633 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --learning_rate=invscaling --loss=hinge --num_iterations=2500
# 2025-04-13 16:23:28,644 - wandb.wandb_agent - INFO - Running runs: ['jj1sr2my']
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_162332-jj1sr2my
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/lsapjzjg
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/jj1sr2my
# Iteration 1: Train Acc: 0.8561, Test Acc: 0.8651
# Iteration 101: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 201: Train Acc: 0.8571, Test Acc: 0.8744
# Iteration 301: Train Acc: 0.8571, Test Acc: 0.8744
# Iteration 401: Train Acc: 0.8566, Test Acc: 0.8744
# Iteration 501: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 601: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 701: Train Acc: 0.8575, Test Acc: 0.8651
# Iteration 801: Train Acc: 0.8580, Test Acc: 0.8698
# Iteration 901: Train Acc: 0.8575, Test Acc: 0.8698
# Iteration 1001: Train Acc: 0.8575, Test Acc: 0.8698
# Iteration 1101: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1201: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 1301: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1401: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1501: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1601: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1701: Train Acc: 0.8585, Test Acc: 0.8744
# Iteration 1801: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 1901: Train Acc: 0.8589, Test Acc: 0.8744
# Iteration 2001: Train Acc: 0.8599, Test Acc: 0.8744
# Iteration 2101: Train Acc: 0.8599, Test Acc: 0.8744
# Iteration 2201: Train Acc: 0.8603, Test Acc: 0.8744
# Iteration 2301: Train Acc: 0.8608, Test Acc: 0.8744
# Iteration 2401: Train Acc: 0.8608, Test Acc: 0.8744
# Final Validation Accuracy: 0.8608
# wandb: 0.228 MB of 0.228 MB uploaded
# wandb:
# wandb: 0.228 MB of 0.228 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:          iteration ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      test_accuracy ▄█████████▁▁▄▄▄▄▄▄██████████████████████
# wandb:     train_accuracy ▃▄▃▂▂▁▁▁▃▄▂▃▃▃▃▃▄▃▄▃▄▄▄▃▄▄▄▄▃▅▆▆▆▇▇▇████
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.8608
# wandb:          iteration 2500
# wandb:      test_accuracy 0.87442
# wandb:     train_accuracy 0.8608
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/jj1sr2my
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_162332-jj1sr2my/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:23:53,893 - wandb.wandb_agent - INFO - Cleaning up finished run: jj1sr2my
# 2025-04-13 16:23:54,069 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:23:54,069 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	learning_rate: adaptive
# 	loss: log_loss
# 	num_iterations: 1000
# 2025-04-13 16:23:54,071 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --learning_rate=adaptive --loss=log_loss --num_iterations=1000
# 2025-04-13 16:23:59,086 - wandb.wandb_agent - INFO - Running runs: ['v0qcwvj8']
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_162402-v0qcwvj8
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/lsapjzjg
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/v0qcwvj8
# Iteration 1: Train Acc: 0.8580, Test Acc: 0.8744
# Iteration 101: Train Acc: 0.8701, Test Acc: 0.8837
# Iteration 201: Train Acc: 0.8696, Test Acc: 0.8837
# Iteration 301: Train Acc: 0.8692, Test Acc: 0.8837
# Iteration 401: Train Acc: 0.8682, Test Acc: 0.8837
# Iteration 501: Train Acc: 0.8692, Test Acc: 0.8837
# Iteration 601: Train Acc: 0.8701, Test Acc: 0.8837
# Iteration 701: Train Acc: 0.8692, Test Acc: 0.8791
# Iteration 801: Train Acc: 0.8706, Test Acc: 0.8837
# Iteration 901: Train Acc: 0.8710, Test Acc: 0.8837
# Final Validation Accuracy: 0.8710
# wandb: 0.091 MB of 0.091 MB uploaded
# wandb: 0.091 MB of 0.104 MB uploaded
# wandb:
# wandb: 0.091 MB of 0.104 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:          iteration ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      test_accuracy ▁▅▃▁▅▆█▅▆▆▅▅▅▅▅▅▅▅▅▅▅▅▅▅▃▃▃▃▃▅▅▅▅▅▅▅▅▅▅▅
# wandb:     train_accuracy ▁█▆▆▇▆▇▆▇▇▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▆▆▇▇▇▇▇▇▇█████
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.87104
# wandb:          iteration 1000
# wandb:      test_accuracy 0.88372
# wandb:     train_accuracy 0.87104
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/v0qcwvj8
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 1 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_162402-v0qcwvj8/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:24:21,630 - wandb.wandb_agent - INFO - Cleaning up finished run: v0qcwvj8
# wandb: Terminating and syncing runs. Press ctrl-c to kill.

# %%
# %%writefile train.py

import argparse
import wandb
import pandas as pd
import numpy as np
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import accuracy_score
from fastai.vision.all import *

from sklearn.model_selection import StratifiedKFold
from sklearn.decomposition import PCA

import pandas as pd
import wandb
from pathlib import Path

# Defaults for sweep overrides or direct usage
default_config = SimpleNamespace(
    loss_function="log_loss",
    learning_rate="optimal",
    num_iterations=1000,
    log_interval=100,
    wandb_project="pistachio-classification",
    wandb_run_name="data-partioning-model-eval",
    use_wandb=True
)

def parse_args():
    """Override default arguments"""
    parser = argparse.ArgumentParser(description="SGD classifier training script")
    parser.add_argument("--loss_function", type=str, default=default_config.loss_function)
    parser.add_argument("--learning_rate", type=str, default=default_config.learning_rate)
    parser.add_argument("--num_iterations", type=int, default=default_config.num_iterations)
    parser.add_argument("--log_interval", type=int, default=default_config.log_interval)
    parser.add_argument("--wandb_project", type=str, default=default_config.wandb_project)
    parser.add_argument("--wandb_run_name", type=str, default=default_config.wandb_run_name)
    parser.add_argument("--use_wandb", type=bool, default=default_config.use_wandb)
    args = parser.parse_args()
    vars(default_config).update(vars(args))
    return

def load_data(n_splits=2):
# Check if the directory exists and download the processed dataset if not
    import os
    if not os.path.exists('./artifacts/pistachio-image-classification-data-split:v0/data_split.csv'):
        processed_data_at = wandb.use_artifact('pistachio-image-classification-data-split:latest')
        processed_dataset_dir = Path(processed_data_at.download())

    # Load the CSV with the data
    data_path = './artifacts/pistachio-image-classification-data-split:v0/data_split.csv'
    df = pd.read_csv(data_path)

    # Separate features and target variable
    X = df.drop(['Class', 'Stage'], axis=1)
    y = df['Class']

    # Initialize Stratified K-Fold
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

    # Create lists to store each fold's splits
    X_train_list = []
    y_train_list = []
    X_val_list = []
    y_val_list = []
    X_test_list = []
    y_test_list = []

    # Loop through each fold and store the splits
    for train_idx, val_idx in skf.split(X, y):
        # Get the train and validation splits for this fold
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

        # Convert y_train, y_val to NumPy arrays (flatten them if needed)
        y_train_flat = y_train.to_numpy()  # Ensure it's a 1D array
        y_val_flat = y_val.to_numpy()      # Ensure it's a 1D array

        # Test data remains constant, separate from the training/validation data
        X_test = X[df['Stage'] == 'test']
        y_test = y[df['Stage'] == 'test']
        y_test_flat = y_test.to_numpy()    # Ensure it's a 1D array

        # Append the current fold's splits to the corresponding lists as 1D arrays
        X_train_list.extend(X_train.to_numpy())  # Add each fold's X_train directly
        y_train_list.extend(y_train_flat)       # Add each fold's y_train directly
        X_val_list.extend(X_val.to_numpy())      # Add each fold's X_val directly
        y_val_list.extend(y_val_flat)           # Add each fold's y_val directly
        X_test_list.extend(X_test.to_numpy())    # Add each fold's X_test directly
        y_test_list.extend(y_test_flat)         # Add each fold's y_test directly

    # Return flattened lists (1D arrays) for all splits
    return X_train_list, y_train_list, X_val_list, y_val_list, X_test_list, y_test_list

def run_experiment(config):
    run = None
    if config.use_wandb:
        run = wandb.init(project=config.wandb_project, name=config.wandb_run_name)

    X_train, y_train, X_val, y_val, X_test, y_test = load_data()

    # add pca
    pca = PCA(n_components=16)
    X_train = pca.fit_transform(X_train)
    X_val = pca.transform(X_val)

    le = LabelEncoder()
    y_train_enc = le.fit_transform(y_train)
    y_val_enc = le.transform(y_val)
    y_test_enc = le.transform(y_test)

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)
    X_test_scaled = scaler.transform(X_test)

    classes = np.unique(y_train_enc)
    class_weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_train_enc)
    class_weight_dict = dict(zip(classes, class_weights))

    model = SGDClassifier(loss=config.loss_function, learning_rate=config.learning_rate, random_state=42, eta0=0.0001)

    results = []
    for i in range(config.num_iterations):
        model.partial_fit(X_train_scaled, y_train_enc, classes=classes)
        train_acc = accuracy_score(y_train_enc, model.predict(X_train_scaled))
        test_acc = accuracy_score(y_test_enc, model.predict(X_test_scaled))

        if i % config.log_interval == 0:
            print(f"Iteration {i+1}: Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}")

        if config.use_wandb:
            wandb.log({"iteration": i + 1, "train_accuracy": train_acc, "test_accuracy": test_acc})

        results.append({"iteration": i + 1, "train_accuracy": train_acc, "test_accuracy": test_acc})

    val_acc = accuracy_score(y_val_enc, model.predict(X_val_scaled))
    print(f"Final Validation Accuracy: {val_acc:.4f}")

    if config.use_wandb:
        wandb.log({"final_val_accuracy": val_acc})
        result_table = wandb.Table(columns=["iteration", "train_accuracy", "test_accuracy"])
        for res in results:
            result_table.add_data(res["iteration"], res["train_accuracy"], res["test_accuracy"])
        wandb.log({"training_results": result_table})
        # run.finish() # already commented out intentionally

    return {
        "model": model,
        "scaler": scaler,
        "label_encoder": le,
        "val_accuracy": val_acc,
        "training_log": results
    }

if __name__ == '__main__':
    parse_args()
    run_experiment(default_config)
# Out:
# Overwriting train.py

# %%
# !python train.py --learning_rate=optimal --loss_function=hinge --num_iterations=1000 --wandb_project "pistachio-classification" --wandb_run_name "sgd_classifier_run"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_162838-p5vv2y0m
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run sgd_classifier_run
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/p5vv2y0m
# Iteration 1: Train Acc: 0.8422, Test Acc: 0.4977
# Iteration 101: Train Acc: 0.8650, Test Acc: 0.4977
# Iteration 201: Train Acc: 0.8748, Test Acc: 0.5023
# Iteration 301: Train Acc: 0.8748, Test Acc: 0.5023
# Iteration 401: Train Acc: 0.8776, Test Acc: 0.5023
# Iteration 501: Train Acc: 0.8780, Test Acc: 0.5023
# Iteration 601: Train Acc: 0.8766, Test Acc: 0.5023
# Iteration 701: Train Acc: 0.8780, Test Acc: 0.5023
# Iteration 801: Train Acc: 0.8766, Test Acc: 0.5023
# Iteration 901: Train Acc: 0.8804, Test Acc: 0.5023
# Final Validation Accuracy: 0.8799
# wandb:
# wandb: 🚀 View run sgd_classifier_run at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/p5vv2y0m
# wandb: Find logs at: wandb/run-20250413_162838-p5vv2y0m/logs

# %%
# %%writefile train_logistic_regression.py
import argparse
import wandb
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
from pathlib import Path
import os
from sklearn.decomposition import PCA
from types import SimpleNamespace


# Defaults for sweep overrides or direct usage
default_config = SimpleNamespace(
    loss_function="lbfgs",  # Use a solver appropriate for Logistic Regression
    learning_rate=None,     # Learning rate is not relevant for Logistic Regression
    num_iterations=1000,
    log_interval=100,
    wandb_project="pistachio-classification",
    wandb_run_name="data-partioning-model-eval",
    use_wandb=True
)

def parse_args():
    """Override default arguments"""
    parser = argparse.ArgumentParser(description="Logistic Regression training script")
    parser.add_argument("--loss_function", type=str, default=default_config.loss_function)
    parser.add_argument("--learning_rate", type=str, default=default_config.learning_rate) # Keep for compatibility, but not used
    parser.add_argument("--num_iterations", type=int, default=default_config.num_iterations)
    parser.add_argument("--log_interval", type=int, default=default_config.log_interval)
    parser.add_argument("--wandb_project", type=str, default=default_config.wandb_project)
    parser.add_argument("--wandb_run_name", type=str, default=default_config.wandb_run_name)
    parser.add_argument("--use_wandb", type=bool, default=default_config.use_wandb)
    args = parser.parse_args()
    vars(default_config).update(vars(args))
    return

def load_data(n_splits=2):
# Check if the directory exists and download the processed dataset if not
    import os
    if not os.path.exists('./artifacts/pistachio-image-classification-data-split:v0/data_split.csv'):
        processed_data_at = wandb.use_artifact('pistachio-image-classification-data-split:latest')
        processed_dataset_dir = Path(processed_data_at.download())

    # Load the CSV with the data
    data_path = './artifacts/pistachio-image-classification-data-split:v0/data_split.csv'
    df = pd.read_csv(data_path)

    # Separate features and target variable
    X = df.drop(['Class', 'Stage'], axis=1)
    y = df['Class']

    # Initialize Stratified K-Fold
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

    # Create lists to store each fold's splits
    X_train_list = []
    y_train_list = []
    X_val_list = []
    y_val_list = []
    X_test_list = []
    y_test_list = []

    # Loop through each fold and store the splits
    for train_idx, val_idx in skf.split(X, y):
        # Get the train and validation splits for this fold
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

        # Convert y_train, y_val to NumPy arrays (flatten them if needed)
        y_train_flat = y_train.to_numpy()  # Ensure it's a 1D array
        y_val_flat = y_val.to_numpy()      # Ensure it's a 1D array

        # Test data remains constant, separate from the training/validation data
        X_test = X[df['Stage'] == 'test']
        y_test = y[df['Stage'] == 'test']
        y_test_flat = y_test.to_numpy()    # Ensure it's a 1D array

        # Append the current fold's splits to the corresponding lists as 1D arrays
        X_train_list.extend(X_train.to_numpy())  # Add each fold's X_train directly
        y_train_list.extend(y_train_flat)       # Add each fold's y_train directly
        X_val_list.extend(X_val.to_numpy())      # Add each fold's X_val directly
        y_val_list.extend(y_val_flat)           # Add each fold's y_val directly
        X_test_list.extend(X_test.to_numpy())    # Add each fold's X_test directly
        y_test_list.extend(y_test_flat)         # Add each fold's y_test directly

    # Return flattened lists (1D arrays) for all splits
    return X_train_list, y_train_list, X_val_list, y_val_list, X_test_list, y_test_list

def run_experiment(config):
    run = None
    if config.use_wandb:
        run = wandb.init(project=config.wandb_project, name=config.wandb_run_name)

    X_train, y_train, X_val, y_val, X_test, y_test = load_data()

    # add pca
    pca = PCA(n_components=28)
    X_train = pca.fit_transform(X_train)
    X_val = pca.transform(X_val)
    X_test = pca.transform(X_test) # Apply PCA to X_test


    le = LabelEncoder()
    y_train_enc = le.fit_transform(y_train)
    y_val_enc = le.transform(y_val)
    y_test_enc = le.transform(y_test)

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)
    X_test_scaled = scaler.transform(X_test)

    classes = np.unique(y_train_enc)
    class_weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_train_enc)
    class_weight_dict = dict(zip(classes, class_weights))

    # Use LogisticRegression instead of SGDClassifier
    model = LogisticRegression(solver=config.loss_function, random_state=42, class_weight=class_weight_dict, max_iter=config.num_iterations) # Use the specified solver
    model.fit(X_train_scaled, y_train_enc)

    # ... (rest of the code remains largely the same, no need for partial_fit)
    train_acc = accuracy_score(y_train_enc, model.predict(X_train_scaled))
    test_acc = accuracy_score(y_test_enc, model.predict(X_test_scaled))
    val_acc = accuracy_score(y_val_enc, model.predict(X_val_scaled))


    print(f"Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}, val Acc: {val_acc:.4f}")


    if config.use_wandb:
      wandb.log({"train_accuracy": train_acc, "test_accuracy": test_acc, "final_val_accuracy": val_acc})

# ... (rest of the code, including if __name__ == '__main__' remains the same)

if __name__ == '__main__':
    parse_args()
    run_experiment(default_config)
# Out:
# Overwriting train_logistic_regression.py

# %%
# !python train_logistic_regression.py --learning_rate=optimal --loss_function=lbfgs --num_iterations=1000 --wandb_project "pistachio-classification" --wandb_run_name "logistic_regression_run"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_164738-tyy42da1
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run logistic_regression_run
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/tyy42da1
# Train Acc: 0.8776, Test Acc: 0.8837, val Acc: 0.8776
# wandb:
# wandb: 🚀 View run logistic_regression_run at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/tyy42da1
# wandb: Find logs at: wandb/run-20250413_164738-tyy42da1/logs

# %%
# prompt: Change the classifier to randomforest in the code above; give me full code
# %%writefile train_random_forest.py

import argparse
import wandb
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier # Changed classifier
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
from pathlib import Path
import os
from sklearn.decomposition import PCA
from types import SimpleNamespace

# Defaults for sweep overrides or direct usage
default_config = SimpleNamespace(
    n_estimators=100, # Add hyperparameter for RandomForest
    max_depth=None, # Add hyperparameter for RandomForest
    loss_function="log_loss", # Placeholder, not used for RandomForest
    learning_rate="optimal", # Placeholder, not used for RandomForest
    num_iterations=1000, # Placeholder, not used for RandomForest
    log_interval=100,
    wandb_project="pistachio-classification",
    wandb_run_name="data-partioning-model-eval",
    use_wandb=True
)

def parse_args():
    """Override default arguments"""
    parser = argparse.ArgumentParser(description="RandomForest classifier training script")
    parser.add_argument("--n_estimators", type=int, default=default_config.n_estimators)
    parser.add_argument("--max_depth", type=int, default=default_config.max_depth)
    parser.add_argument("--loss_function", type=str, default=default_config.loss_function)
    parser.add_argument("--learning_rate", type=str, default=default_config.learning_rate)
    parser.add_argument("--num_iterations", type=int, default=default_config.num_iterations)
    parser.add_argument("--log_interval", type=int, default=default_config.log_interval)
    parser.add_argument("--wandb_project", type=str, default=default_config.wandb_project)
    parser.add_argument("--wandb_run_name", type=str, default=default_config.wandb_run_name)
    parser.add_argument("--use_wandb", type=bool, default=default_config.use_wandb)
    args = parser.parse_args()
    vars(default_config).update(vars(args))
    return

def load_data(n_splits=2):
# Check if the directory exists and download the processed dataset if not
    import os
    if not os.path.exists('./artifacts/pistachio-image-classification-data-split:v0/data_split.csv'):
        processed_data_at = wandb.use_artifact('pistachio-image-classification-data-split:latest')
        processed_dataset_dir = Path(processed_data_at.download())

    # Load the CSV with the data
    data_path = './artifacts/pistachio-image-classification-data-split:v0/data_split.csv'
    df = pd.read_csv(data_path)

    # Separate features and target variable
    X = df.drop(['Class', 'Stage'], axis=1)
    y = df['Class']

    # Initialize Stratified K-Fold
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

    # Create lists to store each fold's splits
    X_train_list = []
    y_train_list = []
    X_val_list = []
    y_val_list = []
    X_test_list = []
    y_test_list = []

    # Loop through each fold and store the splits
    for train_idx, val_idx in skf.split(X, y):
        # Get the train and validation splits for this fold
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

        # Convert y_train, y_val to NumPy arrays (flatten them if needed)
        y_train_flat = y_train.to_numpy()  # Ensure it's a 1D array
        y_val_flat = y_val.to_numpy()      # Ensure it's a 1D array

        # Test data remains constant, separate from the training/validation data
        X_test = X[df['Stage'] == 'test']
        y_test = y[df['Stage'] == 'test']
        y_test_flat = y_test.to_numpy()    # Ensure it's a 1D array

        # Append the current fold's splits to the corresponding lists as 1D arrays
        X_train_list.extend(X_train.to_numpy())  # Add each fold's X_train directly
        y_train_list.extend(y_train_flat)       # Add each fold's y_train directly
        X_val_list.extend(X_val.to_numpy())      # Add each fold's X_val directly
        y_val_list.extend(y_val_flat)           # Add each fold's y_val directly
        X_test_list.extend(X_test.to_numpy())    # Add each fold's X_test directly
        y_test_list.extend(y_test_flat)         # Add each fold's y_test directly

    # Return flattened lists (1D arrays) for all splits
    return X_train_list, y_train_list, X_val_list, y_val_list, X_test_list, y_test_list

def run_experiment(config):
    run = None
    if config.use_wandb:
        run = wandb.init(project=config.wandb_project, name=config.wandb_run_name, config=config)

    X_train, y_train, X_val, y_val, X_test, y_test = load_data()

    # add pca
    pca = PCA(n_components=16)
    X_train = pca.fit_transform(X_train)
    X_val = pca.transform(X_val)
    X_test = pca.transform(X_test) # Apply PCA to X_test

    le = LabelEncoder()
    y_train_enc = le.fit_transform(y_train)
    y_val_enc = le.transform(y_val)
    y_test_enc = le.transform(y_test)

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)
    X_test_scaled = scaler.transform(X_test)

    classes = np.unique(y_train_enc)
    class_weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_train_enc)
    class_weight_dict = dict(zip(classes, class_weights))

    # Initialize RandomForestClassifier with hyperparameters
    model = RandomForestClassifier(n_estimators=config.n_estimators, max_depth=config.max_depth, random_state=42, class_weight=class_weight_dict)
    model.fit(X_train_scaled, y_train_enc)

    train_acc = accuracy_score(y_train_enc, model.predict(X_train_scaled))
    test_acc = accuracy_score(y_test_enc, model.predict(X_test_scaled))
    val_acc = accuracy_score(y_val_enc, model.predict(X_val_scaled))

    print(f"Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f}, val Acc: {val_acc:.4f}")

    if config.use_wandb:
        wandb.log({"train_accuracy": train_acc, "test_accuracy": test_acc, "final_val_accuracy": val_acc})

    return {
        "model": model,
        "scaler": scaler,
        "label_encoder": le,
        "val_accuracy": val_acc
    }

if __name__ == '__main__':
    parse_args()
    run_experiment(default_config)
# Out:
# Overwriting train_random_forest.py

# %%
# !python train_random_forest.py --learning_rate=optimal --loss_function=lbfgs --num_iterations=1000 --wandb_project "pistachio-classification" --wandb_run_name "logistic_regression_run"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_165021-e6r4z5fv
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run logistic_regression_run
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/e6r4z5fv
# Train Acc: 1.0000, Test Acc: 1.0000, val Acc: 1.0000
# wandb:
# wandb: 🚀 View run logistic_regression_run at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/e6r4z5fv
# wandb: Find logs at: wandb/run-20250413_165021-e6r4z5fv/logs

# %%
# %%writefile sweep_random_forest.yaml
#
# program: train_random_forest.py
# method: random
# metric:
#   name: final_val_accuracy
#   goal: maximize
# parameters:
#   n_estimators:
#     values: [50, 100, 200]
#   max_depth:
#     values: [10, 20, None]
#   pca_components:
#     values: [16, 28, 64]
# Out:
# Writing sweep_random_forest.yaml

# %%
# !wandb sweep ./sweep_random_forest.yaml
# Out:
# wandb: Creating sweep from: ./sweep_random_forest.yaml
# wandb: Creating sweep with ID: oc1a3evy
# wandb: View sweep at: https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: Run sweep agent with: wandb agent vadhri-venkat/pistachio-classification/oc1a3evy

# %%
# !wandb agent vadhri-venkat/pistachio-classification/oc1a3evy --count=50
# Out:
# wandb: Starting wandb agent 🕵️
# 2025-04-13 16:57:47,890 - wandb.wandb_agent - INFO - Running runs: []
# 2025-04-13 16:57:48,068 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:57:48,068 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 20
# 	n_estimators: 50
# 2025-04-13 16:57:48,069 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=20 --n_estimators=50
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_165752-esfmqr1j
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/esfmqr1j
# 2025-04-13 16:57:53,081 - wandb.wandb_agent - INFO - Running runs: ['esfmqr1j']
# Train Acc: 1.0000, Test Acc: 1.0000, val Acc: 1.0000
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 1.0
# wandb:      test_accuracy 1.0
# wandb:     train_accuracy 1.0
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/esfmqr1j
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_165752-esfmqr1j/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:58:03,192 - wandb.wandb_agent - INFO - Cleaning up finished run: esfmqr1j
# 2025-04-13 16:58:04,175 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:58:04,175 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 10
# 	n_estimators: 100
# 2025-04-13 16:58:04,177 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=10 --n_estimators=100
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_165808-yrx12h00
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/yrx12h00
# 2025-04-13 16:58:09,186 - wandb.wandb_agent - INFO - Running runs: ['yrx12h00']
# Train Acc: 0.9856, Test Acc: 0.9860, val Acc: 0.9856
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.98557
# wandb:      test_accuracy 0.98605
# wandb:     train_accuracy 0.98557
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/yrx12h00
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_165808-yrx12h00/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:58:19,287 - wandb.wandb_agent - INFO - Cleaning up finished run: yrx12h00
# 2025-04-13 16:58:19,675 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:58:19,675 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 20
# 	n_estimators: 200
# 2025-04-13 16:58:19,677 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=20 --n_estimators=200
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_165823-84w062a4
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/84w062a4
# 2025-04-13 16:58:24,689 - wandb.wandb_agent - INFO - Running runs: ['84w062a4']
# Train Acc: 1.0000, Test Acc: 1.0000, val Acc: 1.0000
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 1.0
# wandb:      test_accuracy 1.0
# wandb:     train_accuracy 1.0
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/84w062a4
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_165823-84w062a4/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:58:34,793 - wandb.wandb_agent - INFO - Cleaning up finished run: 84w062a4
# 2025-04-13 16:58:34,950 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:58:34,950 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 2
# 	n_estimators: 200
# 2025-04-13 16:58:34,952 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=2 --n_estimators=200
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_165838-ffttn5qh
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/ffttn5qh
# 2025-04-13 16:58:39,964 - wandb.wandb_agent - INFO - Running runs: ['ffttn5qh']
# Train Acc: 0.8659, Test Acc: 0.8744, val Acc: 0.8659
# wandb:
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.86592
# wandb:      test_accuracy 0.87442
# wandb:     train_accuracy 0.86592
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/ffttn5qh
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_165838-ffttn5qh/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:58:50,061 - wandb.wandb_agent - INFO - Cleaning up finished run: ffttn5qh
# 2025-04-13 16:58:50,204 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:58:50,204 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 2
# 	n_estimators: 50
# 2025-04-13 16:58:50,205 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=2 --n_estimators=50
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_165854-n0r8gj74
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/n0r8gj74
# 2025-04-13 16:58:55,217 - wandb.wandb_agent - INFO - Running runs: ['n0r8gj74']
# Train Acc: 0.8534, Test Acc: 0.8791, val Acc: 0.8534
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.85335
# wandb:      test_accuracy 0.87907
# wandb:     train_accuracy 0.85335
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/n0r8gj74
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_165854-n0r8gj74/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:59:05,334 - wandb.wandb_agent - INFO - Cleaning up finished run: n0r8gj74
# 2025-04-13 16:59:05,531 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:59:05,531 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 20
# 	n_estimators: 200
# 2025-04-13 16:59:05,533 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=20 --n_estimators=200
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_165909-wzjjh3ub
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/wzjjh3ub
# 2025-04-13 16:59:10,550 - wandb.wandb_agent - INFO - Running runs: ['wzjjh3ub']
# Train Acc: 1.0000, Test Acc: 1.0000, val Acc: 1.0000
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 1.0
# wandb:      test_accuracy 1.0
# wandb:     train_accuracy 1.0
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/wzjjh3ub
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_165909-wzjjh3ub/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:59:20,646 - wandb.wandb_agent - INFO - Cleaning up finished run: wzjjh3ub
# 2025-04-13 16:59:20,892 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:59:20,892 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 10
# 	n_estimators: 100
# 2025-04-13 16:59:20,893 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=10 --n_estimators=100
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_165924-sog1yuhr
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/sog1yuhr
# 2025-04-13 16:59:25,906 - wandb.wandb_agent - INFO - Running runs: ['sog1yuhr']
# Train Acc: 0.9856, Test Acc: 0.9860, val Acc: 0.9856
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.98557
# wandb:      test_accuracy 0.98605
# wandb:     train_accuracy 0.98557
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/sog1yuhr
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_165924-sog1yuhr/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:59:36,003 - wandb.wandb_agent - INFO - Cleaning up finished run: sog1yuhr
# 2025-04-13 16:59:36,159 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:59:36,159 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 10
# 	n_estimators: 200
# 2025-04-13 16:59:36,160 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=10 --n_estimators=200
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_165939-nbta7apu
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/nbta7apu
# 2025-04-13 16:59:41,173 - wandb.wandb_agent - INFO - Running runs: ['nbta7apu']
# Train Acc: 0.9870, Test Acc: 0.9953, val Acc: 0.9870
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.98696
# wandb:      test_accuracy 0.99535
# wandb:     train_accuracy 0.98696
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/nbta7apu
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_165939-nbta7apu/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 16:59:51,278 - wandb.wandb_agent - INFO - Cleaning up finished run: nbta7apu
# 2025-04-13 16:59:51,455 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 16:59:51,455 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 2
# 	n_estimators: 200
# 2025-04-13 16:59:51,456 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=2 --n_estimators=200
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_165955-r45wbrry
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/r45wbrry
# 2025-04-13 16:59:56,467 - wandb.wandb_agent - INFO - Running runs: ['r45wbrry']
# Train Acc: 0.8659, Test Acc: 0.8744, val Acc: 0.8659
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.86592
# wandb:      test_accuracy 0.87442
# wandb:     train_accuracy 0.86592
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/r45wbrry
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_165955-r45wbrry/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 17:00:06,564 - wandb.wandb_agent - INFO - Cleaning up finished run: r45wbrry
# 2025-04-13 17:00:06,746 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 17:00:06,746 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 10
# 	n_estimators: 200
# 2025-04-13 17:00:06,748 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=10 --n_estimators=200
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_170011-syd4h32e
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/syd4h32e
# 2025-04-13 17:00:11,767 - wandb.wandb_agent - INFO - Running runs: ['syd4h32e']
# Train Acc: 0.9870, Test Acc: 0.9953, val Acc: 0.9870
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.98696
# wandb:      test_accuracy 0.99535
# wandb:     train_accuracy 0.98696
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/syd4h32e
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_170011-syd4h32e/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 17:00:21,868 - wandb.wandb_agent - INFO - Cleaning up finished run: syd4h32e
# 2025-04-13 17:00:22,153 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 17:00:22,153 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 20
# 	n_estimators: 50
# 2025-04-13 17:00:22,154 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=20 --n_estimators=50
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_170025-8mrbivz7
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/8mrbivz7
# Train Acc: 1.0000, Test Acc: 1.0000, val Acc: 1.0000
# 2025-04-13 17:00:27,166 - wandb.wandb_agent - INFO - Running runs: ['8mrbivz7']
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 1.0
# wandb:      test_accuracy 1.0
# wandb:     train_accuracy 1.0
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/8mrbivz7
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_170025-8mrbivz7/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 17:00:37,258 - wandb.wandb_agent - INFO - Cleaning up finished run: 8mrbivz7
# 2025-04-13 17:00:37,445 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 17:00:37,446 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 20
# 	n_estimators: 100
# 2025-04-13 17:00:37,447 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=20 --n_estimators=100
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_170041-7eh5gnu6
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/7eh5gnu6
# 2025-04-13 17:00:42,459 - wandb.wandb_agent - INFO - Running runs: ['7eh5gnu6']
# Train Acc: 1.0000, Test Acc: 1.0000, val Acc: 1.0000
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 1.0
# wandb:      test_accuracy 1.0
# wandb:     train_accuracy 1.0
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/7eh5gnu6
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_170041-7eh5gnu6/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 17:00:52,568 - wandb.wandb_agent - INFO - Cleaning up finished run: 7eh5gnu6
# 2025-04-13 17:00:52,787 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 17:00:52,787 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 2
# 	n_estimators: 50
# 2025-04-13 17:00:52,789 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=2 --n_estimators=50
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_170057-y55wiqnm
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/y55wiqnm
# 2025-04-13 17:00:57,804 - wandb.wandb_agent - INFO - Running runs: ['y55wiqnm']
# Train Acc: 0.8534, Test Acc: 0.8791, val Acc: 0.8534
# wandb:
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.85335
# wandb:      test_accuracy 0.87907
# wandb:     train_accuracy 0.85335
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/y55wiqnm
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_170057-y55wiqnm/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 17:01:07,905 - wandb.wandb_agent - INFO - Cleaning up finished run: y55wiqnm
# 2025-04-13 17:01:08,167 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 17:01:08,168 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 20
# 	n_estimators: 200
# 2025-04-13 17:01:08,169 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=20 --n_estimators=200
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_170112-6zacuw44
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/6zacuw44
# 2025-04-13 17:01:13,186 - wandb.wandb_agent - INFO - Running runs: ['6zacuw44']
# Train Acc: 1.0000, Test Acc: 1.0000, val Acc: 1.0000
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 1.0
# wandb:      test_accuracy 1.0
# wandb:     train_accuracy 1.0
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/6zacuw44
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_170112-6zacuw44/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 17:01:23,292 - wandb.wandb_agent - INFO - Cleaning up finished run: 6zacuw44
# 2025-04-13 17:01:23,477 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 17:01:23,477 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 10
# 	n_estimators: 50
# 2025-04-13 17:01:23,479 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=10 --n_estimators=50
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_170127-c2p6oysy
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/c2p6oysy
# Train Acc: 0.9818, Test Acc: 0.9767, val Acc: 0.9818
# 2025-04-13 17:01:28,494 - wandb.wandb_agent - INFO - Running runs: ['c2p6oysy']
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.98184
# wandb:      test_accuracy 0.97674
# wandb:     train_accuracy 0.98184
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/c2p6oysy
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_170127-c2p6oysy/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 17:01:38,600 - wandb.wandb_agent - INFO - Cleaning up finished run: c2p6oysy
# 2025-04-13 17:01:38,750 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 17:01:38,751 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 20
# 	n_estimators: 200
# 2025-04-13 17:01:38,752 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=20 --n_estimators=200
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_170142-c17sedlv
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/c17sedlv
# 2025-04-13 17:01:43,764 - wandb.wandb_agent - INFO - Running runs: ['c17sedlv']
# Train Acc: 1.0000, Test Acc: 1.0000, val Acc: 1.0000
# wandb:
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 1.0
# wandb:      test_accuracy 1.0
# wandb:     train_accuracy 1.0
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/c17sedlv
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_170142-c17sedlv/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 17:01:53,861 - wandb.wandb_agent - INFO - Cleaning up finished run: c17sedlv
# 2025-04-13 17:01:53,993 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 17:01:53,993 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 2
# 	n_estimators: 50
# 2025-04-13 17:01:53,994 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=2 --n_estimators=50
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_170158-24k62i0n
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/24k62i0n
# 2025-04-13 17:01:59,006 - wandb.wandb_agent - INFO - Running runs: ['24k62i0n']
# Train Acc: 0.8534, Test Acc: 0.8791, val Acc: 0.8534
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.85335
# wandb:      test_accuracy 0.87907
# wandb:     train_accuracy 0.85335
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/24k62i0n
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_170158-24k62i0n/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 17:02:09,110 - wandb.wandb_agent - INFO - Cleaning up finished run: 24k62i0n
# 2025-04-13 17:02:09,352 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 17:02:09,352 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 2
# 	n_estimators: 200
# 2025-04-13 17:02:09,353 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=2 --n_estimators=200
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_170213-azn6h7af
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/azn6h7af
# 2025-04-13 17:02:14,368 - wandb.wandb_agent - INFO - Running runs: ['azn6h7af']
# Train Acc: 0.8659, Test Acc: 0.8744, val Acc: 0.8659
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.86592
# wandb:      test_accuracy 0.87442
# wandb:     train_accuracy 0.86592
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/azn6h7af
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_170213-azn6h7af/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 17:02:24,469 - wandb.wandb_agent - INFO - Cleaning up finished run: azn6h7af
# 2025-04-13 17:02:24,640 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 17:02:24,640 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 10
# 	n_estimators: 50
# 2025-04-13 17:02:24,641 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=10 --n_estimators=50
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_170228-79ss3bkt
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/79ss3bkt
# 2025-04-13 17:02:29,654 - wandb.wandb_agent - INFO - Running runs: ['79ss3bkt']
# Train Acc: 0.9818, Test Acc: 0.9767, val Acc: 0.9818
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.98184
# wandb:      test_accuracy 0.97674
# wandb:     train_accuracy 0.98184
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/79ss3bkt
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_170228-79ss3bkt/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 17:02:39,756 - wandb.wandb_agent - INFO - Cleaning up finished run: 79ss3bkt
# 2025-04-13 17:02:39,971 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 17:02:39,971 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 20
# 	n_estimators: 100
# 2025-04-13 17:02:39,972 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=20 --n_estimators=100
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_170243-v852u6p0
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/v852u6p0
# 2025-04-13 17:02:44,984 - wandb.wandb_agent - INFO - Running runs: ['v852u6p0']
# Train Acc: 1.0000, Test Acc: 1.0000, val Acc: 1.0000
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 1.0
# wandb:      test_accuracy 1.0
# wandb:     train_accuracy 1.0
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/v852u6p0
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_170243-v852u6p0/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 17:02:55,092 - wandb.wandb_agent - INFO - Cleaning up finished run: v852u6p0
# 2025-04-13 17:02:55,274 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 17:02:55,274 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 10
# 	n_estimators: 200
# 2025-04-13 17:02:55,276 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=10 --n_estimators=200
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_170259-ofngdwki
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/ofngdwki
# 2025-04-13 17:03:00,288 - wandb.wandb_agent - INFO - Running runs: ['ofngdwki']
# Train Acc: 0.9870, Test Acc: 0.9953, val Acc: 0.9870
# wandb:
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.98696
# wandb:      test_accuracy 0.99535
# wandb:     train_accuracy 0.98696
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/ofngdwki
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_170259-ofngdwki/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 17:03:10,384 - wandb.wandb_agent - INFO - Cleaning up finished run: ofngdwki
# 2025-04-13 17:03:10,524 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 17:03:10,525 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 2
# 	n_estimators: 200
# 2025-04-13 17:03:10,526 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=2 --n_estimators=200
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_170315-2hhga9jz
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# ...
# 2025-04-13 17:08:27,390 - wandb.wandb_agent - INFO - Cleaning up finished run: ct6nylw6
# 2025-04-13 17:08:27,546 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 17:08:27,546 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 2
# 	n_estimators: 50
# 2025-04-13 17:08:27,548 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=2 --n_estimators=50
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_170831-36d39l7n
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/36d39l7n
# 2025-04-13 17:08:32,561 - wandb.wandb_agent - INFO - Running runs: ['36d39l7n']
# Train Acc: 0.8534, Test Acc: 0.8791, val Acc: 0.8534
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.85335
# wandb:      test_accuracy 0.87907
# wandb:     train_accuracy 0.85335
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/36d39l7n
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_170831-36d39l7n/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 17:08:42,675 - wandb.wandb_agent - INFO - Cleaning up finished run: 36d39l7n
# 2025-04-13 17:08:42,844 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 17:08:42,844 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 20
# 	n_estimators: 200
# 2025-04-13 17:08:42,846 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=20 --n_estimators=200
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_170847-yv6jv40x
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/yv6jv40x
# 2025-04-13 17:08:47,856 - wandb.wandb_agent - INFO - Running runs: ['yv6jv40x']
# Train Acc: 1.0000, Test Acc: 1.0000, val Acc: 1.0000
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 1.0
# wandb:      test_accuracy 1.0
# wandb:     train_accuracy 1.0
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/yv6jv40x
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_170847-yv6jv40x/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 17:08:57,960 - wandb.wandb_agent - INFO - Cleaning up finished run: yv6jv40x
# 2025-04-13 17:08:58,238 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 17:08:58,238 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 2
# 	n_estimators: 200
# 2025-04-13 17:08:58,240 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=2 --n_estimators=200
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_170902-gyt43ikx
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/gyt43ikx
# 2025-04-13 17:09:03,256 - wandb.wandb_agent - INFO - Running runs: ['gyt43ikx']
# Train Acc: 0.8659, Test Acc: 0.8744, val Acc: 0.8659
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.86592
# wandb:      test_accuracy 0.87442
# wandb:     train_accuracy 0.86592
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/gyt43ikx
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_170902-gyt43ikx/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 17:09:13,363 - wandb.wandb_agent - INFO - Cleaning up finished run: gyt43ikx
# 2025-04-13 17:09:13,532 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 17:09:13,532 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 20
# 	n_estimators: 50
# 2025-04-13 17:09:13,533 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=20 --n_estimators=50
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_170917-xw9qcr6n
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/xw9qcr6n
# 2025-04-13 17:09:18,545 - wandb.wandb_agent - INFO - Running runs: ['xw9qcr6n']
# Train Acc: 1.0000, Test Acc: 1.0000, val Acc: 1.0000
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 1.0
# wandb:      test_accuracy 1.0
# wandb:     train_accuracy 1.0
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/xw9qcr6n
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_170917-xw9qcr6n/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 17:09:28,645 - wandb.wandb_agent - INFO - Cleaning up finished run: xw9qcr6n
# 2025-04-13 17:09:28,797 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 17:09:28,797 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 2
# 	n_estimators: 50
# 2025-04-13 17:09:28,799 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=2 --n_estimators=50
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_170932-n71ck1u5
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/n71ck1u5
# 2025-04-13 17:09:33,811 - wandb.wandb_agent - INFO - Running runs: ['n71ck1u5']
# Train Acc: 0.8534, Test Acc: 0.8791, val Acc: 0.8534
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.85335
# wandb:      test_accuracy 0.87907
# wandb:     train_accuracy 0.85335
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/n71ck1u5
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_170932-n71ck1u5/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 17:09:43,930 - wandb.wandb_agent - INFO - Cleaning up finished run: n71ck1u5
# 2025-04-13 17:09:44,110 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 17:09:44,110 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 10
# 	n_estimators: 50
# 2025-04-13 17:09:44,111 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=10 --n_estimators=50
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_170948-9w50ckpe
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/9w50ckpe
# 2025-04-13 17:09:49,121 - wandb.wandb_agent - INFO - Running runs: ['9w50ckpe']
# Train Acc: 0.9818, Test Acc: 0.9767, val Acc: 0.9818
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: 0.001 MB of 0.001 MB uploaded
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.98184
# wandb:      test_accuracy 0.97674
# wandb:     train_accuracy 0.98184
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/9w50ckpe
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_170948-9w50ckpe/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 17:09:59,223 - wandb.wandb_agent - INFO - Cleaning up finished run: 9w50ckpe
# 2025-04-13 17:09:59,390 - wandb.wandb_agent - INFO - Agent received command: run
# 2025-04-13 17:09:59,390 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	max_depth: 2
# 	n_estimators: 50
# 2025-04-13 17:09:59,392 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train_random_forest.py --max_depth=2 --n_estimators=50
# wandb: Currently logged in as: vadhri-venkat to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignoring project 'pistachio-classification' when running a sweep.
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /content/wandb/run-20250413_171003-ej1iq2ad
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run data-partioning-model-eval
# wandb: ⭐️ View project at https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: 🧹 View sweep at https://wandb.ai/vadhri-venkat/pistachio-classification/sweeps/oc1a3evy
# wandb: 🚀 View run at https://wandb.ai/vadhri-venkat/pistachio-classification/runs/ej1iq2ad
# Train Acc: 0.8534, Test Acc: 0.8791, val Acc: 0.8534
# 2025-04-13 17:10:04,407 - wandb.wandb_agent - INFO - Running runs: ['ej1iq2ad']
# wandb:
# wandb:
# wandb: Run history:
# wandb: final_val_accuracy ▁
# wandb:      test_accuracy ▁
# wandb:     train_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb: final_val_accuracy 0.85335
# wandb:      test_accuracy 0.87907
# wandb:     train_accuracy 0.85335
# wandb:
# wandb: 🚀 View run data-partioning-model-eval at: https://wandb.ai/vadhri-venkat/pistachio-classification/runs/ej1iq2ad
# wandb: ⭐️ View project at: https://wandb.ai/vadhri-venkat/pistachio-classification
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20250413_171003-ej1iq2ad/logs
# wandb: WARNING The legacy backend is deprecated. In future versions, `wandb-core` will become the sole backend service, and the `wandb.require('legacy-service')` flag will be removed. For more information, visit https://wandb.me/wandb-core
# 2025-04-13 17:10:09,466 - wandb.wandb_agent - INFO - Cleaning up finished run: ej1iq2ad
# wandb: Terminating and syncing runs. Press ctrl-c to kill.
